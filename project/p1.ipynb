# %%
import pickle

with open('./dump.pickle','rb') as f:
    obj = pickle.load(f)
    
obj = [[text.split('.')[0] for text in doc if text!=''][0] for doc in obj]
obj
# Out:
# ['The Iago sparrow (Passer iagoensis), also known as the Cape Verde or rufous-backed sparrow, is a passerine bird of the sparrow family Passeridae',
#  'The Ibadan malimbe (Malimbus ibadanensis) is a rare species of bird in the family Ploceidae',
#  'The Ibera seedeater (Sporophila iberaensis) is a species of bird in the family Thraupidae, formerly included within the family of American sparrows (Emberizidae)',
#  'The Iberian chiffchaff (Phylloscopus ibericus) is a species of leaf warbler endemic to Portugal, Spain and North Africa, west of a line stretching roughly from the western Pyrenees via the mountains of central Spain to the Atlantic',
#  'The Iberian green woodpecker (Picus sharpei) is a medium-sized woodpecker endemic to the Iberian peninsula',
#  'Algarve, Portugal',
#  'Cyanopica cyana cooki\nCyanopica cyanus cooki',
#  'Clorhynchus strophiatus Hodgson, 1835',
#  'The Iceland gull (Larus glaucoides) is a medium-sized gull that breeds in the Arctic regions of Canada and Greenland, but not in Iceland (as its name suggests), where it is only seen during winter',
#  'The icterine greenbul (Phyllastrephus icterinus) is a species of songbird in the bulbul family, Pycnonotidae',
#  'The icterine warbler (Hippolais icterina) is an Old World warbler in the tree warbler genus Hippolais',
#  "Ihering's antwren (Myrmotherula iheringi) is a species of bird in the family Thamnophilidae",
#  'Acanthopneuste ijimae (protonym)[2]Acanthopneuste occipitalis ijimae[3]Phylloscopus coronatus ijimae[4]Phylloscopus tenellipes ijimae[5]',
#  'Hypocnemis cantator flavescens',
#  'The imitator goshawk or imitator sparrowhawk (Accipiter imitator) is a species of bird of prey in the family Accipitridae',
#  'The imperial amazon (Amazona imperialis) or Dominican amazon, also known as the sisserou or sisserou parrot, is a parrot found only on the Caribbean island of Dominica',
#  'The imperial shag or imperial cormorant (Leucocarbo atriceps) is a black and white cormorant native to southern South America, primarily in rocky coastal regions, but locally also at large inland lakes',
#  'The imperial snipe (Gallinago imperialis) is a small stocky wader which breeds in the Andes',
#  'The imperial woodpecker (Campephilus imperialis) is a woodpecker species endemic to Mexico',
#  'The Inaccessible Island finch (Nesospiza acunhae), also known as the Inaccessible bunting, is a species of bird in the family Thraupidae (formerly in Emberizidae)',
#  'The Inaccessible Island rail (Laterallus rogersi) is a small bird of the rail family, Rallidae',
#  'Nesophlox evelynae lyrura',
#  'The Inambari gnatcatcher (Polioptila attenboroughi) is a species of bird in the family Polioptilidae',
#  'The Inambari woodcreeper (Lepidocolaptes fatimalimae) is a species of bird in the subfamily Dendrocolaptinae',
#  'Scardafella inca',
#  'The Inca flycatcher (Leptopogon taczanowskii) is a species of bird in the family Tyrannidae',
#  'The Inca jay or querrequerre (Cyanocorax yncas) is a bird species of the New World jays, which is native to the Andes of South America',
#  'The  Inca tern (Larosterna inca) is a Near Threatened species of bird in subfamily Sterninae of the family Laridae, the gulls, terns, and skimmers',
#  'Thryothorus eisenmanni',
#  'The Indian blackbird (Turdus simillimus) is a member of the thrush family Turdidae',
#  'Parus aplonotus',
#  'Erithacus brunneusLarvivora brunneaTarsiger brunneaLarvivora wickhamiLuscinia brunnea',
#  'The Indian bush lark (Mirafra erythroptera) is a species of lark in the family Alaudidae found in South Asia',
#  'The Indian cormorant or Indian shag (Phalacrocorax fuscicollis) is a member of the cormorant family',
#  'Purandar, Pune, Maharashtra',
#  'The  Indian cuckoo (Cuculus micropterus) is a member of the cuckoo order of birds, the Cuculiformes, that is found in the Indian subcontinent and Southeast Asia',
#  'Urrua bengalensis[3]',
#  'The Indian golden oriole (Oriolus kundoo) is a species of oriole found in the Indian subcontinent and Central Asia',
#  'The Indian grassbird (Graminicola bengalensis) is a passerine bird in the family Pellorneidae',
#  'Lophoceros birostrisTockus birostrisOcyceros ginginianusMeniceros birostris',
#  'Corvus macrorhynchos culminatus',
#  'The Indian nightjar (Caprimulgus asiaticus) is a small nightjar which is a resident breeder in open lands across South Asia and Southeast Asia',
#  'The Indian nuthatch (Sitta castanea) is a species of bird in the family Sittidae',
#  'See text',
#  'The Indian peafowl (Pavo cristatus), also known as the common peafowl, and blue peafowl, is a peafowl species native to the Indian subcontinent',
#  'Corvus brachyurus Linnaeus, 1766[2]',
#  'Ardeola leucoptera',
#  'The Indian robin (Copsychus fulicatus)[note 1] is a species of passarine bird in the family Muscicapidae',
#  'Corvus benghalensis Linnaeus,\xa01758',
#  'P',
#  'The Indian scops owl (Otus bakkamoena) is a species of owl native to South Asia',
#  'The Indian silverbill or white-throated munia (Euodice malabarica) is a small passerine bird found in the Indian Subcontinent and adjoining regions that was formerly considered to include the closely related African silverbill (Euodice cantans)',
#  'Rhynchops albicollis',
#  'Anas poikilorhynchus',
#  'The Indian spotted creeper (Salpornis spilonota) is a small passerine bird, which is a member of the subfamily Salpornithinae which is placed along with the treecreepers in the family Certhiidae',
#  'Aquila hastata',
#  'The Indian stone-curlew or Indian thick-knee (Burhinus indicus) is a species of bird in the family Burhinidae',
#  'The Indian swiftlet or Indian edible-nest swiftlet  (Aerodramus unicolor) is a small swift',
#  'The Indian vulture (Gyps indicus) is an Old World vulture native to India, Pakistan and Nepal',
#  'Sylvia palpebrosaZosterops palpebrosa',
#  'Thalassarche chlororhynchos carteri\nThalassarche bassi',
#  'The indigo bunting (Passerina cyanea) is a small seed-eating bird in the cardinal family, Cardinalidae',
#  'Diglossopis indigotica',
#  'Stoparola indigo',
#  'The Indigo-banded kingfisher (Ceyx cyanopectus) is a species of bird in the family Alcedinidae',
#  'Amazilia cyanifrons[3]',
#  'The Indochinese barbet (Psilopogon annamensis), also called Annam barbet, is a bird belonging to the family Megalaimidae',
#  'The Indochinese blue flycatcher (Cyornis sumatrensis) is a species of bird in the family Muscicapidae',
#  'The Indochinese bush lark (Mirafra erythrocephala) or Indochinese lark is a species of lark in the family Alaudidae found in southeast Asia',
#  'The Indochinese cuckooshrike (Lalage polioptera) is a species of bird in the family Campephagidae',
#  'Alcippe danisi',
#  'The Indochinese green magpie (Cissa hypoleuca) or yellow-breasted magpie, is a passerine bird of the crow family, Corvidae',
#  'The Indochinese roller (Coracias affinis) or Burmese roller, is a member of the roller bird family',
#  'The Indochinese yuhina or chestnut-collared yuhina (Staphida torqueola) is a bird in the family Zosteropidae',
#  'Redirect to:',
#  'Charadrius australis',
#  'The inland thornbill (Acanthiza apicalis) was originally described by English ornithologist John Gould in The Birds of Australia',
#  'The intermediate egret, median egret, smaller egret, or yellow-billed egret (Ardea intermedia) is a medium-sized heron',
#  'Gallirallus wallacii',
#  'The Iphis monarch (Pomarea iphis), or Ua Huka flycatcher, is a species of bird in the family Monarchidae',
#  'The Iquitos gnatcatcher (Polioptila clementsi) is a bird in the family Polioptilidae',
#  'The Iraq babbler (Argya altirostris) is a species of bird in the family Leiothrichidae, native to reed beds of the Tigris-Euphrates Valley',
#  'The Iringa akalat (Sheppardia lowei) is a species of bird in the family Muscicapidae',
#  'The Iriomote tit (Sittiparus olivaceus) is a small passerine bird in the tit family Paridae',
#  'The iris lorikeet (Saudareos iris) is a small, up to 20\xa0cm long, green lorikeet bird',
#  'The Isabela oriole (Oriolus isabellae) is a species of the oriole family endemic to Luzon in the Philippines',
#  'Amaurornis isabellinus',
#  'The isabelline shrike or Daurian shrike (Lanius isabellinus) is a member of the shrike family (Laniidae)',
#  'The isabelline wheatear (Oenanthe isabellina) is a small passerine bird that was formerly classed as a member of the thrush family Turdidae, but is now more generally considered to be an Old World flycatcher in the family Muscicapidae',
#  'The island bronze-naped pigeon (Columba malherbii), also known as the São Tomé bronze-naped pigeon, is a species of bird in the family Columbidae',
#  'The island imperial pigeon (Ducula pistrinaria) is a species of bird in the family Columbidae',
#  'The island leaf warbler (Phylloscopus poliocephalus) is a species of Old World warbler in the family Phylloscopidae',
#  'See text',
#  'The island scrub jay (Aphelocoma insularis), also known as the island jay or Santa Cruz jay, is a bird in the genus, Aphelocoma, which is endemic to Santa Cruz Island off the coast of Southern California',
#  'Collocalia inquietus',
#  'See text',
#  'The island whistler (Pachycephala phaionota) is a species of bird in the family Pachycephalidae endemic to the Moluccas (Indonesia)',
#  'The islet kingfisher (Todiramphus colonus) is a species of bird in the family Alcedinidae',
#  'The isthmian wren (Cantorchilus elutus) is a species of bird in the family Troglodytidae',
#  'The Italian sparrow (Passer italiae), also known as the cisalpine sparrow, is a passerine bird of the sparrow family Passeridae, found in Italy and other parts of the Mediterranean region',
#  'The Itatiaia spinetail (Asthenes moreirae), also known as the Itatiaia thistletail, is a species of bird in the family Furnariidae',
#  'The Itombwe flycatcher (Muscicapa itombwensis) is a bird species in the Old World flycatcher family (Muscicapidae)',
#  "The Ituri batis or Chapin's batis (Batis ituriensis) is a species of bird in the wattle-eye family, Platysteiridae which is found in the humid forests of eastern central Africa",
#  'The ivory gull (Pagophila eburnea) is a small gull, the only species in the genus Pagophila',
#  'The ivory-backed woodswallow (Artamus monachus) is a species of bird in the family Artamidae',
#  'See text',
#  'The ivory-billed coucal or greater black coucal (Centropus menbeki) is a species of cuckoo in the family Cuculidae',
#  'The ivory-billed woodcreeper (Xiphorhynchus flavigaster) is a species of bird of the order of Passeriformes, which are perching birds',
#  'Picus principalis Linnaeus, 1758',
#  'The ivory-breasted pitta (Pitta maxima) is a species of bird in the family Pittidae',
#  'The Izu thrush or Izu Islands thrush (Turdus celaenops) is a bird of the thrush family native to Japan',
#  'The gabar goshawk (Micronisus gabar) is a small species of African and Arabian bird of prey in the family Accipitridae',
#  'The Gabela akalat (Sheppardia gabela) is a species of bird in the family Muscicapidae',
#  'Laniarius luehderi amboimensis',
#  'The Gabela helmetshrike (Prionops gabela) is a species of bird in the Vanga family Vangidae, formerly usually included in the Malaconotidae',
#  'Platystira minima J',
#  'The Gabon coucal (Centropus anselli) is a species of cuckoo in the family Cuculidae',
#  'The Gabon woodpecker (Dendropicos gabonensis) is a species of small woodpecker in the family Picidae which occurs in western central Africa',
#  'The gadwall (Mareca strepera) is a common and widespread dabbling duck[2] in the family Anatidae',
#  'The galah (/ɡəˈlɑː/; Eolophus roseicapilla), also known as the pink and grey cockatoo or rose-breasted cockatoo,[2] is the only species within genus Eolophus of the cockatoo family',
#  "The Galapagos crake (Laterallus spilonota), also called the Galapagos rail and Darwin's rail, is a Vulnerable species of rail in subfamily Rallinae of family Rallidae, the rails, gallinules, and coots",
#  'The Galápagos dove (Zenaida galapagoensis) is a species of bird in the family Columbidae',
#  'The Galápagos flycatcher (Myiarchus magnirostris) also known as the large-billed flycatcher is a species of bird in the family Tyrannidae',
#  'The Galápagos hawk (Buteo galapagoensis) is a large hawk endemic to most of the Galápagos Islands',
#  'The Galápagos martin (Progne modesta) is a species of bird in the family Hirundinidae, endemic to the Galápagos Islands',
#  'The Galápagos mockingbird (Mimus parvulus) is a species of bird in the family Mimidae',
#  'The Galápagos penguin (Spheniscus mendiculus) is a penguin endemic to the Galápagos Islands, Ecuador',
#  'The Galápagos petrel (Pterodroma phaeopygia) is one of the six endemic seabirds of the Galápagos',
#  'Puffinus lherminieri subalaris',
#  'The Gambaga flycatcher (Muscicapa gambagae) is a species of bird in the family Muscicapidae',
#  "Gambel's quail (Callipepla gambelii) is a small ground-dwelling bird in the New World quail family",
#  'The gang-gang cockatoo (Callocephalon fimbriatum) is a parrot found in the cooler and wetter forests and woodlands of Australia, particularly alpine bushland',
#  'The Gansu leaf warbler (Phylloscopus kansuensis) is a small passerine bird known only from China',
#  'The garden emerald (Chlorostilbon assimilis) is a small hummingbird in the "emeralds", tribe Trochilini of subfamily Trochilinae',
#  'The garden warbler (Sylvia borin) is a common and widespread small bird that breeds in most of Europe and in the Palearctic to western Siberia',
#  'The garganey (Spatula querquedula) is a small dabbling duck',
#  'Pitta granatina',
#  'The garnet robin (Eugerygone rubra) is a species of bird in the family Petroicidae',
#  'The garnet-throated hummingbird (Lamprolaima rhami) is a species of hummingbird in tribe Lampornithini of subfamily Trochilinae',
#  "Garrett's reed warbler (Acrocephalus musae), sometimes called Society Islands reed warbler or Forster's reed-warbler was a songbird in the genus Acrocephalus",
#  'Trogon violaceus caligatus',
#  'The Geelvink pygmy parrot  (Micropsitta geelvinkiana) is a species of parrot in the family Psittacidae endemic to Biak and Numfoor islands in Western New Guinea',
#  'The Genovesa cactus finch (Geospiza propinqua) is a species of bird in the tanager family Thraupidae',
#  'Geospiza difficilis acutirostris',
#  'The gentoo penguin (/ˈdʒɛntuː/ JEN-too) (Pygoscelis papua) is a penguin species (or possibly a species complex) in the genus Pygoscelis, most closely related to the Adélie penguin (P',
#  'Augastes geoffroyi (Bourcier, 1843)',
#  'Geomalia heinrichi',
#  "Germain's peacock-pheasant (Polyplectron germaini) is a pheasant that is endemic to Indochina",
#  'Collocalia germani',
#  'The giant antpitta (Grallaria gigantea) is a perching bird species in the antpitta family (Grallariidae)',
#  'The giant antshrike (Batara cinerea) is a species of bird in the family Thamnophilidae, belonging to the monotypic genus Batara',
#  'Ianthocincla waddelliBabax waddelli',
#  'Oreomanes fraseri',
#  'The giant coot (Fulica gigantea) is a species of bird in subfamily Rallinae of family Rallidae, the rails, gallinules, and coots',
#  'The giant coua (Coua gigas) is a bird species from the coua genus in the cuckoo family that is endemic to the dry forests of western and southern Madagascar',
#  'Scaphidura oryzivora',
#  'The giant honeyeater or duetting giant honeyeater (Gymnomyza brunneirostris) is a species of bird in the family Meliphagidae',
#  'The giant hummingbird (Patagona gigas) is the only member of the genus Patagona and the largest member of the hummingbird family, weighing 18–24\xa0g (0',
#  'Pseudibis gigantea Oustalet, 1877',
#  'The giant kingbird (Tyrannus cubensis) is a species of bird in the tyrant flycatcher family Tyrannidae endemic to Cuba',
#  'The giant kingfisher (Megaceryle maxima) is the largest kingfisher in Africa, where it is a resident breeding bird over most of the continent south of the Sahara Desert, other than the arid southwest',
#  'Garrulax maximus',
#  'The giant nuthatch (Sitta magna) is a species of bird in the family Sittidae',
#  'The giant pitta (Hydrornis caeruleus) is a species of bird in the family Pittidae',
#  'The giant scops owl (Otus gurneyi), lesser eagle-owl or the Mindanao eagle-owl, is a species of owl in the family Strigidae',
#  'The giant snipe (Gallinago undulata) is a stocky wader',
#  'The giant sunbird (Dreptes thomensis) is a species of bird in the family Nectariniidae',
#  'Hydrochrous gigas (Hartert & Butler, 1901) [orthographic error]',
#  'The giant weaver (Ploceus grandis) is a species of bird in the family Ploceidae',
#  'The giant white-eye, or Palau greater white-eye (Megazosterops palauensis) is a species of bird in the family Zosteropidae',
#  'The giant wood rail (Aramides ypecaha) is a species of bird in the subfamily Rallinae of the rail, crake, and coot family Rallidae',
#  'The giant wren (Campylorhynchus chiapensis) is a species of bird in the family Troglodytidae',
#  'The gibberbird (Ashbyia lovensis) is a species of chat within the Meliphagidae family of passerine birds',
#  'The Gila woodpecker (Melanerpes uropygialis) is a medium-sized woodpecker of the desert regions of the southwestern United States and western Mexico',
#  "Gilbert's honeyeater (Melithreptus chloropsis), also known as the Swan River honeyeater or western white-naped honeyeater, is a passerine bird of the honeyeater family Meliphagidae native to southwestern Australia",
#  "The Gilbert's whistler (Pachycephala inornata) is a monotypic species of bird endemic to Australia, scattered in semi-arid zones of southern Australia",
#  'The gilded barbet (Capito auratus) is a species of bird in the family Capitonidae, the New World barbets, and are close relatives of the toucans',
#  'The gilded flicker (Colaptes chrysoides) is a large-sized woodpecker (mean length of 29\xa0cm (11\xa0in)) of the Sonoran, Yuma, and eastern Colorado Desert regions of the southwestern United States and northwestern Mexico, including all of Baja California, except the extreme northwestern region',
#  'The gilded sapphire (Hylocharis chrysura), also known as the gilded hummingbird, is a species of hummingbird in the "emeralds", tribe Trochilini of subfamily Trochilinae',
#  'See text',
#  'Melidectes whitemanensis',
#  'Tanagra cyanoventris Vieillot, 1819[2]',
#  'The Gizo white-eye or yellow-billed white-eye (Zosterops luteirostris) is a species of bird in the family Zosteropidae',
#  'The glaucous gull (Larus hyperboreus) is a large gull, the second-largest gull in the world',
#  'The glaucous macaw (Anodorhynchus glaucus) is a critically endangered or possibly extinct species of large, blue and grey South American parrot, a member of a large group of neotropical parrots known as macaws',
#  'The glaucous tanager (Thraupis glaucocolpa) is a species of bird in the family Thraupidae',
#  "Passerina glaucocaerulea (D'Orbigny & Lafresnaye, 1837)",
#  'The glaucous-winged gull (Larus glaucescens) is a large, white-headed gull',
#  'The glistening-green tanager (Chlorochrysa phoenicotis) is a species of bird in the family Thraupidae',
#  'Redirect to:',
#  "Chlorostilbon aureoventris (D'Orbigny and Lafresnaye, 1838)",
#  'The glittering-throated emerald (Chionomesa fimbriata) is a species of hummingbird in the "emeralds", tribe Trochilini of subfamily Trochilinae',
#  'The glossy antshrike (Sakesphorus luctuosus) is a species of bird in the family Thamnophilidae, the antbirds',
#  'C',
#  'The glossy flowerpiercer (Diglossa lafresnayii) is a species of bird in the family Thraupidae',
#  'The glossy ibis (Plegadis falcinellus) is a water bird in the order Pelecaniformes and the ibis and spoonbill family Threskiornithidae',
#  'Hirundo esculenta Linnaeus,\xa01758',
#  'Muscicapa surinama Linnaeus,\xa01766',
#  'Muscicapa divaricataDicrurus adsimilis divaricatus',
#  'Turdus serranus unicolor Olrog & Contino, 1970 (non Tickell, 1833: preoccupied)',
#  'The glossy-mantled manucode (Manucodia ater) is a species of bird-of-paradise',
#  'The glowing puffleg (Eriocnemis vestita) is a species of hummingbird in the "brilliants", tribe Heliantheini in subfamily Lesbiinae',
#  'The glow-throated hummingbird (Selasphorus ardens) is an Endangered species of hummingbird in tribe Mellisugini of subfamily Trochilinae, the "bee hummingbirds"',
#  "Godlewski's bunting (Emberiza godlewskii) is a species of bird in the family Emberizidae",
#  'Myrmeciza goeldii',
#  "The Gola malimbe or Ballman's malimbe (Malimbus ballmanni) is a species of bird in the family Ploceidae",
#  'The goldcrest (Regulus regulus) is a very small passerine bird in the kinglet family',
#  'The golden babbler (Cyanoderma chrysaeum) is a babbler species in the family Timaliidae',
#  'The golden bowerbird (Prionodura newtoniana) is a species of bird in the family Ptilonorhynchidae, the bowerbirds',
#  'The golden bush robin (Tarsiger chrysaeus) or golden bush-robin was first discovered in 1845 by Brian Houghton Hodgson, a British naturalist',
#  'The golden cuckooshrike (Campochaera sloetii) is a species of bird in the family Campephagidae',
#  '6, see text',
#  'The golden fruit dove (Ptilinopus luteovirens), also known as the lemon dove or yellow dove, is a small, approximately 20\xa0cm (8\xa0in) long, short-tailed fruit-dove in the family Columbidae',
#  '(Genus)',
#  'The golden grosbeak (Pheucticus chrysogaster), also known as golden-bellied grosbeak or southern yellow grosbeak, is a species of grosbeak in the family Cardinalidae',
#  'The golden masked owl (Tyto aurantia) is a barn owl endemic to the island of New Britain, Papua New Guinea',
#  'See text',
#  'The golden myna (Mino anais) is a species of starling in the family Sturnidae',
#  'The golden nightjar (Caprimulgus eximius) is a species of nightjar in the family Caprimulgidae',
#  'The golden palm weaver (Ploceus bojeri) is a species of bird in the weaver family, Ploceidae',
#  'Psittacus guaroubaAratinga guarouba',
#  'Paradoxornis verreauxi',
#  'Phasianus pictus Linnaeus,\xa01758',
#  'The golden pipit (Tmetothylacus tenellus) is a distinctive pipit of dry country grassland, savanna and shrubland in eastern Africa',
#  'Hirundo sclateri Cory, 1884',
#  'The golden tanager (Tangara arthus) is a species of bird in the family Thraupidae',
#  'The golden vireo (Vireo hypochryseus) is a species of bird in the family Vireonidae',
#  'Ptilotis marchei',
#  'The golden-backed bishop (Euplectes aureus) is a species of bird in the family Ploceidae',
#  'Buthraupis aureodorsalis',
#  "The golden-backed weaver (Ploceus jacksoni), also known as Jackson's weaver, is a species of bird in the family Ploceidae",
#  'The golden-backed whistler (Pachycephala aurea) or yellow-backed whistler, is a species of bird in the family Pachycephalidae',
#  'The golden-bellied flycatcher (Myiodynastes hemichrysus) is a passerine bird in the tyrant flycatcher family',
#  'The golden-bellied flyrobin (Microeca hemixantha) is a species of bird in the family Petroicidae',
#  'The golden-bellied gerygone (Gerygone sulphurea) is a species of bird in the family Acanthizidae',
#  'The golden-bellied starfrontlet (Coeligena bonapartei) is a species of hummingbird in the "brilliants", tribe Heliantheini in subfamily Lesbiinae',
#  'The golden-bellied warbler has been split into two species:',
#  'The golden-bellied white-eye (Zosterops uropygialis) is a species of bird in the family Zosteropidae',
#  'The golden-billed saltator (Saltator aurantiirostris) is a species of saltator in the family Thraupidae',
#  'The golden-breasted bunting (Emberiza flaviventris) is a passerine bird in the bunting family Emberizidae',
#  'The golden-breasted fruiteater (Pipreola aureopectus) is a species of bird in the family Cotingidae',
#  'The golden-breasted fulvetta (Lioparus chrysotis) is a species of songbird found in Bhutan, China, India, Myanmar, Nepal, and Vietnam',
#  'The golden-breasted puffleg (Eriocnemis mosquera) is a species of hummingbird in the "brilliants", tribe Heliantheini in subfamily Lesbiinae',
#  'The golden-breasted starling (Lamprotornis regius), also known as royal starling, is a medium-sized passerine in the starling family',
#  'The golden-browed chat-tyrant (Silvicultrix pulchella) is a species of passerine bird in the family Tyrannidae',
#  'The golden-browed chlorophonia (Chlorophonia callophrys) is a species of bird in the family Fringillidae',
#  'The golden-browed warbler (Basileuterus belli) is a species of bird in the family Parulidae, the New World warblers',
#  'Aratinga auricapilla (Kuhl, 1820)',
#  'Dendroica chrysoparia Sclater & Salvin, 1861',
#  'The golden-cheeked woodpecker (Melanerpes chrysogenys) is a species of bird in subfamily Picinae of the woodpecker family Picidae',
#  'The golden-chested tanager (Bangsia rothschildi) is a species of bird in the family Thraupidae',
#  'The golden-chevroned tanager (Thraupis ornata) is a species of bird in the family Thraupidae',
#  'The golden-collared honeycreeper (Iridophanes pulcherrimus) is an uncommon species of Neotropical bird in the tanager family Thraupidae',
#  'The golden-collared macaw or yellow-collared macaw (Primolius auricollis) is a small mostly green Central South American parrot, a member of a large group of Neotropical parrots known as macaws',
#  'The golden-collared manakin (Manacus vitellinus) is a species of bird in the family Pipridae',
#  'The golden-collared tanager (Iridosornis jelskii) is a species of bird in the family Thraupidae',
#  'See text',
#  'Dryobates cassini',
#  'The golden-crested myna (Ampeliceps coronatus) is a species in the starling and myna family, Sturnidae',
#  'The golden-crowned babbler (Sterrhoptilus dennistouni) is a species of bird in the family Zosteropidae',
#  'Trochilus auriceps; Chlorostilbon auriceps',
#  'The golden-crowned flycatcher (Myiodynastes chrysocephalus) is a species of bird in the family Tyrannidae',
#  'The golden-crowned kinglet (Regulus satrapa) is a very small songbird in the family Regulidae that lives throughout much of North America',
#  'Pipra vilasboasi Sick, 1959',
#  'The golden-crowned spadebill (Platyrinchus coronatus) is a species of bird in the family Tyrannidae',
#  'Emberiza atricapilla Gmelin, 1789\nZonotrichia coronata Pallas, 1844',
#  'The golden-crowned tanager (Iridosornis rufivertex) is a species of bird in the family Thraupidae',
#  'The golden-crowned warbler (Basileuterus culicivorus) is a small New World warbler',
#  'The golden-eared tanager (Tangara chrysotis) is a species of bird in the tanager family Thraupidae',
#  'Diglossopis glauca',
#  'The goldenface (Pachycare flavogriseum) is a species of passerine bird endemic to New Guinea',
#  'The golden-faced tyrannulet (Zimmerius chrysops) is a species of bird belonging to the family Tyrannidae',
#  'The golden-fronted bowerbird (Amblyornis flavifrons) is a medium-sized, approximately 24\xa0cm long, brown bowerbird',
#  'The golden-fronted fulvetta (Schoeniparus variegaticeps), also known as the gold-fronted fulvetta, is a species of bird in the family Pellorneidae',
#  'Hylophilus aurantiifrons',
#  'The golden-fronted leafbird (Chloropsis aurifrons) is a species of leafbird',
#  'The golden-fronted whitestart (Myioborus ornatus) or the golden-fronted redstart, is a species of bird in the family Parulidae',
#  'The golden-fronted woodpecker (Melanerpes aurifrons) is a species of bird in subfamily Picinae of the woodpecker family Picidae',
#  'The golden-green woodpecker (Piculus chrysochloros) is a species of bird in subfamily Picinae of the woodpecker family Picidae',
#  'The golden-headed cisticola (Cisticola exilis), also known as the bright-capped cisticola, is a species of warbler in the family Cisticolidae, found in Australia and thirteen Asian countries',
#  'The golden-headed manakin (Ceratopipra erythrocephala) is a small passerine bird which breeds in tropical Central and South America in both wet and dry forests, secondary growth and plantations',
#  'The golden-headed quetzal or corequenque (Pharomachrus auriceps) is a strikingly coloured bird in the genus Pharomachrus; it is also referred to as Trogon auriceps',
#  'The golden-hooded tanager (Stilpnia larvata) is a medium-sized passerine bird',
#  'The golden-mantled racket-tail (Prioniturus platurus) is a species of parrot in the family Psittaculidae',
#  'Megalaima pulcherrimus',
#  'The golden-naped finch (Pyrrhoplectes epauletta) is a species of finch in the family Fringillidae',
#  'The golden-naped tanager (Chalcothraupis ruficervix) is a species of bird in the tanager family Thraupidae',
#  'The golden-naped weaver (Ploceus aureonucha) is a species of bird in the family Ploceidae',
#  'The golden-naped woodpecker (Melanerpes chrysauchen) is a species of bird in the woodpecker family Picidae',
#  'The golden-olive woodpecker (Colaptes rubiginosus) is a species of bird in subfamily Picinae of the woodpecker family Picidae',
#  'The golden-plumed parakeet (Leptosittaca branickii) is a Neotropical parrot species within the family Psittacidae, belonging to the monotypic genus Leptosittaca',
#  'Euphonia cyanocephala',
#  'The golden-rumped flowerpecker (Dicaeum annae) is a species of bird in the family Dicaeidae',
#  'Psephotus chrysopterygius',
#  'The golden-sided euphonia (Euphonia cayennensis) is a species of bird in the family Fringillidae',
#  'The golden-spangled piculet (Picumnus exilis) is a species of bird in subfamily Picumninae of the woodpecker family Picidae',
#  'The golden-spotted ground dove (Metriopelia aymara) is a species of bird in the family Columbidae',
#  'Touit surda (lapsus)',
#  'Amazilia oenone[3]',
#  'Chrysoptilus abingoni',
#  'Cyanops ramsayiMegalaima franklinii',
#  'The golden-tufted mountain grackle (Macroagelaius imthurni), also known as the golden-tufted grackle, is a species of bird in the family Icteridae',
#  'Megalaima chrysopogon',
#  'The golden-winged cacique (Cacicus chrysopterus) is a species of bird in the family Icteridae',
#  'Garrulax ngoclinhensis',
#  'The golden-winged manakin (Masius chrysopterus) is a species of bird in the family Pipridae',
#  'Psittacus chrysopterus Linnaeus,\xa01766',
#  'The golden-winged sparrow (Arremon schlegeli) is a species of bird in the family Passerellidae that can found in Colombia and Venezuela',
#  'The golden-winged sunbird (Drepanorhynchus reichenowi) is a species of bird in the family Nectariniidae',
#  'The golden-winged tody-flycatcher (Poecilotriccus calopterus) is a species of bird in the family Tyrannidae, and one of twelve in the genus Poecilotriccus',
#  'The golden-winged warbler (Vermivora chrysoptera) is a New World warbler',
#  "Goldie's bird-of-paradise (Paradisaea decora) is a species of bird-of-paradise",
#  "Goldie's lorikeet (Glossoptilus goldiei) is a species of parrot in the family Psittaculidae",
#  "Goldman's warbler (Setophaga goldmani) is a songbird species in the New World warbler family (Parulidae)",
#  'The gold-ringed tanager (Bangsia aureocincta) is a species of bird in the family Thraupidae, endemic to Colombia',
#  'The goliath coucal (Centropus goliath) is a species of cuckoo in the family Cuculidae',
#  'Garza goliath',
#  'The goliath imperial pigeon (Ducula goliath), also known as the New Caledonian imperial pigeon[2] and the notou,[3] is a species of bird in the family Columbidae',
#  'Telophorus quadricolor',
#  'The gorgeted puffleg (Eriocnemis isabellae) is a Critically Endangered species of hummingbird in the "brilliants", tribe Heliantheini in subfamily Lesbiinae',
#  'The gorgeted sunangel (Heliangelus strophianus) is a species of hummingbird in the "coquettes", tribe Lesbiini of subfamily Lesbiinae',
#  'The rare gorgeted wood quail (Odontophorus strophium) is a small ground-dwelling bird',
#  'Acestrura heliodor[3]',
#  "Gosling's apalis (Apalis goslingi) is a species of bird in the family Cisticolidae",
#  "Gosling's bunting[2] (Emberiza goslingi), also known as the grey-throated bunting,[1] is a species of bird in the family Emberizidae",
#  'Nesospiza goughensis (protonym)Nesospiza jessiae',
#  'The Gough moorhen (Gallinula comeri) is a medium-sized, almost flightless bird that is similar to the common moorhen (Gallinula chloropus), but is smaller, stockier, and has shorter wings',
#  "The Gouldian finch (Chloebia gouldiae), also known as the Lady Gouldian finch, Gould's finch or the rainbow finch, is a colourful passerine bird that is native to Australia",
#  "Gould's emerald (Riccordia elegans) is an extinct species of hummingbird in the family Trochilidae",
#  "Gould's frogmouth (Batrachostomus stellatus) is a nocturnal species of bird in the order Caprimulgiformes and the family Podargidae",
#  "Gould's jewelfront or Gould's brilliant  (Heliodoxa aurescens) is a medium-sized hummingbird in the family Trochilidae",
#  'Redirect to:',
#  "Gould's petrel (Pterodroma leucoptera) is a species of seabird in the family Procellariidae",
#  'Brachypteryx stellatus',
#  "Gould's toucanet (Selenidera gouldii) is a near-passerine bird in the toucan family Ramphastidae",
#  'The graceful honeyeater (Microptilotis gracilis) is a species of bird in the family Meliphagidae',
#  'The graceful pitta (Erythropitta venusta), sometimes alternatively known as the black-crowned pitta (although this term is more regularly applied to E',
#  'The graceful prinia (Prinia gracilis) is a small warbler (in some older works it is referred to as graceful warbler)',
#  "Grace's warbler (Setophaga graciae) is a small New World warbler that specializes in pine woods",
#  'Fringilla teydea polatzeki, Hartert 1905',
#  'The Grand Comoro brush warbler (Nesillas brevicaudata) is a species of Old World warbler in the family Acrocephalidae',
#  'The Grand Comoro bulbul (Hypsipetes parvirostris) is a species of songbird in the bulbul family, Pycnonotidae',
#  'The Grand Comoro drongo (Dicrurus fuscipennis) is a species of bird in the family Dicruridae',
#  'The grand rhabdornis (Rhabdornis grandis), also known as the long-billed rhabdornis or long-billed creeper, is a species of bird currently placed in the starling family, Sturnidae',
#  'The grandala (Grandala coelicolor) is a species of bird in the thrush family Turdidae',
#  "Grant's bluebill (Spermophaga poliogenys) is a species of estrildid finch found in forests in central Africa in subtropical forests or in moist lowlands",
#  'Redirect to:',
#  'The grass wren (Cistothorus platensis) is a species of passerine bird in the family Troglodytidae',
#  'The grass-green tanager (Chlorornis riefferii) is a small South America bird in the tanager family Thraupidae',
#  'The grasshopper buzzard (Butastur rufipennis) is a species of bird of prey in the family Accipitridae which is found in a narrow zone of sub-Saharan Africa north of the equator',
#  'Coturniculus savannarum',
#  'The grassland sparrow (Ammodramus humeralis) is a species of bird in the family Passerellidae',
#  'Sicalis luteiventris',
#  "Grauer's broadbill (Pseudocalyptomena graueri), also known as the African green broadbill, is a species of bird in the family Eurylaimidae, and is monotypic within the genus Pseudocalyptomena",
#  'Coracina graueri',
#  "Grauer's swamp warbler (Bradypterus graueri) is a species of Old World warbler in the family Locustellidae",
#  "Grauer's warbler (Graueria vittata) is a species of Old World warbler in the family Acrocephalidae",
#  'Molothrus badius (Vieillot, 1819)',
#  'The gray-barred wren (Campylorhynchus megalopterus) is a species of bird in the family Troglodytidae',
#  'Genus:\nGaleoscoptes Cabanis, 1850',
#  'Asturina plagiata\nButeo nitidus plagiatus\nAsturina nitida plagiata',
#  'The gray kingbird or grey kingbird (Tyrannus dominicensis), also known as pitirre, petchary or white-breasted kingbird, is a passerine bird in the tyrant flycatchers family Tyrannidae',
#  'The gray thrasher (Toxostoma cinereum) is a medium-sized passerine bird belonging to the family Mimidae',
#  'The gray vireo (Vireo vicinior) is a small North American passerine bird',
#  'Linaria tephrocotis Swainson, 1831[2]',
#  'The gray-headed kite (Leptodon cayanensis) is a raptor found in open woodland and swamp forests',
#  'Asturina nitida',
#  'Locustella fasciolata',
#  'See text',
#  'The gray-throated warbling finch (Microspingus cabanisi) is a species of bird in the family Thraupidae',
#  'The great antpitta (Grallaria excelsa) is a species of bird in the family Grallariidae',
#  'The great antshrike (Taraba major) is a passerine bird in the antbird family, Thamnophilidae',
#  'The great argus (Argusianus argus) is a species of pheasant from Southeast Asia',
#  'The great auk (Pinguinus impennis) is a species of flightless alcid that became extinct in the mid-19th century',
#  'The great barbet (Psilopogon virens) is an Asian barbet native to the Indian sub-continent and Southeast Asia, where it inhabits foremost forests up to 3,000\xa0m (9,800\xa0ft) altitude',
#  'The great black hawk (Buteogallus urubitinga) is a bird of prey in the family Accipitridae, which also includes the eagles, hawks, and Old World vultures',
#  'The great black-backed gull (Larus marinus) is the largest member of the gull family',
#  'The great blue heron (Ardea herodias) is a large wading bird in the heron family Ardeidae, common near the shores of open water and in wetlands over most of North America and Central America, as well as far northwestern South America, the Caribbean and the Galápagos Islands',
#  'The great blue turaco (Corythaeola cristata) is a bird species of the  family Musophagidae',
#  'The great bowerbird (Chlamydera nuchalis) is a common and conspicuous resident of northern Australia, from the area around Broome across the Top End to Cape York Peninsula and as far south as Mount Isa',
#  'The great bustard (Otis tarda) is a bird in the bustard family, and it is the only living member of the genus Otis',
#  'Pelecanus carbo Linnaeus,\xa01758',
#  'Turdus crinitus Linnaeus,\xa01758',
#  'Colymbus cristatus Linnaeus,\xa01758',
#  'The great cuckoo-dove (Reinwardtoena reinwardti) is a species of bird in the family Columbidae',
#  'The great curassow (Crax rubra) is a large, pheasant-like bird from the Neotropical rainforests, its range extending from eastern Mexico, through Central America to western Colombia and northwestern Ecuador',
#  'Aerornis senex[2]',
#  'The great eared nightjar (Lyncornis macrotis) is a species of nightjar in the family Caprimulgidae',
#  'The great egret (Ardea alba), also known as the common egret, large egret, or (in the Old World) great white egret[2] or great white heron[3][4][5] is a large, widely distributed egret',
#  'See text',
#  'Pelecanus minor Gmelin 1789\nTachypetes palmerstoni',
#  'Podicephorus major (Boddaert 1783) Bochenski 1994',
#  'Ara ambiguus ambiguusAra ambiguus guayaquilensis',
#  "The great grey owl (Strix nebulosa) (also great gray owl in American English) is a very large owl, documented as the world's largest species of owl by length",
#  'See text',
#  'The great hanging parrot (Loriculus stigmatus), also called Celebes hanging parrot, Sulawesi hanging parrot and maroon-rumped hanging parrot, is a species of parrot in the family Psittaculidae',
#  'Buceros homrai[2]Dichoceros bicornisBuceros cavatusHomraius bicornisDichoceros cavatusBuceros cristatus',
#  'About 12, see text',
#  'Haemophila pulchra (protonym)',
#  'Choriotis nigricepsEupodotis edwardsiOtis nigriceps',
#  'The great iora (Aegithina lafresnayei) is a species of bird in the family Aegithinidae',
#  'The great jacamar (Jacamerops aureus) is a species of bird in the family Galbulidae',
#  'The great kiskadee (Pitangus sulphuratus), called bem-te-vi in Brazil and benteveo in Argentina, is a passerine bird in the tyrant flycatcher family Tyrannidae',
#  'The great knot (Calidris tenuirostris) is a small wader',
#  'The great lizard cuckoo (Coccyzus merlini) is a species of bird in the tribe Phaenicophaeini, subfamily Cuculinae of the cuckoo family Cuculidae',
#  'The great myna (Acridotheres grandis), also known as the white-vented myna, is a species of starling in the family Sturnidae',
#  'The Great Nicobar serpent eagle (Spilornis klossi), also known as the South Nicobar serpent eagle, is a species of bird of prey in the family Accipitridae',
#  'Conostoma oemodium',
#  'The great potoo (Nyctibius grandis) is the largest potoo species and is widely distributed in Central and South America',
#  'Turdus arundinaceus Linnaeus,\xa01758Acrocephalus turdoïdes[2]',
#  'The great rosefinch (Carpodacus rubicilla) is a species of finch in the family Fringillidae',
#  'The great rufous woodcreeper (Xiphocolaptes major) is a species of bird in the Dendrocolaptinae subfamily, the woodcreepers',
#  "Temminck's sapphirewing Pterophanes temmincki[3]",
#  'The great shearwater (Ardenna gravis) is a large shearwater in the seabird family Procellariidae',
#  'The great shortwing (Heinrichia calligyna) is a species of bird in the family Muscicapidae, and the only member of its genus',
#  'The great shrike-tyrant (Agriornis lividus) is a species of bird in the family Tyrannidae',
#  'Catharacta skua',
#  'The great slaty woodpecker (Mulleripicus pulverulentus) is a species of bird in the family Picidae',
#  'Capella media (Latham, 1787)\nGallinago major\nScolopax media Latham, 1787',
#  'The great sparrow (Passer motitensis), also known as the southern rufous sparrow, is found in southern Africa in dry, wooded savannah and towns',
#  'Siptornopsis hypochondriaca',
#  'Cuculus glandarius Linnaeus,\xa01758',
#  'The great spotted kiwi, great grey kiwi[2] or roroa (Apteryx haastii) is a species of kiwi endemic to the South Island of New Zealand',
#  'The great spotted woodpecker (Dendrocopos major) is a medium-sized woodpecker with pied black and white plumage and a red patch on the lower belly',
#  'The great stone-curlew or  great thick-knee (Esacus recurvirostris) is a large wader which is a resident breeder in tropical southern Asia from India, Pakistan, Sri Lanka, Bangladesh into South-east Asia',
#  'The great swallow-tailed swift (Panyptila sanctihieronymi) is a species of bird in subfamily Apodinae of the swift family Apodidae',
#  'The great thrush (Turdus fuscater) is a species of bird in the family Turdidae',
#  'See text',
#  'The great tit (Parus major) is a passerine bird in the tit family Paridae',
#  'The great white pelican (Pelecanus onocrotalus) also known as the eastern white pelican, rosy pelican or white pelican is a bird in the pelican family',
#  'The great woodswallow (Artamus maximus), also known as the greater woodswallow, giant woodswallow or New Guinea woodswallow is a species of bird in the family Artamidae',
#  'The great xenops (Megaxenops parnaguae) is a furnariid bird, which is endemic to the Caatinga region of north-eastern Brazil',
#  'The great-billed hermit (Phaethornis malaris) is a species of hummingbird in the family Trochilidae',
#  'The great-billed heron (Ardea sumatrana) is a wading bird of the heron family, resident from southeast Asia to Papua New Guinea and Australia',
#  'The great-billed kingfisher or black-billed kingfisher (Pelargopsis melanorhyncha) is a species of bird in the subfamily Halcyoninae',
#  'The great-billed mannikin or grand munia (Lonchura grandis) is a species of estrildid finch found in northern and eastern New Guinea',
#  'The great-billed parrot (Tanygnathus megalorynchos) also known as Moluccan parrot or island parrot, is a medium-sized, approximately 38\xa0cm long, green parrot with a massive red bill, cream iris, blackish shoulders, olive green back, pale blue rump and yellowish green underparts',
#  'Oryzoborus maximiliani',
#  'Leptoptilus argalaArdea dubiaLeptoptilus giganteus[2]Argala migratoria[3]',
#  'The greater ani (Crotophaga major) is a bird in the cuckoo family',
#  'The Greater Antillean bullfinch (Melopyrrha violacea) is a species of bird in the family Thraupidae',
#  'See text',
#  'The Greater Antillean grackle (Quiscalus niger) is a grackle found throughout the Greater Antilles, as well as smaller nearby islands',
#  'The greater bird-of-paradise (Paradisaea apoda) is a bird-of-paradise in the genus Paradisaea',
#  'The greater blue-eared starling or greater blue-eared glossy-starling (Lamprotornis chalybaeus) is a bird that breeds from Senegal east to Ethiopia and south through eastern Africa to northeastern South Africa and Angola',
#  'The greater coucal or crow pheasant (Centropus sinensis), is a large non-parasitic member of the cuckoo order of birds, the Cuculiformes',
#  'Sterna bergii Lichtenstein, 1823',
#  'The greater double-collared sunbird (Cinnyris afer) (formerly placed in the genus Nectarinia), is a small bird in the sunbird family',
#  'The greater flameback (Chrysocolaptes guttacristatus) also known as greater goldenback, large golden-backed woodpecker is a woodpecker species',
#  'The greater flamingo (Phoenicopterus roseus) is the most widespread and largest species of the flamingo family',
#  'The greater flowerpiercer (Diglossa major) is a species of bird in the family Thraupidae',
#  'The greater green leafbird (Chloropsis sonnerati) is a species of bird in the family Chloropseidae',
#  'The greater ground robin (Amalocichla sclateriana) is a species of bird in the family Petroicidae',
#  'The greater honeyguide (Indicator indicator) is a bird in the family Indicatoridae, paleotropical near passerine birds related to the woodpeckers',
#  'See text',
#  'The greater kestrel (Falco rupicoloides) or white-eyed kestrel, is a bird of prey belonging to the falcon family Falconidae',
#  'The greater lophorina (Lophorina superba), also known as superb bird-of-paradise or greater superb bird-of-paradise, is a species of the Paradisaeidae (bird-of-paradise) family',
#  'Melampitta gigantea',
#  'Ianthocincla pectoralisGarrulax pectoralis',
#  'The greater painted-snipe (Rostratula benghalensis) is a species of wader in the family Rostratulidae',
#  'The greater pewee (Contopus pertinax) is a passerine and is in the tyrant flycatcher group',
#  'T',
#  'The greater racket-tailed drongo (Dicrurus paradiseus) is a medium-sized Asian bird which is distinctive in having elongated outer tail feathers with webbing restricted to the tips',
#  'R',
#  'The greater roadrunner (Geococcyx californianus) is a long-legged bird in the cuckoo family, Cuculidae, from the Aridoamerica region in the Southwestern United States and Mexico',
#  'The greater sage-grouse (Centrocercus urophasianus), also known as the sagehen, is the largest grouse (a type of bird) in North America',
#  'The greater sand plover (Charadrius leschenaultii) is a small wader in the plover family of birds',
#  'A',
#  'Campylorhamphus pucherani',
#  'See text',
#  'T',
#  'Aquila clanga',
#  'Hirundo cucullata',
#  'The greater swamp warbler (Acrocephalus rufescens) is a species of Old World warbler in the family Acrocephalidae',
#  'The greater thornbird (Phacellodomus ruber) is a species of bird in the family Furnariidae',
#  'The greater vasa parrot (Coracopsis vasa) is one of two species of vasa parrot, the other being the lesser vasa parrot C',
#  'The greater wagtail-tyrant (Stigmatura budytoides) is a South American species of bird in the family Tyrannidae',
#  'Branta albifrons Scopoli, 1769',
#  'The greater yellow finch (Sicalis auriventris) is a species of bird in the family Thraupidae',
#  'The greater yellow-headed vulture (Cathartes melambrotus), also known as the forest vulture,[3] is a species of bird in the New World vulture family Cathartidae',
#  'Totanus melanoleucus',
#  'Picus flavinucha',
#  'The great-tailed grackle or Mexican grackle (Quiscalus mexicanus) is a medium-sized, highly social passerine bird native to North and South America',
#  'The great-winged petrel (Pterodroma macroptera) is a petrel',
#  'The green araçari (Pteroglossus viridis), is a toucan, a near-passerine bird',
#  'Stictospiza formosaEstrilda formosa Sporaeginthus formosus',
#  'The green-backed twinspot or green twinspot (Mandingoa nitidula) is an estrildid finch found in many parts of Sub-Saharan Africa',
#  'The green barbet (Stactolaema olivacea) is a species of bird in the Lybiidae family (African barbets)',
#  'Green bee-eater has been split into the following species:',
#  'The green broadbill (Calyptomena viridis) also known as the lesser green broadbill is a small bird in the family Calyptomenidae',
#  'The green catbird (Ailuroedus crassirostris) is a species of bowerbird found in subtropical forests along the east coast of Australia, from southeastern Queensland to southern New South Wales',
#  'The green cochoa (Cochoa viridis) is a bird species that was variously placed with the thrushes of family Turdidae or the related Muscicapidae (Old World flycatchers)',
# ...
#  'Phyllastrephus cinereiceps (Sharpe, 1881)Bernieria cinereiceps',
#  'Seicercus tephrocephalus',
#  'Piculus auricularis (Salvin & Godman, 1889)',
#  'The grey-crowned yellowthroat (Geothlypis poliocephala) is a species of bird in the family Parulidae',
#  'The grey-eared brushfinch or black-faced brushfinch (Atlapetes melanolaemus) is a species of bird in the family Passerellidae',
#  'The grey-eared honeyeater (Lichmera incana), also known as the dark-brown honeyeater, is a passerine bird of the honeyeater family which is found in Vanuatu and New Caledonia in the south-west Pacific',
#  'The grey-eyed bulbul (Iole propinqua) is a species of songbird in the bulbul family, Pycnonotidae',
#  'The grey-eyed greenlet (Hylophilus amaurocephalus) is a species of bird in the family Vireonidae',
#  'The grey-faced buzzard (Butastur indicus) is an Asian bird of prey',
#  'The grey-faced petrel (Pterodroma gouldi) is a petrel endemic to the North Island of New Zealand',
#  'The grey-faced tit-babbler (Mixornis kelleyi) is a species of bird in the family Timaliidae',
#  'The grey-flanked cinclodes (Cinclodes oustaleti) is a species of bird in the family Furnariidae',
#  'The grey-fronted dove (Leptotila rufaxilla) is a large New World tropical dove',
#  'The grey-fronted green pigeon (Treron affinis) is a pigeon in the genus Treron',
#  'The grey-fronted honeyeater (Ptilotula plumula) is a species of bird in the family Meliphagidae',
#  'The grey-fronted quail-dove (Geotrygon caniceps) is a species of bird in the family Columbidae',
#  'The grey-green fruit dove (Ptilinopus purpuratus) is a species of bird in the family Columbidae',
#  'The grey-green scrubwren (Aethomyias arfakianus) is a species of bird in the family Acanthizidae',
#  'Diomedea chrysostoma',
#  'Myrmeciza griseiceps',
#  'The grey-headed babbler (Stachyris poliocephala) is a species of bird in the family Timaliidae',
#  'The grey-headed batis (Batis orientalis) is a species of bird in the wattle-eyes family,  Platysteiridae, it was previously classified with the Old World flycatchers in the  family Muscicapidae',
#  'The grey-headed bristlebill (Bleda canicapillus) is a species of songbird in the bulbul family, Pycnonotidae',
#  'The grey-headed broadbill (Smithornis sharpei) is a species of bird in the family Calyptomenidae',
#  'The grey-headed bulbul (Brachypodius priocephalus) is a member of the bulbul family, Pycnonotidae',
#  'The grey-headed bullfinch (Pyrrhula erythaca) is a species of finch in the family Fringillidae',
#  'The grey-headed bushshrike (Malaconotus blanchoti), colloquially known as the ghostbird,[2] is a species of passerine bird in the family Malaconotidae',
#  'Platyrhynchus ceylonensis (protonym)',
#  'The grey-headed chachalaca (Ortalis cinereiceps) is a member of an ancient group of birds of the family Cracidae, which includes chachalacas, guans, and curassows',
#  'Parus cinctusPoecile cincta',
#  'Coracina schisticeps',
#  'The grey-headed dove (Leptotila plumbeiceps) is a large New World dove',
#  'The grey-headed fish eagle (Haliaeetus ichthyaetus) is a fish-eating bird of prey from South East Asia',
#  'The grey-headed fruit dove (Ptilinopus hyogastrus) is a species of bird in the family Columbidae',
#  'The grey-headed goshawk (Accipiter poliocephalus) is a lightly built, medium-sized bird of prey in the family Accipitridae',
#  'The grey-headed greenbul (Phyllastrephus poliocephalus), or grey-headed yellow-bellied greenbul, is a species of songbird in the bulbul family, Pycnonotidae',
#  'Larus cirrocephalus',
#  'Lichenostomus keartlandi',
#  'The grey-headed imperial pigeon (Ducula radiata) is a species of bird in the family Columbidae',
#  'The grey-headed kingfisher (Halcyon leucocephala) is a species of kingfisher that has a wide distribution from the Cape Verde Islands off the north-west coast of Africa to Mauritania, Senegal and Gambia, east to Ethiopia, Somalia and southern Arabia and south to South Africa',
#  'Hoplopterus cinereus (Blyth, 1842)\nMicrosarcops cinereus (Blyth, 1842)\nPluvianus cinereus Blyth, 1842',
#  'The gray-headed lovebird or Madagascar lovebird (Agapornis canus) is a small species of parrot of the lovebird genus',
#  'The grey-headed mannikin or grey-headed munia (Lonchura caniceps) is a species of estrildid finch, native to the Papuan Peninsula',
#  'The grey-headed nigrita (Nigrita canicapillus) is a common species of estrildid finch found in Africa',
#  'The grey-headed oliveback (Delacourella capistrata), also known as the white-cheeked oliveback, is a common species of estrildid finch found in Africa',
#  'The grey-headed parakeet (Psittacula finschii) is closely related to the slaty-headed parakeet which together form a super-species',
#  'The grey-headed parrotbill (Psittiparus gularis) is a parrotbill in the family Sylviidae and is found in eastern Asia from the Himalayas to Indochina and Hainan',
#  'The grey-headed piprites (Piprites griseiceps) is a species of bird which traditionally has been placed in the family Tyrannidae',
#  'The grey-headed robin (Heteromyias cinereifrons) is a species of bird in the family Petroicidae',
#  'Odontospiza griseicapillaLonchura griseicapilla',
#  'The grey-headed spinetail (Cranioleuca semicinerea) is a species of bird in the family Furnariidae',
#  'Anthreptes axillaris\nAnthreptes fraseri axillaris\nDeleornis fraseri axillaris',
#  'Porphyrio porphyrio poliocephalus',
#  'The grey-headed tanager (Eucometis penicillata) is a widely distributed species of small Neotropical bird in the tanager family Thraupidae',
#  'Myiothlypis griseiceps',
#  'The grey-headed woodpecker (Picus canus), also known as the grey-faced woodpecker, is a Eurasian member of the woodpecker family, Picidae',
#  'The grey-hooded attila (Attila rufus) is a species of bird in the family Tyrannidae, the tyrant flycatchers',
#  'The grey-hooded bush tanager (Cnemoscopus rubrirostris) is a species of South American bird in the tanager family Thraupidae',
#  'The grey-hooded flycatcher (Mionectes rufiventris) is a species of bird in the family Tyrannidae',
#  'Alcippe cinereiceps',
#  "Bolborhynchus aymara (d'Orbigny, 1839)",
#  'Paradoxornis zappeyi',
#  'The grey-hooded sierra finch (Phrygilus gayi) is a species of bird in the family Thraupidae',
#  'Aethopyga primigenius (lapsus)',
#  'Seicercus xanthoschistos G',
#  'The grey-hooded white-eye (Heleia pinaiae), also known as the grey-hooded ibon, is a species of bird in the family Zosteropidae',
#  'The greyish eagle-owl or vermiculated eagle-owl (Bubo cinerascens) is a rather large owl of the northern part of sub-Saharan Africa',
#  'The greyish miner (Geositta maritima) is a species of bird in the family Furnariidae',
#  'The greyish mourner (Rhytipterna simplex) is a species of bird in the family Tyrannidae',
#  'The greyish piculet (Picumnus granadensis) is a species of bird in subfamily Picumninae of the woodpecker family Picidae',
#  'Greyish saltator has been split into three species:',
#  'The greylag goose or graylag goose (Anser anser) is a species of large goose in the waterfowl family Anatidae and the type species of the genus Anser',
#  'The grey-legged tinamou (Crypturellus duidae), alternatively, the gray-legged tinamou, is a small ground-dwelling bird endemic to the neotropics',
#  'The grey-mantled wren (Odontorchilus branickii) is a species of bird in the family Troglodytidae',
#  'The grey-naped antpitta (Grallaria griseonucha) is a species of bird in the family Grallariidae',
#  'The grey-necked bunting (Emberiza buchanani), sometimes referred to as grey-hooded bunting (a name also in use for chestnut-eared bunting[3]) is a species of bird in the family Emberizidae',
#  'The grey-necked rockfowl (Picathartes oreas) is a medium-sized bird in the family Picathartidae with a long neck and tail',
#  'The grey-olive greenbul (Phyllastrephus cerviniventris), or grey-olive bulbul, is a species of songbird in the bulbul family, Pycnonotidae',
#  'The grey-rumped swallow (Pseudhirundo griseopyga) is a species of swallow',
#  'Acanthylis cinereiventris[2]',
#  'The grey-rumped swiftlet (Collocalia marginata) or grey-rumped swiftlet, is a small bird in the swift family Apodidae',
#  'The grey-rumped treeswift (Hemiprocne longipennis) is a species of bird in the Hemiprocnidae family',
#  'The grey-sided bush warbler (Cettia brunnifrons) is a species of bush warbler (family Cettiidae)',
#  'The grey-sided flowerpecker (Dicaeum celebicum) is a species of bird in the family Dicaeidae',
#  'Ianthocincla caerulataGarrulax caerulatus',
#  'The grey-sided scimitar babbler (Erythrogenys swinhoei) is a species of bird in the family Timaliidae',
#  'The grey-sided thrush (Turdus feae) is a species of bird in the thrush family, Turdidae',
#  'The grey-streaked flycatcher or grey-spotted flycatcher (Muscicapa griseisticta) is a small passerine bird breeding in the eastern Palearctic belonging to the genus Muscicapa in the Old World flycatcher family Muscicapidae',
#  'The grey-streaked honeyeater (Ptiloprora perstriata), also known as the black-backed honeyeater, is a species of bird in the family Meliphagidae',
#  'Francolinus griseostriatus protonym',
#  'The grey-tailed mountaingem (Lampornis cinereicauda), also variously spelled gray-tailed mountaingem, grey-tailed mountain-gem, or gray-tailed mountain-gem, is a species of hummingbird in tribe Lampornithini of subfamily Trochilinae',
#  'Lathria subalaris (P',
#  'Heteroscelus brevipes\nHeterosceles brevipes\nHeteractitis brevipes',
#  'The grey-throated babbler (Stachyris nigriceps) is a species of passerine bird in the Old World babbler family Timaliidae',
#  'The grey-throated barbet (Gymnobucco bonapartei) is a species of bird in the Lybiidae family (African barbets)',
#  'The grey-throated chat (Granatellus sallaei) is a species of bird in the family Cardinalidae, the cardinals or cardinal grosbeaks',
#  'The grey-throated leaftosser (Sclerurus albigularis) is a species of bird in the family Furnariidae',
#  'The grey-throated martin or Asian plain martin[1] (Riparia chinensis) is a small passerine bird in the swallow family',
#  'The grey-throated rail (Canirallus oculeus) is a species of bird in the family Rallidae, the only member of the genus Canirallus',
#  'Anthreptes malacensis griseigularis',
#  'The grey-throated tit-flycatcher (Myioparus griseigularis) is a species of bird in the family Muscicapidae',
#  'Basileuterus cinereicollis',
#  'Zosterops ugiensis',
#  'The grey-winged blackbird (Turdus boulboul) is a species of bird in the thrush family',
#  'The grey-winged cotinga (Lipaugus conditus) is a species of bird in the family Cotingidae',
#  'Francolinus africanusScleroptila africanus',
#  'The grey-winged Inca finch (Incaspiza ortizi) is a species of bird traditionally placed in the family Emberizidae, but it may be more closely related to the Thraupidae',
#  'The grey-winged robin-chat or grey-winged akalat (Sheppardia polioptera) is a bird in the family Muscicapidae',
#  'The grey-winged trumpeter (Psophia crepitans) is a member of a small family of birds, the Psophiidae',
#  'Redirect to:',
#  "Grimwood's longclaw (Macronyx grimwoodi) is a species of bird in the family Motacillidae",
#  'The groove-billed ani (Crotophaga sulcirostris) is a tropical bird in the cuckoo family with a long tail and a large, curved beak',
#  'See text',
#  'Lanius dubium Latham, 1801',
#  'The ground cuckoo-shrike (Coracina maxima) is an uncommon bird species endemic to Australia, occurring mainly in open woodland and arid grasslands throughout inland Australia,[2] but also occasionally in areas on the east coast',
#  'Podoces humilis Hume, 1871Parus humilis',
#  'The ground woodpecker (Geocolaptes olivaceus) is one of only three ground-dwelling woodpeckers in the world (the others are the Andean and campo flickers)',
#  'Psophocichla litsitsirupa Cabanis, 1860\nPsophocichla litsipsirupa[2]',
#  'The growling riflebird (Ptiloris intercedens), also known as the eastern riflebird, is a medium-sized passerine bird of the family Paradisaeidae',
#  'The Guadalcanal dwarf kingfisher (Ceyx nigromaxilla), is a species of bird in the family Alcedinidae that is endemic to Guadalcanal Island',
#  'The Guadalcanal honeyeater (Guadalcanaria inexpectata) is a species of bird in the family Meliphagidae',
#  'The Guadalcanal thrush (Zoothera turipavae) is a species of bird in the family Turdidae',
#  'Junco hyemalis insularis Ridgway, 1876',
#  "The Guadalupe murrelet (Synthliboramphus hypoleucus) or Xantus' Murrelet is a small seabird found in the California Current system in the Pacific Ocean",
#  'Oceanodroma leucorhoa macrodactyla W',
#  '•  Picus herminieri (Lesson, 1830)\n\xa0•  Linneopicus herminieri (Lesson, 1830)',
#  'The guaiabero (Bolbopsittacus lunulatus) is a species of parrot in the family Psittaculidae, belonging to the  monotypic genus Bolbopsittacus[2] and closely related to the lovebirds (Agapornis) and hanging parrots (Loriculus)',
#  'The Guaiquinima whitestart (Myioborus cardonai), also known as the Guaiquinima redstart, saffron-breasted whitestart or saffron-breasted redstart, is a species of bird in the family Parulidae',
#  'The Guam flycatcher (Myiagra freycineti), or Guam broadbill, is an extinct species of bird in the family Monarchidae formerly endemic to Guam',
#  'The Guam kingfisher (Todiramphus cinnamominus) is a species of kingfisher from the United States Territory of Guam',
#  "The Guam rail (Hypotaenidia owstoni) is a species of flightless bird, endemic to the United States territory of Guam, where it is known locally as the Ko'ko' bird",
#  'Phalacrocorax bougainvilliiPhalacrocorax bougainvilliorumLeucocarbo bougainvillii',
#  'The Guatemalan pygmy owl (Glaucidium cobanense) is a small "typical owl" in subfamily Surniinae',
#  'The Guatemalan tyrannulet or paltry tyrannulet (Zimmerius vilissimus), is a very small passerine bird in the tyrant flycatcher family',
#  'The Guayaquil woodpecker (Campephilus gayaquilensis) is a species of bird in subfamily Picinae of the woodpecker family Picidae',
#  'Pipra rupicola Linnaeus,\xa01766',
#  'The Guianan gnatcatcher (Polioptila guianensis) is a species of bird in the family Polioptilidae',
#  'The Guianan puffbird (Notharchus macrorhynchos) is a species of bird in the family Bucconidae, the puffbirds, nunlets, and nunbirds',
#  'The Guianan red cotinga (Phoenicircus carnifex) is a species of bird in the family Cotingidae, the cotingas',
#  'The Guianan schiffornis or olivaceous schiffornis (Schiffornis olivacea), is a species of Neotropical bird',
#  'Sitta surinamensis',
#  'The Guianan toucanet, or Guyana toucanet (Selenidera piperivora) is a near-passerine bird in the toucan family Ramphastidae',
#  'The Guianan trogon (Trogon violaceus), is a near passerine bird in the trogon and quetzal family Trogonidae',
#  'Zimmerius gracilipes acer',
#  'Hypocnemis cantator cantator',
#  'The Guianan woodcreeper (Lepidocolaptes albolineatus) is a species of bird in the subfamily Dendrocolaptinae',
#  'Cuculus persa Linnaeus,\xa01758',
#  'The guira cuckoo (Guira guira) is a gregarious bird found widely in open and semi-open habitats of northeastern, eastern and southern Brazil, Uruguay, Paraguay, Bolivia, and northeastern Argentina',
#  'Motacilla guira (protonym)',
#  "Güldenstädt's redstart (Phoenicurus erythrogastrus) also sometimes called the white-winged redstart, is a species of bird in the genus Phoenicurus, family Muscicapidae",
#  'Sterna nilotica',
#  'Accipiter gundlachii Lawrence, 1860 [orth',
#  'Centrocercus urophasianoides',
#  "Gurney's eagle (Aquila gurneyi) is a large eagle in the family Accipitridae",
#  "Gurney's pitta (Hydrornis gurneyi) (Thai: นกแต้วแร้วท้องดำ) is a medium-sized passerine bird",
#  "Gurney's sugarbird (Promerops gurneyi) is a medium-sized passerine endemic to the mid- and high-altitude grassland velds in southern Africa",
#  'Anabazenops guttulatus',
#  'The gyrfalcon (/ˈdʒɜːrˌfɔː(l)kən/ or /ˈdʒɜːrˌfælkən/)[3] (Falco rusticolus), the largest of the falcon species, is a bird of prey']

# %%
import openai

openai.api_key = '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'

models = openai.Model.list()

# %%
from tqdm import tqdm
r=[]

# %%
for sentence in tqdm(obj):
  response = openai.Completion.create(
    model="text-davinci-003",
    prompt=f"Given sentence \"{sentence}\" what is the bird, its alternate names and scientific name in the sentence? Give the output in JSON format.",
    temperature=0,
    max_tokens=500,
    top_p=1,
    frequency_penalty=0,
    presence_penalty=0
  )
  r.append(response)
# Out:
# 100%|██████████| 894/894 [28:03<00:00,  1.88s/it]

# %%
r[893].choices[0].text.replace
# Out:
# '\n\n{\n  "bird": "gyrfalcon",\n  "alternate_names": ["Falco rusticolus"],\n  "scientific_name": "Falco rusticolus"\n}'

# %%
t = [x.choices[0].text for x in r]

# %%
t
# Out:
# ['\n\n{\n  "bird": "Iago sparrow",\n  "alternate_names": ["Cape Verde", "rufous-backed sparrow"],\n  "scientific_name": "Passer iagoensis"\n}',
#  '\n\n{\n    "bird": "Ibadan malimbe",\n    "alternate_names": ["Malimbus ibadanensis"],\n    "scientific_name": "Ploceidae"\n}',
#  '\n\n{\n    "bird": "Ibera seedeater",\n    "alternate_names": ["Sporophila iberaensis"],\n    "scientific_name": "Thraupidae"\n}',
#  '\n\n{\n  "bird": "Iberian chiffchaff",\n  "alternate_names": [],\n  "scientific_name": "Phylloscopus ibericus"\n}',
#  '\n\n{\n  "bird": "Iberian green woodpecker",\n  "alternate_names": "Picus sharpei",\n  "scientific_name": "Picus sharpei"\n}',
#  '\n\n{\n    "bird": "None",\n    "alternate_names": "None",\n    "scientific_name": "None"\n}',
#  '\n\n{\n  "bird": "Cyanopica cyanus",\n  "alternate_names": ["cooki"],\n  "scientific_name": "Cyanopica cyana"\n}',
#  '\n\n{\n    "bird": "Clorhynchus strophiatus",\n    "alternate_names": [],\n    "scientific_name": "Hodgson, 1835"\n}',
#  '\n\n{\n    "bird": "Iceland gull",\n    "alternate_names": "Larus glaucoides",\n    "scientific_name": "Larus glaucoides"\n}',
#  '\n\n{\n    "bird": "Icterine Greenbul",\n    "alternate_names": "Phyllastrephus icterinus",\n    "scientific_name": "Pycnonotidae"\n}',
#  '\n\n{\n  "bird": "Icterine Warbler",\n  "alternate_names": ["Hippolais icterina"],\n  "scientific_name": "Hippolais icterina"\n}',
#  '\n\n{\n    "bird": "Ihering\'s antwren",\n    "alternate_names": "Myrmotherula iheringi",\n    "scientific_name": "Thamnophilidae"\n}',
#  '\n\n{\n  "bird": "Acanthopneuste ijimae",\n  "alternate_names": ["Acanthopneuste occipitalis ijimae", "Phylloscopus coronatus ijimae", "Phylloscopus tenellipes ijimae"],\n  "scientific_name": "Acanthopneuste ijimae (protonym)"\n}',
#  '\n\n{\n    "bird": "Hypocnemis cantator",\n    "alternate_names": "Flavescens",\n    "scientific_name": "Hypocnemis cantator flavescens"\n}',
#  '\n\n{\n  "bird": "imitator goshawk or imitator sparrowhawk",\n  "alternate_names": ["Accipiter imitator"],\n  "scientific_name": "Accipiter imitator"\n}',
#  '\n\n{\n    "bird": "Imperial Amazon",\n    "alternate_names": ["Sisserou", "Sisserou Parrot"],\n    "scientific_name": "Amazona imperialis"\n}',
#  '\n\n{\n  "bird": "Imperial Shag",\n  "alternate_names": ["Imperial Cormorant"],\n  "scientific_name": "Leucocarbo atriceps"\n}',
#  '\n\n{\n    "bird": "Imperial Snipe",\n    "alternate_names": [],\n    "scientific_name": "Gallinago imperialis"\n}',
#  '\n\n{\n  "bird": "The imperial woodpecker",\n  "alternate_names": "Campephilus imperialis",\n  "scientific_name": "Campephilus imperialis"\n}',
#  '\n\n{\n    "bird": "Inaccessible Island finch",\n    "alternate_names": "Inaccessible bunting",\n    "scientific_name": "Nesospiza acunhae",\n    "family": "Thraupidae (formerly in Emberizidae)"\n}',
#  '\n\n{\n    "bird": "Inaccessible Island rail",\n    "alternate_names": [],\n    "scientific_name": "Laterallus rogersi"\n}',
#  '\n\n{\n    "bird": "Nesophlox evelynae lyrura",\n    "alternate_names": null,\n    "scientific_name": "Nesophlox evelynae lyrura"\n}',
#  '\n\n{\n  "bird": "Inambari gnatcatcher",\n  "alternate_names": "Polioptila attenboroughi",\n  "scientific_name": "Polioptilidae"\n}',
#  '\n\n{\n  "bird": "Inambari woodcreeper",\n  "alternate_names": [],\n  "scientific_name": "Lepidocolaptes fatimalimae"\n}',
#  '\n\n{\n    "bird": "Scardafella inca",\n    "alternate_names": null,\n    "scientific_name": "Scardafella inca"\n}',
#  '\n\n{\n    "bird": "Inca flycatcher",\n    "alternate_names": [],\n    "scientific_name": "Leptopogon taczanowskii"\n}',
#  '\n\n{\n  "bird": "Inca jay",\n  "alternate_names": "querrequerre",\n  "scientific_name": "Cyanocorax yncas"\n}',
#  '\n\n{\n  "bird": "Inca Tern",\n  "alternate_names": "Larosterna inca",\n  "scientific_name": "Sterninae of the family Laridae"\n}',
#  '\n\n{\n    "bird": "Thryothorus eisenmanni",\n    "alternate_names": "none",\n    "scientific_name": "Thryothorus eisenmanni"\n}',
#  '\n\n{\n  "bird": "Indian blackbird",\n  "alternate_names": [],\n  "scientific_name": "Turdus simillimus"\n}',
#  '\n\n{\n    "bird": "Parus aplonotus",\n    "alternate_names": "none",\n    "scientific_name": "Parus aplonotus"\n}',
#  '\n\n{\n  "bird": "Erithacus brunneus",\n  "alternate_names": ["Larvivora brunnea", "Tarsiger brunnea", "Luscinia brunnea"],\n  "scientific_name": "Erithacus brunneus"\n}',
#  '\n\n{\n  "bird": "Indian bush lark",\n  "alternate_names": "Mirafra erythroptera",\n  "scientific_name": "Alaudidae"\n}',
#  '\n\n{\n  "bird": "Indian cormorant",\n  "alternate_names": "Indian shag",\n  "scientific_name": "Phalacrocorax fuscicollis"\n}',
#  '\n\n{\n    "bird": "None",\n    "alternate_names": "None",\n    "scientific_name": "None"\n}',
#  '\n\n{\n  "bird": "Indian cuckoo",\n  "alternate_names": "Cuculus micropterus",\n  "scientific_name": "Cuculiformes"\n}',
#  '\n\n{\n  "bird": "Urrua bengalensis",\n  "alternate_names": [],\n  "scientific_name": "Urrua bengalensis[3]"\n}',
#  '\n\n{\n  "bird": "Indian golden oriole",\n  "alternate_names": "Oriolus kundoo",\n  "scientific_name": "Oriolus kundoo"\n}',
#  '\n\n{\n  "bird": "Indian grassbird",\n  "alternate_names": "Graminicola bengalensis",\n  "scientific_name": "Pellorneidae"\n}',
#  '\n\n{\n  "bird": "Lophoceros birostris",\n  "alternate_names": ["Tockus birostris", "Meniceros birostris"],\n  "scientific_name": "Ocyceros ginginianus"\n}',
#  '\n\n{\n    "bird": "Corvus macrorhynchos culminatus",\n    "alternate_names": "",\n    "scientific_name": "Corvus macrorhynchos culminatus"\n}',
#  '\n\n{\n  "bird": "Indian nightjar",\n  "alternate_names": "none",\n  "scientific_name": "Caprimulgus asiaticus"\n}',
#  '\n\n{\n    "bird": "Indian nuthatch",\n    "alternate_names": [],\n    "scientific_name": "Sitta castanea"\n}',
#  '\n\n{\n    "bird": "See text",\n    "alternate_names": "None",\n    "scientific_name": "None"\n}',
#  '\n\n{\n  "bird": "Indian peafowl",\n  "alternate_names": ["common peafowl", "blue peafowl"],\n  "scientific_name": "Pavo cristatus"\n}',
#  '\n\n{\n  "bird": "Corvus brachyurus",\n  "alternate_names": [],\n  "scientific_name": "Linnaeus, 1766[2]"\n}',
#  '\n\n{\n    "bird": "Ardeola leucoptera",\n    "alternate_names": "Indian Pond Heron, Paddybird, Ricebird",\n    "scientific_name": "Ardeola leucoptera"\n}',
#  '\n\n{\n    "bird": "Indian robin",\n    "alternate_names": "Copsychus fulicatus",\n    "scientific_name": "Muscicapidae"\n}',
#  '\n\n{\n  "bird": "Corvus benghalensis",\n  "alternate_names": [],\n  "scientific_name": "Linnaeus, 1758"\n}',
#  '\n\n{\n    "bird": "P",\n    "alternate_names": [],\n    "scientific_name": ""\n}',
#  '\n\n{\n  "bird": "Indian scops owl",\n  "alternate_names": "Otus bakkamoena",\n  "scientific_name": "Otus bakkamoena"\n}',
#  '\n\n{\n  "bird": "Indian silverbill or white-throated munia",\n  "alternate_names": ["Euodice malabarica", "African silverbill", "Euodice cantans"],\n  "scientific_name": "Euodice malabarica"\n}',
#  '\n\n{\n  "bird": "Rhynchops albicollis",\n  "alternate_names": "White-throated Skimmer, White-throated Needletail",\n  "scientific_name": "Rhynchops albicollis"\n}',
#  '\n\n{\n    "bird": "Anas poikilorhynchus",\n    "alternate_names": "None",\n    "scientific_name": "Anas poikilorhynchus"\n}',
#  '\n\n{\n  "bird": "Indian spotted creeper",\n  "alternate_names": ["Salpornis spilonota"],\n  "scientific_name": "Salpornithinae"\n}',
#  '\n\n{\n    "bird": "Aquila hastata",\n    "alternate_names": "Hastate Eagle, Booted Eagle",\n    "scientific_name": "Hieraaetus pennatus"\n}',
#  '\n\n{\n    "bird": "Indian stone-curlew or Indian thick-knee",\n    "scientific_name": "Burhinus indicus",\n    "family": "Burhinidae"\n}',
#  '\n\n{\n    "bird": "Indian swiftlet",\n    "alternate_names": "Indian edible-nest swiftlet",\n    "scientific_name": "Aerodramus unicolor"\n}',
#  '\n\n{\n  "bird": "Indian vulture",\n  "alternate_names": ["Gyps indicus"],\n  "scientific_name": "Gyps indicus"\n}',
#  '\n\n{\n  "bird": "Sylvia palpebrosa",\n  "alternate_names": ["Zosterops palpebrosa"],\n  "scientific_name": "Sylvia palpebrosa"\n}',
#  '\n\n{\n  "bird": "Thalassarche chlororhynchos carteri",\n  "alternate_names": ["Thalassarche bassi"],\n  "scientific_name": "Thalassarche chlororhynchos carteri"\n}',
#  '\n\n{\n    "bird": "indigo bunting",\n    "alternate_names": ["Passerina cyanea"],\n    "scientific_name": "Cardinalidae"\n}',
#  '\n\n{\n    "bird": "Diglossopis indigotica",\n    "alternate_names": [],\n    "scientific_name": "Diglossopis indigotica"\n}',
#  '\n\n{\n    "bird": "Stoparola",\n    "alternate_names": ["Indigo"],\n    "scientific_name": "Stoparola indica"\n}',
#  '\n\n{\n    "bird": "Indigo-banded kingfisher",\n    "alternate_names": "Ceyx cyanopectus",\n    "scientific_name": "Alcedinidae"\n}',
#  '\n\n{\n    "bird": "Amazilia cyanifrons",\n    "alternate_names": [],\n    "scientific_name": "Amazilia cyanifrons[3]"\n}',
#  '\n\n{\n    "bird": "Indochinese barbet",\n    "alternate_names": "Annam barbet",\n    "scientific_name": "Psilopogon annamensis"\n}',
#  '\n\n{\n    "bird": "Indochinese blue flycatcher",\n    "alternate_names": "None",\n    "scientific_name": "Cyornis sumatrensis",\n    "family": "Muscicapidae"\n}',
#  '\n\n{\n  "bird": "Indochinese bush lark",\n  "alternate_names": "Indochinese lark",\n  "scientific_name": "Mirafra erythrocephala"\n}',
#  '\n\n{\n    "bird": "Indochinese cuckooshrike",\n    "alternate_names": [],\n    "scientific_name": "Lalage polioptera"\n}',
#  '\n\n{\n    "bird": "Alcippe danisi",\n    "alternate_names": [],\n    "scientific_name": "Alcippe danisi"\n}',
#  '\n\n{\n  "bird": "Indochinese green magpie",\n  "alternate_names": ["yellow-breasted magpie"],\n  "scientific_name": "Cissa hypoleuca"\n}',
#  '\n\n{\n    "bird": "Indochinese roller",\n    "alternate_names": ["Burmese roller"],\n    "scientific_name": "Coracias affinis"\n}',
#  '\n\n{\n    "bird": "Indochinese yuhina",\n    "alternate_names": "Chestnut-collared yuhina",\n    "scientific_name": "Staphida torqueola",\n    "family": "Zosteropidae"\n}',
#  '\n\n{\n    "bird": "Redirect to",\n    "alternate_names": null,\n    "scientific_name": null\n}',
#  '\n\n{\n    "bird": "Charadrius australis",\n    "alternate_names": [],\n    "scientific_name": "Charadrius australis"\n}',
#  '\n\n{\n    "bird": "inland thornbill",\n    "alternate_names": [],\n    "scientific_name": "Acanthiza apicalis"\n}',
#  '\n\n{\n  "bird": "intermediate egret",\n  "alternate_names": ["median egret", "smaller egret", "yellow-billed egret"],\n  "scientific_name": "Ardea intermedia"\n}',
#  '\n\n{\n    "bird": "Gallirallus wallacii",\n    "alternate_names": [],\n    "scientific_name": "Gallirallus wallacii"\n}',
#  '\n\n{\n    "bird": "Iphis monarch",\n    "alternate_names": ["Ua Huka flycatcher"],\n    "scientific_name": "Pomarea iphis"\n}',
#  '\n\n{\n    "bird": "Iquitos gnatcatcher",\n    "alternate_names": ["Polioptila clementsi"],\n    "scientific_name": "Polioptilidae"\n}',
#  '\n\n{\n  "bird": "Iraq babbler",\n  "alternate_names": "Argya altirostris",\n  "scientific_name": "Leiothrichidae"\n}',
#  '\n\n{\n    "bird": "Iringa akalat",\n    "alternate_names": "Sheppardia lowei",\n    "scientific_name": "Muscicapidae"\n}',
#  '\n\n{\n    "bird": "Iriomote tit",\n    "alternate_names": "Sittiparus olivaceus",\n    "scientific_name": "Paridae"\n}',
#  '\n\n{\n  "bird": "lorikeet",\n  "alternate_names": ["Saudareos iris"],\n  "scientific_name": "Iris lorikeet"\n}',
#  '\n\n{\n    "bird": "Isabela oriole",\n    "alternate_names": "none",\n    "scientific_name": "Oriolus isabellae"\n}',
#  '\n\n{\n  "bird": "Amaurornis isabellinus",\n  "alternate_names": "None",\n  "scientific_name": "Amaurornis isabellinus"\n}',
#  '\n\n{\n    "bird": "Isabelline Shrike",\n    "alternate_names": "Daurian Shrike",\n    "scientific_name": "Lanius isabellinus"\n}',
#  '\n\n{\n  "bird": "Isabelline Wheatear",\n  "alternate_names": ["Oenanthe Isabellina"],\n  "scientific_name": "Oenanthe Isabellina"\n}',
#  '\n\n{\n  "bird": "The island bronze-naped pigeon",\n  "alternate_names": "São Tomé bronze-naped pigeon",\n  "scientific_name": "Columba malherbii"\n}',
#  '\n\n{\n  "bird": "Island Imperial Pigeon",\n  "alternateNames": [],\n  "scientificName": "Ducula pistrinaria"\n}',
#  '\n\n{\n  "bird": "Island Leaf Warbler",\n  "alternate_names": "None",\n  "scientific_name": "Phylloscopus poliocephalus"\n}',
#  '\n\n{\n    "bird": "See text",\n    "alternate_names": "None",\n    "scientific_name": "None"\n}',
#  '\n\n{\n  "bird": "island scrub jay",\n  "alternate_names": ["island jay", "Santa Cruz jay"],\n  "scientific_name": "Aphelocoma insularis"\n}',
#  '\n\n{\n    "bird": "Collocalia inquietus",\n    "alternate_names": "White-rumped Swiftlet, White-rumped Needletail, White-rumped Spinetail, White-rumped Spinetailed Swift",\n    "scientific_name": "Collocalia inquietus"\n}',
#  '\n\n{\n    "bird": "See text",\n    "alternate_names": "None",\n    "scientific_name": "None"\n}',
#  '\n\n{\n  "bird": "The island whistler",\n  "alternate_names": "Pachycephala phaionota",\n  "scientific_name": "Pachycephalidae"\n}',
#  '\n\n{\n    "bird": "The islet kingfisher",\n    "alternate_names": "Todiramphus colonus",\n    "scientific_name": "Alcedinidae"\n}',
#  '\n\n{\n    "bird": "Isthmian Wren",\n    "alternate_names": [],\n    "scientific_name": "Cantorchilus elutus"\n}',
#  '\n\n{\n  "bird": "Italian sparrow",\n  "alternate_names": ["Cisalpine sparrow"],\n  "scientific_name": "Passer italiae"\n}',
#  '\n\n{\n  "bird": "Itatiaia spinetail",\n  "alternate_names": "Itatiaia thistletail",\n  "scientific_name": "Asthenes moreirae",\n  "family": "Furnariidae"\n}',
#  '\n\n{\n  "bird": "Itombwe flycatcher",\n  "alternate_names": ["Muscicapa itombwensis"],\n  "scientific_name": "Muscicapidae"\n}',
#  '\n\n{\n  "bird": "Ituri batis",\n  "alternate_names": ["Chapin\'s batis"],\n  "scientific_name": "Batis ituriensis"\n}',
#  '\n\n{\n  "bird": "ivory gull",\n  "alternate_names": "Pagophila eburnea",\n  "scientific_name": "Pagophila eburnea"\n}',
#  '\n\n{\n  "bird": "ivory-backed woodswallow",\n  "alternate_names": "Artamus monachus",\n  "scientific_name": "Artamidae"\n}',
#  '\n\n{\n    "bird": "See text",\n    "alternate_names": "None",\n    "scientific_name": "None"\n}',
#  '\n\n{\n    "bird": "ivory-billed coucal",\n    "alternate_names": "greater black coucal",\n    "scientific_name": "Centropus menbeki"\n}',
#  '\n\n{\n  "bird": "ivory-billed woodcreeper",\n  "alternate_names": "Xiphorhynchus flavigaster",\n  "scientific_name": "Passeriformes"\n}',
#  '\n\n{\n    "bird": "Picus principalis",\n    "alternate_names": [],\n    "scientific_name": "Linnaeus, 1758"\n}',
#  '\n\n{\n  "bird": "Pitta maxima",\n  "alternate_names": "ivory-breasted pitta",\n  "scientific_name": "Pitta maxima"\n}',
#  '\n\n{\n    "bird": "Izu thrush",\n    "alternate_names": "Izu Islands thrush",\n    "scientific_name": "Turdus celaenops"\n}',
#  '\n\n{\n    "bird": "Gabar Goshawk",\n    "alternate_names": [],\n    "scientific_name": "Micronisus gabar"\n}',
#  '\n\n{\n    "bird": "Gabela akalat",\n    "alternate_names": "Sheppardia gabela",\n    "scientific_name": "Muscicapidae"\n}',
#  '\n\n{\n    "bird": "Laniarius luehderi",\n    "alternate_names": "amboimensis",\n    "scientific_name": "Laniarius luehderi amboimensis"\n}',
#  '\n\n{\n    "bird": "Gabela helmetshrike",\n    "alternate_names": "Prionops gabela",\n    "scientific_name": "Vanga family Vangidae"\n}',
#  '\n\n{\n    "bird": "Platystira minima",\n    "alternate_names": [],\n    "scientific_name": "J"\n}',
#  '\n\n{\n    "bird": "Gabon coucal",\n    "alternate_names": "Centropus anselli",\n    "scientific_name": "Cuculidae"\n}',
#  '\n\n{\n  "bird": "Gabon woodpecker",\n  "alternate_names": "Dendropicos gabonensis",\n  "scientific_name": "Picidae"\n}',
#  '\n\n{\n    "bird": "gadwall",\n    "alternate_names": "Mareca strepera",\n    "scientific_name": "Anatidae"\n}',
#  '\n\n{\n  "bird": "galah",\n  "alternate_names": ["pink and grey cockatoo", "rose-breasted cockatoo"],\n  "scientific_name": "Eolophus roseicapilla"\n}',
#  '\n\n{\n  "bird": "Galapagos crake",\n  "alternate_names": ["Galapagos rail", "Darwin\'s rail"],\n  "scientific_name": "Laterallus spilonota"\n}',
#  '\n\n{\n  "bird": "Galápagos dove",\n  "alternate_names": "Zenaida galapagoensis",\n  "scientific_name": "Columbidae"\n}',
#  '\n\n{\n  "bird": "Galápagos flycatcher",\n  "alternate_names": "large-billed flycatcher",\n  "scientific_name": "Myiarchus magnirostris"\n}',
#  '\n\n{\n  "bird": "Galápagos hawk",\n  "alternate_names": "Buteo galapagoensis",\n  "scientific_name": "Buteo galapagoensis"\n}',
#  '\n\n{\n  "bird": "Galápagos martin",\n  "alternate_names": "Progne modesta",\n  "scientific_name": "Hirundinidae"\n}',
#  '\n\n{\n  "bird": "Galápagos mockingbird",\n  "alternateNames": "Mimus parvulus",\n  "scientificName": "Mimus parvulus"\n}',
#  '\n\n{\n  "bird": "Galápagos penguin",\n  "alternate_names": "Spheniscus mendiculus",\n  "scientific_name": "Spheniscus mendiculus"\n}',
#  '\n\n{\n  "bird": "Galápagos petrel",\n  "alternate_names": "Pterodroma phaeopygia",\n  "scientific_name": "Pterodroma phaeopygia"\n}',
#  '\n\n{\n    "bird": "Puffinus lherminieri",\n    "alternate_names": "subalaris",\n    "scientific_name": "Puffinus lherminieri subalaris"\n}',
#  '\n\n{\n  "bird": "Gambaga flycatcher",\n  "alternate_names": "Muscicapa gambagae",\n  "scientific_name": "Muscicapidae"\n}',
#  '\n\n{\n  "bird": "Gambel\'s quail",\n  "alternate_names": "Callipepla gambelii",\n  "scientific_name": "New World quail family"\n}',
#  '\n\n{\n  "bird": "gang-gang cockatoo",\n  "alternate_names": "Callocephalon fimbriatum",\n  "scientific_name": "Callocephalon fimbriatum"\n}',
#  '\n\n{\n    "bird": "Gansu leaf warbler",\n    "alternate_names": "Phylloscopus kansuensis",\n    "scientific_name": "Phylloscopus kansuensis"\n}',
#  '\n\n{\n    "bird": "Garden Emerald",\n    "alternate_names": ["Chlorostilbon assimilis"],\n    "scientific_name": "Chlorostilbon assimilis"\n}',
#  '\n\n{\n    "bird": "Garden Warbler",\n    "alternate_names": [],\n    "scientific_name": "Sylvia borin"\n}',
#  '\n\n{\n    "bird": "garganey",\n    "alternate_names": ["Spatula querquedula"],\n    "scientific_name": "Spatula querquedula"\n}',
#  '\n\n{\n    "bird": "Pitta",\n    "alternate_names": "Ground-thrush, Ground Thrush, Ground Thrush-babbler, Ground-thrush Babbler",\n    "scientific_name": "Pitta granatina"\n}',
#  '\n\n{\n    "bird": "garnet robin",\n    "alternate_names": "Eugerygone rubra",\n    "scientific_name": "Petroicidae"\n}',
#  '\n\n{\n    "bird": "garnet-throated hummingbird",\n    "alternate_names": "Lamprolaima rhami",\n    "scientific_name": "Lampornithini of subfamily Trochilinae"\n}',
#  '\n\n{\n  "bird": "Garrett\'s reed warbler",\n  "alternate_names": ["Society Islands reed warbler", "Forster\'s reed-warbler"],\n  "scientific_name": "Acrocephalus musae"\n}',
#  '\n\n{\n  "bird": "Trogon violaceus caligatus",\n  "alternate_names": "None",\n  "scientific_name": "Trogon violaceus caligatus"\n}',
#  '\n\n{\n  "bird": "Geelvink pygmy parrot",\n  "alternate_names": "Micropsitta geelvinkiana",\n  "scientific_name": "Psittacidae"\n}',
#  '\n\n{\n    "bird": "Genovesa cactus finch",\n    "alternate_names": "Geospiza propinqua",\n    "scientific_name": "Thraupidae"\n}',
#  '\n\n{\n    "bird": "Geospiza difficilis",\n    "alternate_names": "acutirostris",\n    "scientific_name": "Geospiza difficilis acutirostris"\n}',
#  '\n\n{\n    "bird": "Gentoo Penguin",\n    "alternate_names": ["Pygoscelis papua"],\n    "scientific_name": "Pygoscelis papua"\n}',
#  '\n\n{\n    "bird": "Augastes geoffroyi",\n    "alternate_names": "Bourcier, 1843",\n    "scientific_name": "Augastes geoffroyi (Bourcier, 1843)"\n}',
#  '\n\n{\n    "bird": "Geomalia heinrichi",\n    "alternate_names": [],\n    "scientific_name": "Geomalia heinrichi"\n}',
#  '\n\n{\n  "bird": "Germain\'s peacock-pheasant",\n  "alternate_names": ["Polyplectron germaini"],\n  "scientific_name": "Polyplectron germaini"\n}',
#  '\n\n{\n    "bird": "Collocalia germani",\n    "alternate_names": "German\'s Swiftlet, German\'s Swift",\n    "scientific_name": "Collocalia germani"\n}',
#  '\n\n{\n  "bird": "Giant Antpitta",\n  "alternate_names": "Grallaria gigantea",\n  "scientific_name": "Grallariidae"\n}',
#  '\n\n{\n  "bird": "Giant Antshrike",\n  "alternate_names": [],\n  "scientific_name": "Batara cinerea"\n}',
#  '\n\n{\n    "bird": "Ianthocincla waddelli",\n    "alternate_names": ["Babax waddelli"],\n    "scientific_name": "Ianthocincla waddelli"\n}',
#  '\n\n{\n    "bird": "Oreomanes fraseri",\n    "alternate_names": "none",\n    "scientific_name": "Oreomanes fraseri"\n}',
#  '\n\n{\n    "bird": "Giant Coot",\n    "alternate_names": ["Fulica gigantea"],\n    "scientific_name": "Fulica gigantea"\n}',
#  '\n\n{\n    "bird": "Giant Coua",\n    "alternate_names": ["Coua gigas"],\n    "scientific_name": "Coua gigas"\n}',
#  '\n\n{\n    "bird": "Scaphidura oryzivora",\n    "alternate_names": "none",\n    "scientific_name": "Scaphidura oryzivora"\n}',
#  '\n\n{\n    "bird": "Giant Honeyeater",\n    "alternate_names": "Duetting Giant Honeyeater",\n    "scientific_name": "Gymnomyza brunneirostris"\n}',
#  '\n\n{\n  "bird": "Giant Hummingbird",\n  "alternate_names": [],\n  "scientific_name": "Patagona gigas"\n}',
#  '\n\n{\n    "bird": "Pseudibis gigantea",\n    "alternate_names": "None",\n    "scientific_name": "Oustalet, 1877"\n}',
#  '\n\n{\n    "bird": "Giant Kingbird",\n    "alternate_names": [],\n    "scientific_name": "Tyrannus cubensis"\n}',
#  '\n\n{\n  "bird": "Giant Kingfisher",\n  "alternate_names": "Megaceryle maxima",\n  "scientific_name": "Megaceryle maxima"\n}',
#  '\n\n{\n    "bird": "Garrulax maximus",\n    "alternate_names": "None",\n    "scientific_name": "Garrulax maximus"\n}',
#  '\n\n{\n    "bird": "giant nuthatch",\n    "alternate_names": [],\n    "scientific_name": "Sitta magna"\n}',
#  '\n\n{\n    "bird": "Giant Pitta",\n    "alternate_names": ["Hydrornis caeruleus"],\n    "scientific_name": "Pittidae"\n}',
#  '\n\n{\n  "bird": "Giant Scops Owl",\n  "alternate_names": ["Lesser Eagle-Owl", "Mindanao Eagle-Owl"],\n  "scientific_name": "Otus gurneyi",\n  "family": "Strigidae"\n}',
#  '\n\n{\n    "bird": "Giant Snipe",\n    "alternate_names": [],\n    "scientific_name": "Gallinago undulata"\n}',
#  '\n\n{\n  "bird": "Giant Sunbird",\n  "alternate_names": [],\n  "scientific_name": "Dreptes thomensis"\n}',
#  '\n\n{\n    "bird": "Hydrochrous gigas",\n    "alternate_names": "Hartert & Butler, 1901",\n    "scientific_name": "[orthographic error]"\n}',
#  '\n\n{\n    "bird": "The giant weaver",\n    "alternate_names": "Ploceus grandis",\n    "scientific_name": "Ploceidae"\n}',
#  '\n\n{\n    "bird": "The giant white-eye",\n    "alternate_names": "Palau greater white-eye",\n    "scientific_name": "Megazosterops palauensis"\n}',
#  '\n\n{\n  "bird": "Giant wood rail",\n  "alternate_names": [],\n  "scientific_name": "Aramides ypecaha"\n}',
#  '\n\n{\n    "bird": "The giant wren",\n    "alternate_names": "Campylorhynchus chiapensis",\n    "scientific_name": "Troglodytidae"\n}',
#  '\n\n{\n  "bird": "gibberbird",\n  "alternate_names": "Ashbyia lovensis",\n  "scientific_name": "Meliphagidae family of passerine birds"\n}',
#  '\n\n{\n  "bird": "Gila woodpecker",\n  "alternate_names": "Melanerpes uropygialis",\n  "scientific_name": "Melanerpes uropygialis"\n}',
#  '\n\n{\n  "bird": "Gilbert\'s honeyeater",\n  "alternate_names": ["Swan River honeyeater", "western white-naped honeyeater"],\n  "scientific_name": "Melithreptus chloropsis"\n}',
#  '\n\n{\n  "bird": "Gilbert\'s whistler",\n  "alternate_names": "none",\n  "scientific_name": "Pachycephala inornata",\n  "endemic_to": "Australia",\n  "habitat": "semi-arid zones of southern Australia"\n}',
#  '\n\n{\n    "bird": "gilded barbet",\n    "alternate_names": ["Capito auratus"],\n    "scientific_name": "Capitonidae"\n}',
#  '\n\n{\n  "bird": "The gilded flicker",\n  "alternate_names": "Colaptes chrysoides",\n  "scientific_name": "Colaptes chrysoides"\n}',
#  '\n\n{\n  "bird": "Gilded sapphire",\n  "alternate_names": "Gilded hummingbird",\n  "scientific_name": "Hylocharis chrysura"\n}',
#  '\n\n{\n    "bird": "See text",\n    "alternate_names": "None",\n    "scientific_name": "None"\n}',
#  '\n\n{\n    "bird": "Melidectes whitemanensis",\n    "alternate_names": [],\n    "scientific_name": "Melidectes whitemanensis"\n}',
#  '\n\n{\n  "bird": "Tanagra cyanoventris",\n  "alternate_names": [],\n  "scientific_name": "Vieillot, 1819[2]"\n}',
#  '\n\n{\n    "bird": "Gizo white-eye",\n    "alternate_names": ["yellow-billed white-eye"],\n    "scientific_name": "Zosterops luteirostris"\n}',
#  '\n\n{\n  "bird": "glaucous gull",\n  "alternate_names": ["Larus hyperboreus"],\n  "scientific_name": "Larus hyperboreus"\n}',
#  '\n\n{\n  "bird": "The glaucous macaw",\n  "alternate_names": "Anodorhynchus glaucus",\n  "scientific_name": "Anodorhynchus glaucus"\n}',
#  '\n\n{\n    "bird": "glaucous tanager",\n    "alternate_names": [],\n    "scientific_name": "Thraupis glaucocolpa"\n}',
#  '\n\n{\n  "bird": "Passerina glaucocaerulea",\n  "alternate_names": "D\'Orbigny & Lafresnaye, 1837",\n  "scientific_name": "Passerina glaucocaerulea (D\'Orbigny & Lafresnaye, 1837)"\n}',
#  '\n\n{\n  "bird": "gull",\n  "alternate_names": "Larus glaucescens",\n  "scientific_name": "The glaucous-winged gull"\n}',
#  '\n\n{\n  "bird": "Glistening-green tanager",\n  "alternate_names": [],\n  "scientific_name": "Chlorochrysa phoenicotis"\n}',
#  '\n\n{\n    "bird": "Redirect to",\n    "alternate_names": null,\n    "scientific_name": null\n}',
#  '\n\n{\n    "bird": "Chlorostilbon aureoventris",\n    "alternate_names": ["D\'Orbigny and Lafresnaye, 1838"],\n    "scientific_name": "Chlorostilbon aureoventris"\n}',
#  '\n\n{\n    "bird": "hummingbird",\n    "alternate_names": "Chionomesa fimbriata",\n    "scientific_name": "Trochilini of subfamily Trochilinae"\n}',
#  '\n\n{\n    "bird": "glossy antshrike",\n    "alternate_names": "Sakesphorus luctuosus",\n    "scientific_name": "Thamnophilidae, the antbirds"\n}',
#  '\n\n{\n    "bird": "Crow",\n    "alternate_names": ["Carrion Crow", "Common Crow"],\n    "scientific_name": "Corvus brachyrhynchos"\n}',
#  '\n\n{\n    "bird": "flowerpiercer",\n    "alternate_names": ["Diglossa lafresnayii"],\n    "scientific_name": "Thraupidae"\n}',
#  '\n\n{\n  "bird": "glossy ibis",\n  "alternate_names": ["Plegadis falcinellus"],\n  "scientific_name": "Threskiornithidae"\n}',
#  '\n\n{\n  "bird": "Hirundo esculenta",\n  "alternate_names": [],\n  "scientific_name": "Linnaeus, 1758"\n}',
#  '\n\n{\n  "bird": "Muscicapa surinama",\n  "alternate_names": [],\n  "scientific_name": "Linnaeus, 1766"\n}',
#  '\n\n{\n  "bird": "Muscicapa divaricata",\n  "alternate_names": ["Dicrurus adsimilis divaricatus"],\n  "scientific_name": "Muscicapa divaricata"\n}',
#  '\n\n{\n    "bird": "Turdus serranus",\n    "alternate_names": ["unicolor", "Olrog & Contino, 1970"],\n    "scientific_name": "Turdus serranus unicolor Olrog & Contino, 1970 (non Tickell, 1833: preoccupied)"\n}',
#  '\n\n{\n  "bird": "Manucode",\n  "alternateNames": ["Manucodia ater"],\n  "scientificName": "Manucodia ater"\n}',
#  '\n\n{\n    "Bird": "Puffleg",\n    "Alternate Names": "None",\n    "Scientific Name": "Eriocnemis vestita"\n}',
#  '\n\n{\n  "Bird": "Glow-throated Hummingbird",\n  "Alternate Names": "None",\n  "Scientific Name": "Selasphorus ardens"\n}',
#  '\n\n{\n    "bird": "Godlewski\'s bunting",\n    "alternate_names": ["Emberiza godlewskii"],\n    "scientific_name": "Emberizidae"\n}',
#  '\n\n{\n    "bird": "Myrmeciza goeldii",\n    "alternate_names": "none",\n    "scientific_name": "Myrmeciza goeldii"\n}',
#  '\n\n{\n  "bird": "Gola malimbe",\n  "alternate_names": "Ballman\'s malimbe",\n  "scientific_name": "Malimbus ballmanni"\n}',
#  '\n\n{\n    "bird": "goldcrest",\n    "alternate_names": "Regulus regulus",\n    "scientific_name": "Kinglet family"\n}',
#  '\n\n{\n    "bird": "The golden babbler",\n    "alternate_names": "Cyanoderma chrysaeum",\n    "scientific_name": "Timaliidae"\n}',
#  '\n\n{\n    "bird": "golden bowerbird",\n    "alternate_names": "Prionodura newtoniana",\n    "scientific_name": "Ptilonorhynchidae"\n}',
#  '\n\n{\n  "bird": "Golden Bush Robin",\n  "alternate_names": ["Golden Bush-Robin"],\n  "scientific_name": "Tarsiger chrysaeus"\n}',
#  '\n\n{\n  "bird": "The golden cuckooshrike",\n  "alternate_names": "Campochaera sloetii",\n  "scientific_name": "Campephagidae"\n}',
#  '\n\n{\n    "bird": "6",\n    "alternate_names": "see text",\n    "scientific_name": "N/A"\n}',
#  '\n\n{\n  "bird": "golden fruit dove",\n  "alternate_names": ["lemon dove", "yellow dove"],\n  "scientific_name": "Ptilinopus luteovirens"\n}',
#  '\n\n{\n    "bird": "Genus",\n    "alternate_names": [],\n    "scientific_name": "Genus"\n}',
#  '\n\n{\n  "bird": "Golden Grosbeak",\n  "alternate_names": ["Golden-bellied Grosbeak", "Southern Yellow Grosbeak"],\n  "scientific_name": "Pheucticus chrysogaster"\n}',
#  '\n\n{\n  "bird": "Barn Owl",\n  "alternate_names": ["Tyto aurantia"],\n  "scientific_name": "Tyto aurantia"\n}',
#  '\n\n{\n    "bird": "See text",\n    "alternate_names": "None",\n    "scientific_name": "None"\n}',
#  '\n\n{\n    "bird": "Golden Myna",\n    "alternate_names": ["Mino anais"],\n    "scientific_name": "Sturnidae"\n}',
#  '\n\n{\n  "bird": "golden nightjar",\n  "alternate_names": "Caprimulgus eximius",\n  "scientific_name": "Caprimulgidae"\n}',
#  '\n\n{\n    "bird": "The golden palm weaver",\n    "alternate_names": "Ploceus bojeri",\n    "scientific_name": "Ploceidae"\n}',
#  '\n\n{\n  "bird": "Guarouba",\n  "alternate_names": ["Psittacus guarouba", "Aratinga guarouba"],\n  "scientific_name": "Psittacidae"\n}',
#  '\n\n{\n    "bird": "Paradoxornis verreauxi",\n    "alternate_names": "Verreaux\'s Parrotbill, White-browed Parrotbill",\n    "scientific_name": "Paradoxornis verreauxi"\n}',
#  '\n\n{\n    "bird": "Phasianus pictus",\n    "alternate_names": "none",\n    "scientific_name": "Linnaeus, 1758"\n}',
#  '\n\n{\n    "bird": "The golden pipit",\n    "alternate_names": "Tmetothylacus tenellus",\n    "scientific_name": "Tmetothylacus tenellus"\n}',
#  '\n\n{\n    "bird": "Hirundo sclateri",\n    "alternate_names": [],\n    "scientific_name": "Cory, 1884"\n}',
#  '\n\n{\n    "bird": "golden tanager",\n    "alternate_names": [],\n    "scientific_name": "Tangara arthus",\n    "family": "Thraupidae"\n}',
#  '\n\n{\n    "bird": "The golden vireo",\n    "alternate_names": "Vireo hypochryseus",\n    "scientific_name": "Vireonidae"\n}',
#  '\n\n{\n    "bird": "Ptilotis marchei",\n    "alternate_names": [],\n    "scientific_name": "Ptilotis marchei"\n}',
#  '\n\n{\n    "bird": "The golden-backed bishop",\n    "alternate_names": "Euplectes aureus",\n    "scientific_name": "Ploceidae"\n}',
#  '\n\n{\n  "bird": "Buthraupis aureodorsalis",\n  "alternate_names": "Golden-browed Chlorophonia, Chlorophonia aureodorsalis",\n  "scientific_name": "Buthraupis aureodorsalis"\n}',
#  '\n\n{\n  "bird": "The golden-backed weaver",\n  "alternate_names": "Jackson\'s weaver",\n  "scientific_name": "Ploceus jacksoni"\n}',
#  '\n\n{\n  "bird": "The golden-backed whistler",\n  "alternate_names": ["yellow-backed whistler"],\n  "scientific_name": "Pachycephala aurea"\n}',
#  '\n\n{\n    "bird": "golden-bellied flycatcher",\n    "alternate_names": ["Myiodynastes hemichrysus"],\n    "scientific_name": "Myiodynastes hemichrysus"\n}',
#  '\n\n{\n  "bird": "flyrobin",\n  "alternate_names": ["Microeca hemixantha"],\n  "scientific_name": "Petroicidae"\n}',
#  '\n\n{\n    "bird": "Gerygone sulphurea",\n    "alternate_names": "Golden-bellied Gerygone",\n    "scientific_name": "Gerygone sulphurea"\n}',
#  '\n\n{\n  "bird": "starfrontlet",\n  "alternate_names": ["Coeligena bonapartei"],\n  "scientific_name": "Coeligena bonapartei"\n}',
#  '\n\n{\n    "bird": "Golden-bellied Warbler",\n    "alternate_names": [],\n    "scientific_name": "Setophaga chrysoparia"\n}',
#  '\n\n{\n  "bird": "The golden-bellied white-eye",\n  "alternate_names": ["Zosterops uropygialis"],\n  "scientific_name": "Zosteropidae"\n}',
#  '\n\n{\n    "bird": "golden-billed saltator",\n    "alternate_names": ["Saltator aurantiirostris"],\n    "scientific_name": "Saltator aurantiirostris"\n}',
#  '\n\n{\n  "bird": "golden-breasted bunting",\n  "alternateNames": ["Emberiza flaviventris"],\n  "scientificName": "Emberizidae"\n}',
#  '\n\n{\n    "bird": "The golden-breasted fruiteater",\n    "alternate_names": "Pipreola aureopectus",\n    "scientific_name": "Cotingidae"\n}',
#  '\n\n{\n    "bird": "The golden-breasted fulvetta",\n    "alternate_names": "Lioparus chrysotis",\n    "scientific_name": "Lioparus chrysotis"\n}',
#  '\n\n{\n  "bird": "The golden-breasted puffleg",\n  "alternate_names": "Eriocnemis mosquera",\n  "scientific_name": "Heliantheini in subfamily Lesbiinae"\n}',
#  '\n\n{\n    "bird": "The golden-breasted starling",\n    "alternate_names": "royal starling",\n    "scientific_name": "Lamprotornis regius"\n}',
#  '\n\n{\n    "bird": "Golden-browed chat-tyrant",\n    "alternate_names": ["Silvicultrix pulchella"],\n    "scientific_name": "Tyrannidae"\n}',
#  '\n\n{\n  "bird": "The golden-browed chlorophonia",\n  "alternate_names": "Chlorophonia callophrys",\n  "scientific_name": "Fringillidae"\n}',
#  '\n\n{\n  "bird": "golden-browed warbler",\n  "alternate_names": "Basileuterus belli",\n  "scientific_name": "Parulidae, the New World warblers"\n}',
#  '\n\n{\n    "bird": "Aratinga auricapilla",\n    "alternate_names": "none",\n    "scientific_name": "Kuhl, 1820"\n}',
#  '\n\n{\n    "bird": "Dendroica chrysoparia",\n    "alternate_names": "Sclater & Salvin, 1861",\n    "scientific_name": "Dendroica chrysoparia Sclater & Salvin, 1861"\n}',
#  '\n\n{\n  "bird": "golden-cheeked woodpecker",\n  "alternate_names": "Melanerpes chrysogenys",\n  "scientific_name": "Picinae of the woodpecker family Picidae"\n}',
#  '\n\n{\n    "bird": "golden-chested tanager",\n    "alternate_names": [],\n    "scientific_name": "Bangsia rothschildi"\n}',
#  '\n\n{\n    "bird": "golden-chevroned tanager",\n    "alternate_names": [],\n    "scientific_name": "Thraupis ornata"\n}',
#  '\n\n{\n    "bird": "golden-collared honeycreeper",\n    "alternate_names": ["Iridophanes pulcherrimus"],\n    "scientific_name": "Iridophanes pulcherrimus"\n}',
#  '\n\n{\n  "bird": "macaw",\n  "alternate_names": ["golden-collared macaw", "yellow-collared macaw"],\n  "scientific_name": "Primolius auricollis"\n}',
#  '\n\n{\n  "bird": "golden-collared manakin",\n  "alternate_names": "Manacus vitellinus",\n  "scientific_name": "Pipridae"\n}',
#  '\n\n{\n    "bird": "golden-collared tanager",\n    "alternate_names": [],\n    "scientific_name": "Iridosornis jelskii"\n}',
#  '\n\n{\n    "bird": "See text",\n    "alternate_names": "None",\n    "scientific_name": "None"\n}',
#  '\n\n{\n    "bird": "Dryobates cassini",\n    "alternate_names": "None",\n    "scientific_name": "Dryobates cassini"\n}',
#  '\n\n{\n    "bird": "golden-crested myna",\n    "alternate_names": ["Ampeliceps coronatus"],\n    "scientific_name": "Sturnidae"\n}',
#  '\n\n{\n    "bird": "The golden-crowned babbler",\n    "alternate_names": "None",\n    "scientific_name": "Sterrhoptilus dennistouni"\n}',
#  '\n\n{\n  "bird": "Trochilus auriceps",\n  "alternate_names": ["Chlorostilbon auriceps"],\n  "scientific_name": "Trochilus auriceps"\n}',
#  '\n\n{\n    "bird": "The golden-crowned flycatcher",\n    "alternate_names": "Myiodynastes chrysocephalus",\n    "scientific_name": "Tyrannidae"\n}',
#  '\n\n{\n    "bird": "golden-crowned kinglet",\n    "alternate_names": "Regulus satrapa",\n    "scientific_name": "Regulidae"\n}',
#  '\n\n{\n    "bird": "Pipra vilasboasi",\n    "alternate_names": [],\n    "scientific_name": "Sick, 1959"\n}',
#  '\n\n{\n    "bird": "golden-crowned spadebill",\n    "alternate_names": [],\n    "scientific_name": "Platyrinchus coronatus"\n}',
#  '\n\n{\n  "bird": "Emberiza atricapilla",\n  "alternate_names": "Gmelin, 1789 Zonotrichia coronata Pallas, 1844",\n  "scientific_name": "Emberiza atricapilla Gmelin, 1789 Zonotrichia coronata Pallas, 1844"\n}',
#  '\n\n{\n    "bird": "golden-crowned tanager",\n    "alternate_names": [],\n    "scientific_name": "Iridosornis rufivertex"\n}',
#  '\n\n{\n  "bird": "golden-crowned warbler",\n  "alternate_names": "Basileuterus culicivorus",\n  "scientific_name": "Basileuterus culicivorus"\n}',
#  '\n\n{\n    "bird": "The golden-eared tanager",\n    "alternate_names": "Tangara chrysotis",\n    "scientific_name": "Thraupidae"\n}',
#  '\n\n{\n    "bird": "Diglossopis glauca",\n    "alternate_names": "None",\n    "scientific_name": "Diglossopis glauca"\n}',
#  '\n\n{\n  "bird": "Goldenface",\n  "alternate_names": "Pachycare flavogriseum",\n  "scientific_name": "Pachycare flavogriseum"\n}',
#  '\n\n{\n    "bird": "The golden-faced tyrannulet",\n    "alternate_names": "Zimmerius chrysops",\n    "scientific_name": "Tyrannidae"\n}',
#  '\n\n{\n  "bird": "golden-fronted bowerbird",\n  "alternate_names": "Amblyornis flavifrons",\n  "scientific_name": "Amblyornis flavifrons"\n}',
#  '\n\n{\n  "bird": "golden-fronted fulvetta",\n  "alternate_names": ["gold-fronted fulvetta"],\n  "scientific_name": "Schoeniparus variegaticeps"\n}',
#  '\n\n{\n    "bird": "Hylophilus aurantiifrons",\n    "alternate_names": [],\n    "scientific_name": "Hylophilus aurantiifrons"\n}',
#  '\n\n{\n    "bird": "Golden-fronted Leafbird",\n    "alternate_names": "Chloropsis aurifrons",\n    "scientific_name": "Chloropsis aurifrons"\n}',
#  '\n\n{\n  "bird": "golden-fronted whitestart",\n  "alternate_names": ["golden-fronted redstart"],\n  "scientific_name": "Myioborus ornatus",\n  "family": "Parulidae"\n}',
#  '\n\n{\n  "bird": "golden-fronted woodpecker",\n  "alternate_names": "Melanerpes aurifrons",\n  "scientific_name": "Picinae of the woodpecker family Picidae"\n}',
#  '\n\n{\n  "bird": "golden-green woodpecker",\n  "alternateNames": "Piculus chrysochloros",\n  "scientificName": "Picinae of the woodpecker family Picidae"\n}',
#  '\n\n{\n  "bird": "The golden-headed cisticola",\n  "alternate_names": "bright-capped cisticola",\n  "scientific_name": "Cisticola exilis"\n}',
#  '\n\n{\n  "bird": "The golden-headed manakin",\n  "alternate_names": "Ceratopipra erythrocephala",\n  "scientific_name": "Ceratopipra erythrocephala"\n}',
#  '\n\n{\n  "bird": "golden-headed quetzal or corequenque",\n  "alternate_names": ["Trogon auriceps"],\n  "scientific_name": "Pharomachrus auriceps"\n}',
#  '\n\n{\n  "bird": "golden-hooded tanager",\n  "alternate_names": "Stilpnia larvata",\n  "scientific_name": "Stilpnia larvata"\n}',
#  '\n\n{\n  "bird": "Golden-mantled Racket-tail",\n  "alternate_names": ["Prioniturus platurus"],\n  "scientific_name": "Psittaculidae"\n}',
#  '\n\n{\n    "bird": "Megalaima pulcherrimus",\n    "alternate_names": "None",\n    "scientific_name": "Megalaima pulcherrimus"\n}',
#  '\n\n{\n  "bird": "golden-naped finch",\n  "alternate_names": "Pyrrhoplectes epauletta",\n  "scientific_name": "Fringillidae"\n}',
#  '\n\n{\n    "bird": "golden-naped tanager",\n    "alternate_names": [],\n    "scientific_name": "Chalcothraupis ruficervix"\n}',
#  '\n\n{\n    "bird": "The golden-naped weaver",\n    "alternate_names": "Ploceus aureonucha",\n    "scientific_name": "Ploceidae"\n}',
#  '\n\n{\n  "bird": "The golden-naped woodpecker",\n  "alternate_names": "Melanerpes chrysauchen",\n  "scientific_name": "Picidae"\n}',
#  '\n\n{\n  "bird": "golden-olive woodpecker",\n  "alternate_names": "Colaptes rubiginosus",\n  "scientific_name": "Picinae of the woodpecker family Picidae"\n}',
#  '\n\n{\n  "bird": "golden-plumed parakeet",\n  "alternate_names": "Leptosittaca branickii",\n  "scientific_name": "Psittacidae, Leptosittaca"\n}',
#  '\n\n{\n  "bird": "Euphonia cyanocephala",\n  "alternate_names": "",\n  "scientific_name": "Euphonia cyanocephala"\n}',
#  '\n\n{\n    "bird": "golden-rumped flowerpecker",\n    "alternate_names": "Dicaeum annae",\n    "scientific_name": "Dicaeidae"\n}',
#  '\n\n{\n    "bird": "Psephotus chrysopterygius",\n    "alternate_names": [],\n    "scientific_name": "Psephotus chrysopterygius"\n}',
#  '\n\n{\n  "bird": "The golden-sided euphonia",\n  "alternate_names": "Euphonia cayennensis",\n  "scientific_name": "Fringillidae"\n}',
#  '\n\n{\n    "bird": "golden-spangled piculet",\n    "alternate_names": ["Picumnus exilis"],\n    "scientific_name": "Picumnus exilis"\n}',
#  '\n\n{\n    "bird": "Golden-spotted ground dove",\n    "alternate_names": "Metriopelia aymara",\n    "scientific_name": "Columbidae"\n}',
#  '\n\n{\n    "bird": "Touit",\n    "alternate_names": ["surda", "lapsus"],\n    "scientific_name": "Touit surda"\n}',
#  '\n\n{\n    "bird": "Amazilia oenone",\n    "alternate_names": [],\n    "scientific_name": "Amazilia oenone[3]"\n}',
#  '\n\n{\n    "bird": "Chrysoptilus abingoni",\n    "alternate_names": [],\n    "scientific_name": "Chrysoptilus abingoni"\n}',
#  '\n\n{\n  "bird": "Cyanops ramsayi",\n  "alternate_names": "Megalaima franklinii",\n  "scientific_name": "Cyanops ramsayiMegalaima franklinii"\n}',
#  '\n\n{\n  "bird": "The golden-tufted mountain grackle",\n  "alternate_names": "golden-tufted grackle",\n  "scientific_name": "Macroagelaius imthurni",\n  "family": "Icteridae"\n}',
#  '\n\n{\n  "bird": "Megalaima chrysopogon",\n  "alternate_names": "Asian Barred Owlet, Barred Owlet, Brown-cheeked Owlet, Brown-cheeked Wood-Owlet, Brown-cheeked Wood-Owl, Brown-cheeked Wood-owl, Brown-cheeked Woodowlet, Brown-cheeked Woodowl, Brown-cheeked Woodpecker-Owl, Brown-cheeked Woodpecker-owl, Brown-cheeked Woodpecker-Owlet, Brown-cheeked Woodpecker-owlet, Brown-cheeked Woodpecker-owl, Brown-cheeked Woodpecker-owl, Brown-cheeked Woodpecker-owl, Brown-cheeked Woodpecker-owl, Brown-cheeked Woodpecker-owl, Brown-cheeked Woodpecker-owl, Brown-cheeked Woodpecker-owl, Brown-cheeked Woodpecker-owl, Brown-cheeked Woodpecker-owl, Brown-cheeked Woodpecker-owl, Brown-cheeked Woodpecker-owl, Brown-cheeked Woodpecker-owl, Brown-cheeked Woodpecker-owl, Brown-cheeked Woodpecker-owl, Brown-cheeked Woodpecker-owl, Brown-cheeked Woodpecker-owl, Brown-cheeked Woodpecker-owl, Brown-cheeked Woodpecker-owl, Brown-cheeked Woodpecker-owl, Brown-cheeked Woodpecker-owl, Brown-cheeked Woodpecker-owl, Brown-cheeked Woodpecker-owl, Brown-cheeked Woodpecker-owl, Brown-cheeked Woodpecker-owl, Brown-cheeked Woodpecker-owl, Brown-cheeked Woodpecker-owl, Brown-cheeked Woodpecker-owl, Brown-cheeked Woodpecker-owl, Brown-cheeked Woodpecker-owl, Brown-cheeked Woodpecker-owl, Brown-cheeked Woodpecker-owl, Brown-cheeked Woodpecker-owl, Brown-cheeked Wood',
#  '\n\n{\n    "bird": "The golden-winged cacique",\n    "alternate_names": "Cacicus chrysopterus",\n    "scientific_name": "Icteridae"\n}',
#  '\n\n{\n  "bird": "Garrulax ngoclinhensis",\n  "alternate_names": [],\n  "scientific_name": "Garrulax ngoclinhensis"\n}',
#  '\n\n{\n  "bird": "golden-winged manakin",\n  "alternate_names": "Masius chrysopterus",\n  "scientific_name": "Pipridae"\n}',
#  '\n\n{\n  "bird": "Psittacus chrysopterus",\n  "alternateNames": [],\n  "scientificName": "Linnaeus, 1766"\n}',
#  '\n\n{\n    "bird": "golden-winged sparrow",\n    "alternate_names": "Arremon schlegeli",\n    "scientific_name": "Passerellidae"\n}',
#  '\n\n{\n  "bird": "The golden-winged sunbird",\n  "alternate_names": "Drepanorhynchus reichenowi",\n  "scientific_name": "Nectariniidae"\n}',
#  '\n\n{\n  "bird": "The golden-winged tody-flycatcher",\n  "alternateNames": ["Poecilotriccus calopterus"],\n  "scientificName": "Poecilotriccus calopterus"\n}',
#  '\n\n{\n  "bird": "golden-winged warbler",\n  "alternate_names": "Vermivora chrysoptera",\n  "scientific_name": "New World warbler"\n}',
#  '\n\n{\n  "bird": "Goldie\'s bird-of-paradise",\n  "alternateNames": "Paradisaea decora",\n  "scientificName": "Paradisaea decora"\n}',
#  '\n\n{\n  "bird": "lorikeet",\n  "alternate_names": ["Glossoptilus goldiei"],\n  "scientific_name": "Psittaculidae"\n}',
#  '\n\n{\n  "bird": "Goldman\'s warbler",\n  "alternate_names": "Setophaga goldmani",\n  "scientific_name": "Parulidae"\n}',
#  '\n\n{\n    "bird": "gold-ringed tanager",\n    "alternate_names": [],\n    "scientific_name": "Bangsia aureocincta"\n}',
#  '\n\n{\n    "bird": "Goliath Coucal",\n    "alternate_names": [],\n    "scientific_name": "Centropus goliath"\n}',
#  '\n\n{\n    "bird": "Garza goliath",\n    "alternate_names": "Goliath Heron, Giant Heron",\n    "scientific_name": "Ardea goliath"\n}',
#  '\n\n{\n    "bird": "Goliath Imperial Pigeon",\n    "alternate_names": ["New Caledonian Imperial Pigeon", "Notou"],\n    "scientific_name": "Ducula goliath"\n}',
#  '\n\n{\n    "bird": "Telophorus quadricolor",\n    "alternate_names": [],\n    "scientific_name": "Telophorus quadricolor"\n}',
#  '\n\n{\n  "bird": "Gorgeted puffleg",\n  "alternate_names": "None",\n  "scientific_name": "Eriocnemis isabellae"\n}',
#  '\n\n{\n    "Bird": "Gorgeted Sunangel",\n    "Alternate Names": "Heliangelus Strophianus",\n    "Scientific Name": "Heliangelus Strophianus"\n}',
#  '\n\n{\n    "bird": "gorgeted wood quail",\n    "alternate_names": ["Odontophorus strophium"],\n    "scientific_name": "Odontophorus strophium"\n}',
#  '\n\n{\n    "bird": "Acestrura heliodor",\n    "alternate_names": [],\n    "scientific_name": "Acestrura heliodor[3]"\n}',
#  '\n\n{\n    "bird": "Gosling\'s Apalis",\n    "alternate_names": "Apalis goslingi",\n    "scientific_name": "Cisticolidae"\n}',
#  '\n\n{\n    "bird": "Gosling\'s bunting",\n    "alternate_names": ["grey-throated bunting"],\n    "scientific_name": "Emberiza goslingi"\n}',
#  '\n\n{\n  "bird": "Nesospiza goughensis",\n  "alternate_names": ["Nesospiza jessiae"],\n  "scientific_name": "Nesospiza goughensis (protonym)"\n}',
#  '\n\n{\n  "bird": "Gough moorhen",\n  "alternate_names": ["common moorhen"],\n  "scientific_name": "Gallinula comeri"\n}',
#  '\n\n{\n  "bird": "Gouldian finch",\n  "alternate_names": ["Lady Gouldian finch", "Gould\'s finch", "rainbow finch"],\n  "scientific_name": "Chloebia gouldiae"\n}',
#  '\n\n{\n    "bird": "hummingbird",\n    "alternate_names": "Gould\'s emerald",\n    "scientific_name": "Riccordia elegans",\n    "family": "Trochilidae"\n}',
#  '\n\n{\n  "bird": "Gould\'s frogmouth",\n  "alternate_names": "Batrachostomus stellatus",\n  "scientific_name": "Podargidae"\n}',
#  '\n\n{\n    "bird": "Gould\'s jewelfront",\n    "alternate_names": "Gould\'s brilliant",\n    "scientific_name": "Heliodoxa aurescens",\n    "family": "Trochilidae"\n}',
#  '\n\n{\n    "bird": "Redirect to",\n    "alternate_names": null,\n    "scientific_name": null\n}',
#  '\n\n{\n    "bird": "Gould\'s petrel",\n    "alternate_names": "Pterodroma leucoptera",\n    "scientific_name": "Procellariidae"\n}',
#  '\n\n{\n    "bird": "Brachypteryx stellatus",\n    "alternate_names": [],\n    "scientific_name": "Brachypteryx stellatus"\n}',
#  '\n\n{\n    "bird": "Gould\'s toucanet",\n    "alternate_names": "Selenidera gouldii",\n    "scientific_name": "Ramphastidae"\n}',
#  '\n\n{\n    "bird": "honeyeater",\n    "alternate_names": ["Microptilotis gracilis"],\n    "scientific_name": "Microptilotis gracilis"\n}',
#  '\n\n{\n    "bird": "pitta",\n    "alternate_names": ["black-crowned pitta"],\n    "scientific_name": "Erythropitta venusta"\n}',
#  '\n\n{\n  "bird": "Prinia gracilis",\n  "alternate_names": "Graceful Warbler",\n  "scientific_name": "Prinia gracilis"\n}',
#  '\n\n{\n    "bird": "Grace\'s warbler",\n    "alternate_names": "Setophaga graciae",\n    "scientific_name": "Setophaga graciae"\n}',
#  '\n\n{\n    "bird": "Fringilla teydea",\n    "alternate_names": ["Polatzeki"],\n    "scientific_name": "Hartert 1905"\n}',
#  '\n\n{\n    "bird": "Grand Comoro brush warbler",\n    "alternate_names": "Nesillas brevicaudata",\n    "scientific_name": "Acrocephalidae"\n}',
#  '\n\n{\n  "bird": "Grand Comoro bulbul",\n  "alternate_names": "Hypsipetes parvirostris",\n  "scientific_name": "Pycnonotidae"\n}',
#  '\n\n{\n  "bird": "Grand Comoro drongo",\n  "alternate_names": "Dicrurus fuscipennis",\n  "scientific_name": "Dicruridae"\n}',
#  '\n\n{\n  "bird": "grand rhabdornis",\n  "alternate_names": ["long-billed rhabdornis", "long-billed creeper"],\n  "scientific_name": "Rhabdornis grandis"\n}',
#  '\n\n{\n    "bird": "Grandala",\n    "alternate_names": ["Grandala coelicolor"],\n    "scientific_name": "Turdidae"\n}',
# ...
#  '\n\n{\n  "bird": "grey-headed oliveback",\n  "alternate_names": ["white-cheeked oliveback"],\n  "scientific_name": "Delacourella capistrata"\n}',
#  '\n\n{\n  "bird": "Grey-headed parakeet",\n  "alternate_names": ["Slaty-headed parakeet"],\n  "scientific_name": "Psittacula finschii"\n}',
#  '\n\n{\n  "bird": "Grey-headed Parrotbill",\n  "alternate_names": "Psittiparus gularis",\n  "scientific_name": "Sylviidae"\n}',
#  '\n\n{\n  "bird": "Grey-headed piprites",\n  "alternate_names": ["Piprites griseiceps"],\n  "scientific_name": "Piprites griseiceps"\n}',
#  '\n\n{\n  "bird": "grey-headed robin",\n  "alternate_names": ["Heteromyias cinereifrons"],\n  "scientific_name": "Petroicidae"\n}',
#  '\n\n{\n  "bird": "Odontospiza griseicapilla",\n  "alternate_names": "Lonchura griseicapilla",\n  "scientific_name": "Odontospiza griseicapilla"\n}',
#  '\n\n{\n  "bird": "grey-headed spinetail",\n  "alternate_names": "Cranioleuca semicinerea",\n  "scientific_name": "Furnariidae"\n}',
#  '\n\n{\n  "bird": "Deleornis fraseri axillaris",\n  "alternate_names": ["Anthreptes axillaris", "Anthreptes fraseri axillaris"],\n  "scientific_name": "Deleornis fraseri axillaris"\n}',
#  '\n\n{\n    "bird": "Porphyrio porphyrio",\n    "alternate_names": ["Purple Swamphen", "Pūkeko"],\n    "scientific_name": "Porphyrio porphyrio poliocephalus"\n}',
#  '\n\n{\n  "bird": "grey-headed tanager",\n  "alternate_names": [],\n  "scientific_name": "Eucometis penicillata"\n}',
#  '\n\n{\n    "bird": "Myiothlypis griseiceps",\n    "alternate_names": "None",\n    "scientific_name": "Myiothlypis griseiceps"\n}',
#  '\n\n{\n  "bird": "Grey-headed woodpecker",\n  "alternate_names": "Grey-faced woodpecker",\n  "scientific_name": "Picus canus"\n}',
#  '\n\n{\n  "bird": "Attila rufus",\n  "alternate_names": "Grey-hooded Attila",\n  "scientific_name": "Tyrannidae"\n}',
#  '\n\n{\n  "bird": "grey-hooded bush tanager",\n  "alternate_names": "Cnemoscopus rubrirostris",\n  "scientific_name": "Thraupidae"\n}',
#  '\n\n{\n  "bird": "Grey-hooded Flycatcher",\n  "alternateNames": ["Mionectes rufiventris"],\n  "scientificName": "Tyrannidae"\n}',
#  '\n\n{\n    "bird": "Alcippe cinereiceps",\n    "alternate_names": "Grey-capped Wood-Warbler, Grey-headed Wren-Warbler",\n    "scientific_name": "Alcippe cinereiceps"\n}',
#  '\n\n{\n    "bird": "Bolborhynchus aymara",\n    "alternate_names": "d\'Orbigny, 1839",\n    "scientific_name": "Bolborhynchus aymara (d\'Orbigny, 1839)"\n}',
#  '\n\n{\n    "bird": "Paradoxornis zappeyi",\n    "alternate_names": "None",\n    "scientific_name": "Paradoxornis zappeyi"\n}',
#  '\n\n{\n    "bird": "grey-hooded sierra finch",\n    "alternate_names": "Phrygilus gayi",\n    "scientific_name": "Thraupidae"\n}',
#  '\n\n{\n    "bird": "Aethopyga primigenius",\n    "alternate_names": "lapsus",\n    "scientific_name": "Aethopyga primigenius"\n}',
#  '\n\n{\n  "bird": "Seicercus xanthoschistos",\n  "alternate_names": [],\n  "scientific_name": "G"\n}',
#  '\n\n{\n  "bird": "grey-hooded white-eye",\n  "alternate_names": "grey-hooded ibon",\n  "scientific_name": "Heleia pinaiae"\n}',
#  '\n\n{\n  "bird": "eagle-owl",\n  "alternate_names": ["greyish eagle-owl", "vermiculated eagle-owl"],\n  "scientific_name": "Bubo cinerascens"\n}',
#  '\n\n{\n    "bird": "greyish miner",\n    "alternate_names": "Geositta maritima",\n    "scientific_name": "Furnariidae"\n}',
#  '\n\n{\n    "bird": "Rhytipterna simplex",\n    "alternate_names": "greyish mourner",\n    "scientific_name": "Rhytipterna simplex"\n}',
#  '\n\n{\n  "bird": "greyish piculet",\n  "alternate_names": "Picumnus granadensis",\n  "scientific_name": "Picumninae of the woodpecker family Picidae"\n}',
#  '\n\n{\n    "bird": "Greyish Saltator",\n    "alternate_names": [],\n    "scientific_name": "Saltator coerulescens"\n}',
#  '\n\n{\n  "bird": "greylag goose or graylag goose",\n  "alternate_names": ["Anser anser"],\n  "scientific_name": "Anser anser"\n}',
#  '\n\n{\n  "bird": "tinamou",\n  "alternate_names": ["grey-legged tinamou", "gray-legged tinamou"],\n  "scientific_name": "Crypturellus duidae"\n}',
#  '\n\n{\n    "bird": "grey-mantled wren",\n    "alternate_names": ["Odontorchilus branickii"],\n    "scientific_name": "Odontorchilus branickii"\n}',
#  '\n\n{\n  "bird": "Grey-naped antpitta",\n  "alternate_names": "Grallaria griseonucha",\n  "scientific_name": "Grallariidae"\n}',
#  '\n\n{\n  "bird": "Grey-necked bunting",\n  "alternate_names": ["Grey-hooded bunting", "Chestnut-eared bunting"],\n  "scientific_name": "Emberiza buchanani"\n}',
#  '\n\n{\n  "bird": "grey-necked rockfowl",\n  "alternate_names": "Picathartes oreas",\n  "scientific_name": "Picathartidae"\n}',
#  '\n\n{\n  "bird": "grey-olive greenbul",\n  "alternate_names": ["grey-olive bulbul"],\n  "scientific_name": "Phyllastrephus cerviniventris"\n}',
#  '\n\n{\n  "bird": "Grey-rumped swallow",\n  "alternate_names": ["Pseudhirundo griseopyga"],\n  "scientific_name": "Pseudhirundo griseopyga"\n}',
#  '\n\n{\n  "bird": "Acanthylis cinereiventris",\n  "alternate_names": [],\n  "scientific_name": "Acanthylis cinereiventris[2]"\n}',
#  '\n\n{\n  "bird": "grey-rumped swiftlet",\n  "alternate_names": ["Collocalia marginata"],\n  "scientific_name": "Apodidae"\n}',
#  '\n\n{\n  "bird": "Grey-rumped Treeswift",\n  "alternate_names": "None",\n  "scientific_name": "Hemiprocne longipennis"\n}',
#  '\n\n{\n  "bird": "Grey-sided Bush Warbler",\n  "alternate_names": ["Cettia brunnifrons"],\n  "scientific_name": "Cettia brunnifrons"\n}',
#  '\n\n{\n    "bird": "grey-sided flowerpecker",\n    "alternate_names": "Dicaeum celebicum",\n    "scientific_name": "Dicaeidae"\n}',
#  '\n\n{\n  "bird": "Ianthocincla caerulata",\n  "alternate_names": ["Garrulax caerulatus"],\n  "scientific_name": "Ianthocincla caerulata"\n}',
#  '\n\n{\n    "bird": "grey-sided scimitar babbler",\n    "alternate_names": [],\n    "scientific_name": "Erythrogenys swinhoei"\n}',
#  '\n\n{\n    "bird": "grey-sided thrush",\n    "alternate_names": ["Turdus feae"],\n    "scientific_name": "Turdidae"\n}',
#  '\n\n{\n  "bird": "grey-streaked flycatcher or grey-spotted flycatcher",\n  "scientificName": "Muscicapa griseisticta",\n  "genus": "Muscicapa",\n  "family": "Muscicapidae"\n}',
#  '\n\n{\n  "bird": "grey-streaked honeyeater",\n  "alternate_names": "black-backed honeyeater",\n  "scientific_name": "Ptiloprora perstriata"\n}',
#  '\n\n{\n    "bird": "Francolinus griseostriatus",\n    "alternate_names": "Grey-breasted Francolin, Grey-breasted Spurfowl",\n    "scientific_name": "Francolinus griseostriatus"\n}',
#  '\n\n{\n  "bird": "mountaingem",\n  "alternate_names": ["gray-tailed mountaingem", "grey-tailed mountain-gem", "gray-tailed mountain-gem"],\n  "scientific_name": "Lampornis cinereicauda"\n}',
#  '\n\n{\n    "bird": "Lathria subalaris",\n    "alternate_names": [],\n    "scientific_name": "P"\n}',
#  '\n\n{\n  "bird": "Heteroscelus brevipes",\n  "alternate_names": ["Heterosceles brevipes", "Heteractitis brevipes"],\n  "scientific_name": "Heteroscelus brevipes"\n}',
#  '\n\n{\n  "bird": "grey-throated babbler",\n  "alternate_names": [],\n  "scientific_name": "Stachyris nigriceps"\n}',
#  '\n\n{\n    "bird": "grey-throated barbet",\n    "alternate_names": "Gymnobucco bonapartei",\n    "scientific_name": "Lybiidae family"\n}',
#  '\n\n{\n    "bird": "Grey-throated chat",\n    "alternate_names": "Cardinals or cardinal grosbeaks",\n    "scientific_name": "Granatellus sallaei"\n}',
#  '\n\n{\n  "bird": "grey-throated leaftosser",\n  "alternate_names": [],\n  "scientific_name": "Sclerurus albigularis"\n}',
#  '\n\n{\n  "bird": "grey-throated martin or Asian plain martin",\n  "alternate_names": ["Riparia chinensis"],\n  "scientific_name": "Riparia chinensis"\n}',
#  '\n\n{\n  "bird": "grey-throated rail",\n  "alternate_names": "Canirallus oculeus",\n  "scientific_name": "Rallidae"\n}',
#  '\n\n{\n    "bird": "Anthreptes malacensis",\n    "alternate_names": "griseigularis",\n    "scientific_name": "Anthreptes malacensis griseigularis"\n}',
#  '\n\n{\n  "bird": "grey-throated tit-flycatcher",\n  "alternate_names": ["Myioparus griseigularis"],\n  "scientific_name": "Myioparus griseigularis"\n}',
#  '\n\n{\n    "bird": "Basileuterus cinereicollis",\n    "alternate_names": "Gray-crowned Yellowthroat, Gray-hooded Yellowthroat",\n    "scientific_name": "Basileuterus cinereicollis"\n}',
#  '\n\n{\n    "bird": "Zosterops ugiensis",\n    "alternate_names": "None",\n    "scientific_name": "Zosterops ugiensis"\n}',
#  '\n\n{\n  "bird": "grey-winged blackbird",\n  "alternate_names": "Turdus boulboul",\n  "scientific_name": "Turdus boulboul"\n}',
#  '\n\n{\n    "bird": "grey-winged cotinga",\n    "alternate_names": [],\n    "scientific_name": "Lipaugus conditus"\n}',
#  '\n\n{\n  "bird": "Francolinus africanus",\n  "alternate_names": "Scleroptila africanus",\n  "scientific_name": "Francolinus africanusScleroptila africanus"\n}',
#  '\n\n{\n    "bird": "Inca finch",\n    "alternate_names": ["Incaspiza ortizi"],\n    "scientific_name": "Emberizidae"\n}',
#  '\n\n{\n  "bird": "Grey-winged robin-chat",\n  "alternate_names": ["Grey-winged akalat"],\n  "scientific_name": "Sheppardia polioptera"\n}',
#  '\n\n{\n    "bird": "Grey-winged trumpeter",\n    "alternate_names": ["Psophia crepitans"],\n    "scientific_name": "Psophiidae"\n}',
#  '\n\n{\n    "bird": "Redirect to",\n    "alternate_names": null,\n    "scientific_name": null\n}',
#  '\n\n{\n    "bird": "Grimwood\'s longclaw",\n    "alternate_names": "Macronyx grimwoodi",\n    "scientific_name": "Motacillidae"\n}',
#  '\n\n{\n  "bird": "Groove-billed Ani",\n  "alternate_names": ["Crotophaga sulcirostris"],\n  "scientific_name": "Crotophaga sulcirostris"\n}',
#  '\n\n{\n    "bird": "See text",\n    "alternate_names": "None",\n    "scientific_name": "None"\n}',
#  '\n\n{\n    "bird": "Lanius dubium",\n    "alternate_names": [],\n    "scientific_name": "Latham, 1801"\n}',
#  '\n\n{\n    "bird": "ground cuckoo-shrike",\n    "alternate_names": ["Coracina maxima"],\n    "scientific_name": "Coracina maxima"\n}',
#  '\n\n{\n  "bird": "Podoces humilis",\n  "alternate_names": ["Parus humilis"],\n  "scientific_name": "Hume, 1871"\n}',
#  '\n\n{\n  "bird": "Ground Woodpecker",\n  "alternate_names": ["Andean Flicker", "Campo Flicker"],\n  "scientific_name": "Geocolaptes olivaceus"\n}',
#  '\n\n{\n  "bird": "Psophocichla litsitsirupa",\n  "alternate_names": ["Psophocichla litsipsirupa"],\n  "scientific_name": "Cabanis, 1860"\n}',
#  '\n\n{\n  "bird": "Growling Riflebird",\n  "alternate_names": "Eastern Riflebird",\n  "scientific_name": "Ptiloris intercedens"\n}',
#  '\n\n{\n  "bird": "Guadalcanal dwarf kingfisher",\n  "alternate_names": "Ceyx nigromaxilla",\n  "scientific_name": "Alcedinidae"\n}',
#  '\n\n{\n  "bird": "Guadalcanal honeyeater",\n  "alternate_names": "none",\n  "scientific_name": "Guadalcanaria inexpectata"\n}',
#  '\n\n{\n    "bird": "Guadalcanal thrush",\n    "alternate_names": [],\n    "scientific_name": "Zoothera turipavae"\n}',
#  '\n\n{\n    "bird": "Junco hyemalis insularis",\n    "alternate_names": [],\n    "scientific_name": "Ridgway, 1876"\n}',
#  '\n\n{\n  "bird": "Guadalupe murrelet",\n  "alternate_names": "Xantus\' Murrelet",\n  "scientific_name": "Synthliboramphus hypoleucus"\n}',
#  '\n\n{\n    "bird": "Oceanodroma leucorhoa macrodactyla",\n    "alternate_names": "None",\n    "scientific_name": "Oceanodroma leucorhoa macrodactyla W"\n}',
#  '\n\n{\n  "bird": "Picus herminieri",\n  "alternate_names": ["Linneopicus herminieri"],\n  "scientific_name": "Lesson, 1830"\n}',
#  '\n\n{\n  "bird": "Guaiabero",\n  "alternate_names": ["Bolbopsittacus lunulatus"],\n  "scientific_name": "Psittaculidae"\n}',
#  '\n\n{\n  "bird": "Guaiquinima whitestart",\n  "alternate_names": ["Guaiquinima redstart", "Saffron-breasted whitestart", "Saffron-breasted redstart"],\n  "scientific_name": "Myioborus cardonai"\n}',
#  '\n\n{\n  "bird": "Guam flycatcher",\n  "alternate_names": "Guam broadbill",\n  "scientific_name": "Myiagra freycineti"\n}',
#  '\n\n{\n  "bird": "Guam kingfisher",\n  "alternate_names": [],\n  "scientific_name": "Todiramphus cinnamominus"\n}',
#  '\n\n{\n  "bird": "Guam rail",\n  "alternate_names": "Ko\'ko\' bird",\n  "scientific_name": "Hypotaenidia owstoni"\n}',
#  '\n\n{\n  "bird": "Phalacrocorax bougainvillii",\n  "alternate_names": ["Phalacrocorax bougainvilliorum", "Leucocarbo bougainvillii"],\n  "scientific_name": "Phalacrocorax bougainvillii"\n}',
#  '\n\n{\n  "bird": "Guatemalan pygmy owl",\n  "alternate_names": "Glaucidium cobanense",\n  "scientific_name": "Surniinae"\n}',
#  '\n\n{\n    "bird": "Guatemalan tyrannulet",\n    "alternate_names": ["paltry tyrannulet"],\n    "scientific_name": "Zimmerius vilissimus"\n}',
#  '\n\n{\n  "bird": "Guayaquil woodpecker",\n  "alternate_names": "Campephilus gayaquilensis",\n  "scientific_name": "Picinae of the woodpecker family Picidae"\n}',
#  '\n\n{\n  "bird": "Pipra rupicola",\n  "alternate_names": [],\n  "scientific_name": "Linnaeus, 1766"\n}',
#  '\n\n{\n  "bird": "Guianan gnatcatcher",\n  "alternate_names": "none",\n  "scientific_name": "Polioptila guianensis"\n}',
#  '\n\n{\n  "bird": "Guianan puffbird",\n  "alternate_names": ["puffbirds", "nunlets", "nunbirds"],\n  "scientific_name": "Notharchus macrorhynchos"\n}',
#  '\n\n{\n    "bird": "Guianan red cotinga",\n    "alternate_names": [],\n    "scientific_name": "Phoenicircus carnifex"\n}',
#  '\n\n{\n  "bird": "Guianan schiffornis",\n  "alternate_names": "olivaceous schiffornis",\n  "scientific_name": "Schiffornis olivacea"\n}',
#  '\n\n{\n    "bird": "Sitta surinamensis",\n    "alternate_names": "Brown-headed Nuthatch, Surinam Nuthatch",\n    "scientific_name": "Sitta surinamensis"\n}',
#  '\n\n{\n  "bird": "Guianan toucanet",\n  "alternate_names": "Guyana toucanet",\n  "scientific_name": "Selenidera piperivora",\n  "family": "Ramphastidae"\n}',
#  '\n\n{\n    "bird": "Guianan trogon",\n    "alternate_names": ["Trogon violaceus"],\n    "scientific_name": "Trogonidae"\n}',
#  '\n\n{\n    "bird": "Zimmerius gracilipes",\n    "alternate_names": "Zimmer\'s Flycatcher, Acer Flycatcher",\n    "scientific_name": "Zimmerius gracilipes acer"\n}',
#  '\n\n{\n    "bird": "Hypocnemis cantator",\n    "alternate_names": "None",\n    "scientific_name": "Hypocnemis cantator"\n}',
#  '\n\n{\n  "bird": "Guianan woodcreeper",\n  "alternate_names": [],\n  "scientific_name": "Lepidocolaptes albolineatus"\n}',
#  '\n\n{\n  "bird": "Cuculus persa",\n  "alternate_names": [],\n  "scientific_name": "Linnaeus, 1758"\n}',
#  '\n\n{\n  "bird": "Guira cuckoo",\n  "alternate_names": "Guira guira",\n  "scientific_name": "Guira guira"\n}',
#  '\n\n{\n    "bird": "Motacilla guira",\n    "alternate_names": [],\n    "scientific_name": "Motacilla guira (protonym)"\n}',
#  '\n\n{\n  "bird": "Güldenstädt\'s redstart",\n  "alternate_names": "white-winged redstart",\n  "scientific_name": "Phoenicurus erythrogastrus",\n  "genus": "Phoenicurus",\n  "family": "Muscicapidae"\n}',
#  '\n\n{\n    "bird": "Sterna nilotica",\n    "alternate_names": "Gull-billed Tern, White-winged Tern, White-winged Black Tern",\n    "scientific_name": "Chlidonias nilotica"\n}',
#  '\n\n{\n    "bird": "Accipiter gundlachii",\n    "alternate_names": "Lawrence, 1860 [orth",\n    "scientific_name": "Accipiter gundlachii Lawrence, 1860 [orth"\n}',
#  '\n\n{\n    "bird": "Centrocercus urophasianoides",\n    "alternate_names": "None",\n    "scientific_name": "Centrocercus urophasianoides"\n}',
#  '\n\n{\n    "bird": "Gurney\'s eagle",\n    "alternate_names": ["Aquila gurneyi"],\n    "scientific_name": "Accipitridae"\n}',
#  '\n\n{\n    "bird": "Gurney\'s pitta",\n    "alternate_names": ["Thai: นกแต้วแร้วท้องดำ"],\n    "scientific_name": "Hydrornis gurneyi"\n}',
#  '\n\n{\n    "bird": "Gurney\'s sugarbird",\n    "alternate_names": "Promerops gurneyi",\n    "scientific_name": "Promerops gurneyi"\n}',
#  '\n\n{\n  "bird": "Anabazenops guttulatus",\n  "alternate_names": "none",\n  "scientific_name": "Anabazenops guttulatus"\n}',
#  '\n\n{\n  "bird": "gyrfalcon",\n  "alternate_names": ["Falco rusticolus"],\n  "scientific_name": "Falco rusticolus"\n}']

# %%
with open('annotation.pickle','wb') as fw:
    pickle.dump(t,fw)

# %%
import json

def f(x):
    try:    
        return json.loads(x)
    except:
        return x
    

t = [f(x) for x in t]

# %%
t
# Out:
# [{'bird': 'Iago sparrow',
#   'alternate_names': ['Cape Verde', 'rufous-backed sparrow'],
#   'scientific_name': 'Passer iagoensis'},
#  {'bird': 'Ibadan malimbe',
#   'alternate_names': ['Malimbus ibadanensis'],
#   'scientific_name': 'Ploceidae'},
#  {'bird': 'Ibera seedeater',
#   'alternate_names': ['Sporophila iberaensis'],
#   'scientific_name': 'Thraupidae'},
#  {'bird': 'Iberian chiffchaff',
#   'alternate_names': [],
#   'scientific_name': 'Phylloscopus ibericus'},
#  {'bird': 'Iberian green woodpecker',
#   'alternate_names': 'Picus sharpei',
#   'scientific_name': 'Picus sharpei'},
#  {'bird': 'None', 'alternate_names': 'None', 'scientific_name': 'None'},
#  {'bird': 'Cyanopica cyanus',
#   'alternate_names': ['cooki'],
#   'scientific_name': 'Cyanopica cyana'},
#  {'bird': 'Clorhynchus strophiatus',
#   'alternate_names': [],
#   'scientific_name': 'Hodgson, 1835'},
#  {'bird': 'Iceland gull',
#   'alternate_names': 'Larus glaucoides',
#   'scientific_name': 'Larus glaucoides'},
#  {'bird': 'Icterine Greenbul',
#   'alternate_names': 'Phyllastrephus icterinus',
#   'scientific_name': 'Pycnonotidae'},
#  {'bird': 'Icterine Warbler',
#   'alternate_names': ['Hippolais icterina'],
#   'scientific_name': 'Hippolais icterina'},
#  {'bird': "Ihering's antwren",
#   'alternate_names': 'Myrmotherula iheringi',
#   'scientific_name': 'Thamnophilidae'},
#  {'bird': 'Acanthopneuste ijimae',
#   'alternate_names': ['Acanthopneuste occipitalis ijimae',
#    'Phylloscopus coronatus ijimae',
#    'Phylloscopus tenellipes ijimae'],
#   'scientific_name': 'Acanthopneuste ijimae (protonym)'},
#  {'bird': 'Hypocnemis cantator',
#   'alternate_names': 'Flavescens',
#   'scientific_name': 'Hypocnemis cantator flavescens'},
#  {'bird': 'imitator goshawk or imitator sparrowhawk',
#   'alternate_names': ['Accipiter imitator'],
#   'scientific_name': 'Accipiter imitator'},
#  {'bird': 'Imperial Amazon',
#   'alternate_names': ['Sisserou', 'Sisserou Parrot'],
#   'scientific_name': 'Amazona imperialis'},
#  {'bird': 'Imperial Shag',
#   'alternate_names': ['Imperial Cormorant'],
#   'scientific_name': 'Leucocarbo atriceps'},
#  {'bird': 'Imperial Snipe',
#   'alternate_names': [],
#   'scientific_name': 'Gallinago imperialis'},
#  {'bird': 'The imperial woodpecker',
#   'alternate_names': 'Campephilus imperialis',
#   'scientific_name': 'Campephilus imperialis'},
#  {'bird': 'Inaccessible Island finch',
#   'alternate_names': 'Inaccessible bunting',
#   'scientific_name': 'Nesospiza acunhae',
#   'family': 'Thraupidae (formerly in Emberizidae)'},
#  {'bird': 'Inaccessible Island rail',
#   'alternate_names': [],
#   'scientific_name': 'Laterallus rogersi'},
#  {'bird': 'Nesophlox evelynae lyrura',
#   'alternate_names': None,
#   'scientific_name': 'Nesophlox evelynae lyrura'},
#  {'bird': 'Inambari gnatcatcher',
#   'alternate_names': 'Polioptila attenboroughi',
#   'scientific_name': 'Polioptilidae'},
#  {'bird': 'Inambari woodcreeper',
#   'alternate_names': [],
#   'scientific_name': 'Lepidocolaptes fatimalimae'},
#  {'bird': 'Scardafella inca',
#   'alternate_names': None,
#   'scientific_name': 'Scardafella inca'},
#  {'bird': 'Inca flycatcher',
#   'alternate_names': [],
#   'scientific_name': 'Leptopogon taczanowskii'},
#  {'bird': 'Inca jay',
#   'alternate_names': 'querrequerre',
#   'scientific_name': 'Cyanocorax yncas'},
#  {'bird': 'Inca Tern',
#   'alternate_names': 'Larosterna inca',
#   'scientific_name': 'Sterninae of the family Laridae'},
#  {'bird': 'Thryothorus eisenmanni',
#   'alternate_names': 'none',
#   'scientific_name': 'Thryothorus eisenmanni'},
#  {'bird': 'Indian blackbird',
#   'alternate_names': [],
#   'scientific_name': 'Turdus simillimus'},
#  {'bird': 'Parus aplonotus',
#   'alternate_names': 'none',
#   'scientific_name': 'Parus aplonotus'},
#  {'bird': 'Erithacus brunneus',
#   'alternate_names': ['Larvivora brunnea',
#    'Tarsiger brunnea',
#    'Luscinia brunnea'],
#   'scientific_name': 'Erithacus brunneus'},
#  {'bird': 'Indian bush lark',
#   'alternate_names': 'Mirafra erythroptera',
#   'scientific_name': 'Alaudidae'},
#  {'bird': 'Indian cormorant',
#   'alternate_names': 'Indian shag',
#   'scientific_name': 'Phalacrocorax fuscicollis'},
#  {'bird': 'None', 'alternate_names': 'None', 'scientific_name': 'None'},
#  {'bird': 'Indian cuckoo',
#   'alternate_names': 'Cuculus micropterus',
#   'scientific_name': 'Cuculiformes'},
#  {'bird': 'Urrua bengalensis',
#   'alternate_names': [],
#   'scientific_name': 'Urrua bengalensis[3]'},
#  {'bird': 'Indian golden oriole',
#   'alternate_names': 'Oriolus kundoo',
#   'scientific_name': 'Oriolus kundoo'},
#  {'bird': 'Indian grassbird',
#   'alternate_names': 'Graminicola bengalensis',
#   'scientific_name': 'Pellorneidae'},
#  {'bird': 'Lophoceros birostris',
#   'alternate_names': ['Tockus birostris', 'Meniceros birostris'],
#   'scientific_name': 'Ocyceros ginginianus'},
#  {'bird': 'Corvus macrorhynchos culminatus',
#   'alternate_names': '',
#   'scientific_name': 'Corvus macrorhynchos culminatus'},
#  {'bird': 'Indian nightjar',
#   'alternate_names': 'none',
#   'scientific_name': 'Caprimulgus asiaticus'},
#  {'bird': 'Indian nuthatch',
#   'alternate_names': [],
#   'scientific_name': 'Sitta castanea'},
#  {'bird': 'See text', 'alternate_names': 'None', 'scientific_name': 'None'},
#  {'bird': 'Indian peafowl',
#   'alternate_names': ['common peafowl', 'blue peafowl'],
#   'scientific_name': 'Pavo cristatus'},
#  {'bird': 'Corvus brachyurus',
#   'alternate_names': [],
#   'scientific_name': 'Linnaeus, 1766[2]'},
#  {'bird': 'Ardeola leucoptera',
#   'alternate_names': 'Indian Pond Heron, Paddybird, Ricebird',
#   'scientific_name': 'Ardeola leucoptera'},
#  {'bird': 'Indian robin',
#   'alternate_names': 'Copsychus fulicatus',
#   'scientific_name': 'Muscicapidae'},
#  {'bird': 'Corvus benghalensis',
#   'alternate_names': [],
#   'scientific_name': 'Linnaeus, 1758'},
#  {'bird': 'P', 'alternate_names': [], 'scientific_name': ''},
#  {'bird': 'Indian scops owl',
#   'alternate_names': 'Otus bakkamoena',
#   'scientific_name': 'Otus bakkamoena'},
#  {'bird': 'Indian silverbill or white-throated munia',
#   'alternate_names': ['Euodice malabarica',
#    'African silverbill',
#    'Euodice cantans'],
#   'scientific_name': 'Euodice malabarica'},
#  {'bird': 'Rhynchops albicollis',
#   'alternate_names': 'White-throated Skimmer, White-throated Needletail',
#   'scientific_name': 'Rhynchops albicollis'},
#  {'bird': 'Anas poikilorhynchus',
#   'alternate_names': 'None',
#   'scientific_name': 'Anas poikilorhynchus'},
#  {'bird': 'Indian spotted creeper',
#   'alternate_names': ['Salpornis spilonota'],
#   'scientific_name': 'Salpornithinae'},
#  {'bird': 'Aquila hastata',
#   'alternate_names': 'Hastate Eagle, Booted Eagle',
#   'scientific_name': 'Hieraaetus pennatus'},
#  {'bird': 'Indian stone-curlew or Indian thick-knee',
#   'scientific_name': 'Burhinus indicus',
#   'family': 'Burhinidae'},
#  {'bird': 'Indian swiftlet',
#   'alternate_names': 'Indian edible-nest swiftlet',
#   'scientific_name': 'Aerodramus unicolor'},
#  {'bird': 'Indian vulture',
#   'alternate_names': ['Gyps indicus'],
#   'scientific_name': 'Gyps indicus'},
#  {'bird': 'Sylvia palpebrosa',
#   'alternate_names': ['Zosterops palpebrosa'],
#   'scientific_name': 'Sylvia palpebrosa'},
#  {'bird': 'Thalassarche chlororhynchos carteri',
#   'alternate_names': ['Thalassarche bassi'],
#   'scientific_name': 'Thalassarche chlororhynchos carteri'},
#  {'bird': 'indigo bunting',
#   'alternate_names': ['Passerina cyanea'],
#   'scientific_name': 'Cardinalidae'},
#  {'bird': 'Diglossopis indigotica',
#   'alternate_names': [],
#   'scientific_name': 'Diglossopis indigotica'},
#  {'bird': 'Stoparola',
#   'alternate_names': ['Indigo'],
#   'scientific_name': 'Stoparola indica'},
#  {'bird': 'Indigo-banded kingfisher',
#   'alternate_names': 'Ceyx cyanopectus',
#   'scientific_name': 'Alcedinidae'},
#  {'bird': 'Amazilia cyanifrons',
#   'alternate_names': [],
#   'scientific_name': 'Amazilia cyanifrons[3]'},
#  {'bird': 'Indochinese barbet',
#   'alternate_names': 'Annam barbet',
#   'scientific_name': 'Psilopogon annamensis'},
#  {'bird': 'Indochinese blue flycatcher',
#   'alternate_names': 'None',
#   'scientific_name': 'Cyornis sumatrensis',
#   'family': 'Muscicapidae'},
#  {'bird': 'Indochinese bush lark',
#   'alternate_names': 'Indochinese lark',
#   'scientific_name': 'Mirafra erythrocephala'},
#  {'bird': 'Indochinese cuckooshrike',
#   'alternate_names': [],
#   'scientific_name': 'Lalage polioptera'},
#  {'bird': 'Alcippe danisi',
#   'alternate_names': [],
#   'scientific_name': 'Alcippe danisi'},
#  {'bird': 'Indochinese green magpie',
#   'alternate_names': ['yellow-breasted magpie'],
#   'scientific_name': 'Cissa hypoleuca'},
#  {'bird': 'Indochinese roller',
#   'alternate_names': ['Burmese roller'],
#   'scientific_name': 'Coracias affinis'},
#  {'bird': 'Indochinese yuhina',
#   'alternate_names': 'Chestnut-collared yuhina',
#   'scientific_name': 'Staphida torqueola',
#   'family': 'Zosteropidae'},
#  {'bird': 'Redirect to', 'alternate_names': None, 'scientific_name': None},
#  {'bird': 'Charadrius australis',
#   'alternate_names': [],
#   'scientific_name': 'Charadrius australis'},
#  {'bird': 'inland thornbill',
#   'alternate_names': [],
#   'scientific_name': 'Acanthiza apicalis'},
#  {'bird': 'intermediate egret',
#   'alternate_names': ['median egret', 'smaller egret', 'yellow-billed egret'],
#   'scientific_name': 'Ardea intermedia'},
#  {'bird': 'Gallirallus wallacii',
#   'alternate_names': [],
#   'scientific_name': 'Gallirallus wallacii'},
#  {'bird': 'Iphis monarch',
#   'alternate_names': ['Ua Huka flycatcher'],
#   'scientific_name': 'Pomarea iphis'},
#  {'bird': 'Iquitos gnatcatcher',
#   'alternate_names': ['Polioptila clementsi'],
#   'scientific_name': 'Polioptilidae'},
#  {'bird': 'Iraq babbler',
#   'alternate_names': 'Argya altirostris',
#   'scientific_name': 'Leiothrichidae'},
#  {'bird': 'Iringa akalat',
#   'alternate_names': 'Sheppardia lowei',
#   'scientific_name': 'Muscicapidae'},
#  {'bird': 'Iriomote tit',
#   'alternate_names': 'Sittiparus olivaceus',
#   'scientific_name': 'Paridae'},
#  {'bird': 'lorikeet',
#   'alternate_names': ['Saudareos iris'],
#   'scientific_name': 'Iris lorikeet'},
#  {'bird': 'Isabela oriole',
#   'alternate_names': 'none',
#   'scientific_name': 'Oriolus isabellae'},
#  {'bird': 'Amaurornis isabellinus',
#   'alternate_names': 'None',
#   'scientific_name': 'Amaurornis isabellinus'},
#  {'bird': 'Isabelline Shrike',
#   'alternate_names': 'Daurian Shrike',
#   'scientific_name': 'Lanius isabellinus'},
#  {'bird': 'Isabelline Wheatear',
#   'alternate_names': ['Oenanthe Isabellina'],
#   'scientific_name': 'Oenanthe Isabellina'},
#  {'bird': 'The island bronze-naped pigeon',
#   'alternate_names': 'São Tomé bronze-naped pigeon',
#   'scientific_name': 'Columba malherbii'},
#  {'bird': 'Island Imperial Pigeon',
#   'alternateNames': [],
#   'scientificName': 'Ducula pistrinaria'},
#  {'bird': 'Island Leaf Warbler',
#   'alternate_names': 'None',
#   'scientific_name': 'Phylloscopus poliocephalus'},
#  {'bird': 'See text', 'alternate_names': 'None', 'scientific_name': 'None'},
#  {'bird': 'island scrub jay',
#   'alternate_names': ['island jay', 'Santa Cruz jay'],
#   'scientific_name': 'Aphelocoma insularis'},
#  {'bird': 'Collocalia inquietus',
#   'alternate_names': 'White-rumped Swiftlet, White-rumped Needletail, White-rumped Spinetail, White-rumped Spinetailed Swift',
#   'scientific_name': 'Collocalia inquietus'},
#  {'bird': 'See text', 'alternate_names': 'None', 'scientific_name': 'None'},
#  {'bird': 'The island whistler',
#   'alternate_names': 'Pachycephala phaionota',
#   'scientific_name': 'Pachycephalidae'},
#  {'bird': 'The islet kingfisher',
#   'alternate_names': 'Todiramphus colonus',
#   'scientific_name': 'Alcedinidae'},
#  {'bird': 'Isthmian Wren',
#   'alternate_names': [],
#   'scientific_name': 'Cantorchilus elutus'},
#  {'bird': 'Italian sparrow',
#   'alternate_names': ['Cisalpine sparrow'],
#   'scientific_name': 'Passer italiae'},
#  {'bird': 'Itatiaia spinetail',
#   'alternate_names': 'Itatiaia thistletail',
#   'scientific_name': 'Asthenes moreirae',
#   'family': 'Furnariidae'},
#  {'bird': 'Itombwe flycatcher',
#   'alternate_names': ['Muscicapa itombwensis'],
#   'scientific_name': 'Muscicapidae'},
#  {'bird': 'Ituri batis',
#   'alternate_names': ["Chapin's batis"],
#   'scientific_name': 'Batis ituriensis'},
#  {'bird': 'ivory gull',
#   'alternate_names': 'Pagophila eburnea',
#   'scientific_name': 'Pagophila eburnea'},
#  {'bird': 'ivory-backed woodswallow',
#   'alternate_names': 'Artamus monachus',
#   'scientific_name': 'Artamidae'},
#  {'bird': 'See text', 'alternate_names': 'None', 'scientific_name': 'None'},
#  {'bird': 'ivory-billed coucal',
#   'alternate_names': 'greater black coucal',
#   'scientific_name': 'Centropus menbeki'},
#  {'bird': 'ivory-billed woodcreeper',
#   'alternate_names': 'Xiphorhynchus flavigaster',
#   'scientific_name': 'Passeriformes'},
#  {'bird': 'Picus principalis',
#   'alternate_names': [],
#   'scientific_name': 'Linnaeus, 1758'},
#  {'bird': 'Pitta maxima',
#   'alternate_names': 'ivory-breasted pitta',
#   'scientific_name': 'Pitta maxima'},
#  {'bird': 'Izu thrush',
#   'alternate_names': 'Izu Islands thrush',
#   'scientific_name': 'Turdus celaenops'},
#  {'bird': 'Gabar Goshawk',
#   'alternate_names': [],
#   'scientific_name': 'Micronisus gabar'},
#  {'bird': 'Gabela akalat',
#   'alternate_names': 'Sheppardia gabela',
#   'scientific_name': 'Muscicapidae'},
#  {'bird': 'Laniarius luehderi',
#   'alternate_names': 'amboimensis',
#   'scientific_name': 'Laniarius luehderi amboimensis'},
#  {'bird': 'Gabela helmetshrike',
#   'alternate_names': 'Prionops gabela',
#   'scientific_name': 'Vanga family Vangidae'},
#  {'bird': 'Platystira minima', 'alternate_names': [], 'scientific_name': 'J'},
#  {'bird': 'Gabon coucal',
#   'alternate_names': 'Centropus anselli',
#   'scientific_name': 'Cuculidae'},
#  {'bird': 'Gabon woodpecker',
#   'alternate_names': 'Dendropicos gabonensis',
#   'scientific_name': 'Picidae'},
#  {'bird': 'gadwall',
#   'alternate_names': 'Mareca strepera',
#   'scientific_name': 'Anatidae'},
#  {'bird': 'galah',
#   'alternate_names': ['pink and grey cockatoo', 'rose-breasted cockatoo'],
#   'scientific_name': 'Eolophus roseicapilla'},
#  {'bird': 'Galapagos crake',
#   'alternate_names': ['Galapagos rail', "Darwin's rail"],
#   'scientific_name': 'Laterallus spilonota'},
#  {'bird': 'Galápagos dove',
#   'alternate_names': 'Zenaida galapagoensis',
#   'scientific_name': 'Columbidae'},
#  {'bird': 'Galápagos flycatcher',
#   'alternate_names': 'large-billed flycatcher',
#   'scientific_name': 'Myiarchus magnirostris'},
#  {'bird': 'Galápagos hawk',
#   'alternate_names': 'Buteo galapagoensis',
#   'scientific_name': 'Buteo galapagoensis'},
#  {'bird': 'Galápagos martin',
#   'alternate_names': 'Progne modesta',
#   'scientific_name': 'Hirundinidae'},
#  {'bird': 'Galápagos mockingbird',
#   'alternateNames': 'Mimus parvulus',
#   'scientificName': 'Mimus parvulus'},
#  {'bird': 'Galápagos penguin',
#   'alternate_names': 'Spheniscus mendiculus',
#   'scientific_name': 'Spheniscus mendiculus'},
#  {'bird': 'Galápagos petrel',
#   'alternate_names': 'Pterodroma phaeopygia',
#   'scientific_name': 'Pterodroma phaeopygia'},
#  {'bird': 'Puffinus lherminieri',
#   'alternate_names': 'subalaris',
#   'scientific_name': 'Puffinus lherminieri subalaris'},
#  {'bird': 'Gambaga flycatcher',
#   'alternate_names': 'Muscicapa gambagae',
#   'scientific_name': 'Muscicapidae'},
#  {'bird': "Gambel's quail",
#   'alternate_names': 'Callipepla gambelii',
#   'scientific_name': 'New World quail family'},
#  {'bird': 'gang-gang cockatoo',
#   'alternate_names': 'Callocephalon fimbriatum',
#   'scientific_name': 'Callocephalon fimbriatum'},
#  {'bird': 'Gansu leaf warbler',
#   'alternate_names': 'Phylloscopus kansuensis',
#   'scientific_name': 'Phylloscopus kansuensis'},
#  {'bird': 'Garden Emerald',
#   'alternate_names': ['Chlorostilbon assimilis'],
#   'scientific_name': 'Chlorostilbon assimilis'},
#  {'bird': 'Garden Warbler',
#   'alternate_names': [],
#   'scientific_name': 'Sylvia borin'},
#  {'bird': 'garganey',
#   'alternate_names': ['Spatula querquedula'],
#   'scientific_name': 'Spatula querquedula'},
#  {'bird': 'Pitta',
#   'alternate_names': 'Ground-thrush, Ground Thrush, Ground Thrush-babbler, Ground-thrush Babbler',
#   'scientific_name': 'Pitta granatina'},
#  {'bird': 'garnet robin',
#   'alternate_names': 'Eugerygone rubra',
#   'scientific_name': 'Petroicidae'},
#  {'bird': 'garnet-throated hummingbird',
#   'alternate_names': 'Lamprolaima rhami',
#   'scientific_name': 'Lampornithini of subfamily Trochilinae'},
#  {'bird': "Garrett's reed warbler",
#   'alternate_names': ['Society Islands reed warbler',
#    "Forster's reed-warbler"],
#   'scientific_name': 'Acrocephalus musae'},
#  {'bird': 'Trogon violaceus caligatus',
#   'alternate_names': 'None',
#   'scientific_name': 'Trogon violaceus caligatus'},
#  {'bird': 'Geelvink pygmy parrot',
#   'alternate_names': 'Micropsitta geelvinkiana',
#   'scientific_name': 'Psittacidae'},
#  {'bird': 'Genovesa cactus finch',
#   'alternate_names': 'Geospiza propinqua',
#   'scientific_name': 'Thraupidae'},
#  {'bird': 'Geospiza difficilis',
#   'alternate_names': 'acutirostris',
#   'scientific_name': 'Geospiza difficilis acutirostris'},
#  {'bird': 'Gentoo Penguin',
#   'alternate_names': ['Pygoscelis papua'],
#   'scientific_name': 'Pygoscelis papua'},
#  {'bird': 'Augastes geoffroyi',
#   'alternate_names': 'Bourcier, 1843',
#   'scientific_name': 'Augastes geoffroyi (Bourcier, 1843)'},
#  {'bird': 'Geomalia heinrichi',
#   'alternate_names': [],
#   'scientific_name': 'Geomalia heinrichi'},
#  {'bird': "Germain's peacock-pheasant",
#   'alternate_names': ['Polyplectron germaini'],
#   'scientific_name': 'Polyplectron germaini'},
#  {'bird': 'Collocalia germani',
#   'alternate_names': "German's Swiftlet, German's Swift",
#   'scientific_name': 'Collocalia germani'},
#  {'bird': 'Giant Antpitta',
#   'alternate_names': 'Grallaria gigantea',
#   'scientific_name': 'Grallariidae'},
#  {'bird': 'Giant Antshrike',
#   'alternate_names': [],
#   'scientific_name': 'Batara cinerea'},
#  {'bird': 'Ianthocincla waddelli',
#   'alternate_names': ['Babax waddelli'],
#   'scientific_name': 'Ianthocincla waddelli'},
#  {'bird': 'Oreomanes fraseri',
#   'alternate_names': 'none',
#   'scientific_name': 'Oreomanes fraseri'},
#  {'bird': 'Giant Coot',
#   'alternate_names': ['Fulica gigantea'],
#   'scientific_name': 'Fulica gigantea'},
#  {'bird': 'Giant Coua',
#   'alternate_names': ['Coua gigas'],
#   'scientific_name': 'Coua gigas'},
#  {'bird': 'Scaphidura oryzivora',
#   'alternate_names': 'none',
#   'scientific_name': 'Scaphidura oryzivora'},
#  {'bird': 'Giant Honeyeater',
#   'alternate_names': 'Duetting Giant Honeyeater',
#   'scientific_name': 'Gymnomyza brunneirostris'},
#  {'bird': 'Giant Hummingbird',
#   'alternate_names': [],
#   'scientific_name': 'Patagona gigas'},
#  {'bird': 'Pseudibis gigantea',
#   'alternate_names': 'None',
#   'scientific_name': 'Oustalet, 1877'},
#  {'bird': 'Giant Kingbird',
#   'alternate_names': [],
#   'scientific_name': 'Tyrannus cubensis'},
#  {'bird': 'Giant Kingfisher',
#   'alternate_names': 'Megaceryle maxima',
#   'scientific_name': 'Megaceryle maxima'},
#  {'bird': 'Garrulax maximus',
#   'alternate_names': 'None',
#   'scientific_name': 'Garrulax maximus'},
#  {'bird': 'giant nuthatch',
#   'alternate_names': [],
#   'scientific_name': 'Sitta magna'},
#  {'bird': 'Giant Pitta',
#   'alternate_names': ['Hydrornis caeruleus'],
#   'scientific_name': 'Pittidae'},
#  {'bird': 'Giant Scops Owl',
#   'alternate_names': ['Lesser Eagle-Owl', 'Mindanao Eagle-Owl'],
#   'scientific_name': 'Otus gurneyi',
#   'family': 'Strigidae'},
#  {'bird': 'Giant Snipe',
#   'alternate_names': [],
#   'scientific_name': 'Gallinago undulata'},
#  {'bird': 'Giant Sunbird',
#   'alternate_names': [],
#   'scientific_name': 'Dreptes thomensis'},
#  {'bird': 'Hydrochrous gigas',
#   'alternate_names': 'Hartert & Butler, 1901',
#   'scientific_name': '[orthographic error]'},
#  {'bird': 'The giant weaver',
#   'alternate_names': 'Ploceus grandis',
#   'scientific_name': 'Ploceidae'},
#  {'bird': 'The giant white-eye',
#   'alternate_names': 'Palau greater white-eye',
#   'scientific_name': 'Megazosterops palauensis'},
#  {'bird': 'Giant wood rail',
#   'alternate_names': [],
#   'scientific_name': 'Aramides ypecaha'},
#  {'bird': 'The giant wren',
#   'alternate_names': 'Campylorhynchus chiapensis',
#   'scientific_name': 'Troglodytidae'},
#  {'bird': 'gibberbird',
#   'alternate_names': 'Ashbyia lovensis',
#   'scientific_name': 'Meliphagidae family of passerine birds'},
#  {'bird': 'Gila woodpecker',
#   'alternate_names': 'Melanerpes uropygialis',
#   'scientific_name': 'Melanerpes uropygialis'},
#  {'bird': "Gilbert's honeyeater",
#   'alternate_names': ['Swan River honeyeater',
#    'western white-naped honeyeater'],
#   'scientific_name': 'Melithreptus chloropsis'},
#  {'bird': "Gilbert's whistler",
#   'alternate_names': 'none',
#   'scientific_name': 'Pachycephala inornata',
#   'endemic_to': 'Australia',
#   'habitat': 'semi-arid zones of southern Australia'},
#  {'bird': 'gilded barbet',
#   'alternate_names': ['Capito auratus'],
#   'scientific_name': 'Capitonidae'},
#  {'bird': 'The gilded flicker',
#   'alternate_names': 'Colaptes chrysoides',
#   'scientific_name': 'Colaptes chrysoides'},
#  {'bird': 'Gilded sapphire',
#   'alternate_names': 'Gilded hummingbird',
#   'scientific_name': 'Hylocharis chrysura'},
#  {'bird': 'See text', 'alternate_names': 'None', 'scientific_name': 'None'},
#  {'bird': 'Melidectes whitemanensis',
#   'alternate_names': [],
#   'scientific_name': 'Melidectes whitemanensis'},
#  {'bird': 'Tanagra cyanoventris',
#   'alternate_names': [],
#   'scientific_name': 'Vieillot, 1819[2]'},
#  {'bird': 'Gizo white-eye',
#   'alternate_names': ['yellow-billed white-eye'],
#   'scientific_name': 'Zosterops luteirostris'},
#  {'bird': 'glaucous gull',
#   'alternate_names': ['Larus hyperboreus'],
#   'scientific_name': 'Larus hyperboreus'},
#  {'bird': 'The glaucous macaw',
#   'alternate_names': 'Anodorhynchus glaucus',
#   'scientific_name': 'Anodorhynchus glaucus'},
#  {'bird': 'glaucous tanager',
#   'alternate_names': [],
#   'scientific_name': 'Thraupis glaucocolpa'},
#  {'bird': 'Passerina glaucocaerulea',
#   'alternate_names': "D'Orbigny & Lafresnaye, 1837",
#   'scientific_name': "Passerina glaucocaerulea (D'Orbigny & Lafresnaye, 1837)"},
#  {'bird': 'gull',
#   'alternate_names': 'Larus glaucescens',
#   'scientific_name': 'The glaucous-winged gull'},
#  {'bird': 'Glistening-green tanager',
#   'alternate_names': [],
#   'scientific_name': 'Chlorochrysa phoenicotis'},
#  {'bird': 'Redirect to', 'alternate_names': None, 'scientific_name': None},
#  {'bird': 'Chlorostilbon aureoventris',
#   'alternate_names': ["D'Orbigny and Lafresnaye, 1838"],
#   'scientific_name': 'Chlorostilbon aureoventris'},
#  {'bird': 'hummingbird',
#   'alternate_names': 'Chionomesa fimbriata',
#   'scientific_name': 'Trochilini of subfamily Trochilinae'},
#  {'bird': 'glossy antshrike',
#   'alternate_names': 'Sakesphorus luctuosus',
#   'scientific_name': 'Thamnophilidae, the antbirds'},
#  {'bird': 'Crow',
#   'alternate_names': ['Carrion Crow', 'Common Crow'],
#   'scientific_name': 'Corvus brachyrhynchos'},
#  {'bird': 'flowerpiercer',
#   'alternate_names': ['Diglossa lafresnayii'],
#   'scientific_name': 'Thraupidae'},
#  {'bird': 'glossy ibis',
#   'alternate_names': ['Plegadis falcinellus'],
#   'scientific_name': 'Threskiornithidae'},
#  {'bird': 'Hirundo esculenta',
#   'alternate_names': [],
#   'scientific_name': 'Linnaeus, 1758'},
#  {'bird': 'Muscicapa surinama',
#   'alternate_names': [],
#   'scientific_name': 'Linnaeus, 1766'},
#  {'bird': 'Muscicapa divaricata',
#   'alternate_names': ['Dicrurus adsimilis divaricatus'],
#   'scientific_name': 'Muscicapa divaricata'},
#  {'bird': 'Turdus serranus',
#   'alternate_names': ['unicolor', 'Olrog & Contino, 1970'],
#   'scientific_name': 'Turdus serranus unicolor Olrog & Contino, 1970 (non Tickell, 1833: preoccupied)'},
#  {'bird': 'Manucode',
#   'alternateNames': ['Manucodia ater'],
#   'scientificName': 'Manucodia ater'},
#  {'Bird': 'Puffleg',
#   'Alternate Names': 'None',
#   'Scientific Name': 'Eriocnemis vestita'},
#  {'Bird': 'Glow-throated Hummingbird',
#   'Alternate Names': 'None',
#   'Scientific Name': 'Selasphorus ardens'},
#  {'bird': "Godlewski's bunting",
#   'alternate_names': ['Emberiza godlewskii'],
#   'scientific_name': 'Emberizidae'},
#  {'bird': 'Myrmeciza goeldii',
#   'alternate_names': 'none',
#   'scientific_name': 'Myrmeciza goeldii'},
#  {'bird': 'Gola malimbe',
#   'alternate_names': "Ballman's malimbe",
#   'scientific_name': 'Malimbus ballmanni'},
#  {'bird': 'goldcrest',
#   'alternate_names': 'Regulus regulus',
#   'scientific_name': 'Kinglet family'},
#  {'bird': 'The golden babbler',
#   'alternate_names': 'Cyanoderma chrysaeum',
#   'scientific_name': 'Timaliidae'},
#  {'bird': 'golden bowerbird',
#   'alternate_names': 'Prionodura newtoniana',
#   'scientific_name': 'Ptilonorhynchidae'},
#  {'bird': 'Golden Bush Robin',
#   'alternate_names': ['Golden Bush-Robin'],
#   'scientific_name': 'Tarsiger chrysaeus'},
#  {'bird': 'The golden cuckooshrike',
#   'alternate_names': 'Campochaera sloetii',
#   'scientific_name': 'Campephagidae'},
#  {'bird': '6', 'alternate_names': 'see text', 'scientific_name': 'N/A'},
#  {'bird': 'golden fruit dove',
#   'alternate_names': ['lemon dove', 'yellow dove'],
#   'scientific_name': 'Ptilinopus luteovirens'},
#  {'bird': 'Genus', 'alternate_names': [], 'scientific_name': 'Genus'},
#  {'bird': 'Golden Grosbeak',
#   'alternate_names': ['Golden-bellied Grosbeak', 'Southern Yellow Grosbeak'],
#   'scientific_name': 'Pheucticus chrysogaster'},
#  {'bird': 'Barn Owl',
#   'alternate_names': ['Tyto aurantia'],
#   'scientific_name': 'Tyto aurantia'},
#  {'bird': 'See text', 'alternate_names': 'None', 'scientific_name': 'None'},
#  {'bird': 'Golden Myna',
#   'alternate_names': ['Mino anais'],
#   'scientific_name': 'Sturnidae'},
#  {'bird': 'golden nightjar',
#   'alternate_names': 'Caprimulgus eximius',
#   'scientific_name': 'Caprimulgidae'},
#  {'bird': 'The golden palm weaver',
#   'alternate_names': 'Ploceus bojeri',
#   'scientific_name': 'Ploceidae'},
#  {'bird': 'Guarouba',
#   'alternate_names': ['Psittacus guarouba', 'Aratinga guarouba'],
#   'scientific_name': 'Psittacidae'},
#  {'bird': 'Paradoxornis verreauxi',
#   'alternate_names': "Verreaux's Parrotbill, White-browed Parrotbill",
#   'scientific_name': 'Paradoxornis verreauxi'},
#  {'bird': 'Phasianus pictus',
#   'alternate_names': 'none',
#   'scientific_name': 'Linnaeus, 1758'},
#  {'bird': 'The golden pipit',
#   'alternate_names': 'Tmetothylacus tenellus',
#   'scientific_name': 'Tmetothylacus tenellus'},
#  {'bird': 'Hirundo sclateri',
#   'alternate_names': [],
#   'scientific_name': 'Cory, 1884'},
#  {'bird': 'golden tanager',
#   'alternate_names': [],
#   'scientific_name': 'Tangara arthus',
#   'family': 'Thraupidae'},
#  {'bird': 'The golden vireo',
#   'alternate_names': 'Vireo hypochryseus',
#   'scientific_name': 'Vireonidae'},
#  {'bird': 'Ptilotis marchei',
#   'alternate_names': [],
#   'scientific_name': 'Ptilotis marchei'},
#  {'bird': 'The golden-backed bishop',
#   'alternate_names': 'Euplectes aureus',
#   'scientific_name': 'Ploceidae'},
#  {'bird': 'Buthraupis aureodorsalis',
#   'alternate_names': 'Golden-browed Chlorophonia, Chlorophonia aureodorsalis',
#   'scientific_name': 'Buthraupis aureodorsalis'},
#  {'bird': 'The golden-backed weaver',
#   'alternate_names': "Jackson's weaver",
#   'scientific_name': 'Ploceus jacksoni'},
#  {'bird': 'The golden-backed whistler',
#   'alternate_names': ['yellow-backed whistler'],
#   'scientific_name': 'Pachycephala aurea'},
#  {'bird': 'golden-bellied flycatcher',
#   'alternate_names': ['Myiodynastes hemichrysus'],
#   'scientific_name': 'Myiodynastes hemichrysus'},
#  {'bird': 'flyrobin',
#   'alternate_names': ['Microeca hemixantha'],
#   'scientific_name': 'Petroicidae'},
#  {'bird': 'Gerygone sulphurea',
#   'alternate_names': 'Golden-bellied Gerygone',
#   'scientific_name': 'Gerygone sulphurea'},
#  {'bird': 'starfrontlet',
#   'alternate_names': ['Coeligena bonapartei'],
#   'scientific_name': 'Coeligena bonapartei'},
#  {'bird': 'Golden-bellied Warbler',
#   'alternate_names': [],
#   'scientific_name': 'Setophaga chrysoparia'},
#  {'bird': 'The golden-bellied white-eye',
#   'alternate_names': ['Zosterops uropygialis'],
#   'scientific_name': 'Zosteropidae'},
#  {'bird': 'golden-billed saltator',
#   'alternate_names': ['Saltator aurantiirostris'],
#   'scientific_name': 'Saltator aurantiirostris'},
#  {'bird': 'golden-breasted bunting',
#   'alternateNames': ['Emberiza flaviventris'],
#   'scientificName': 'Emberizidae'},
#  {'bird': 'The golden-breasted fruiteater',
#   'alternate_names': 'Pipreola aureopectus',
#   'scientific_name': 'Cotingidae'},
#  {'bird': 'The golden-breasted fulvetta',
#   'alternate_names': 'Lioparus chrysotis',
#   'scientific_name': 'Lioparus chrysotis'},
#  {'bird': 'The golden-breasted puffleg',
#   'alternate_names': 'Eriocnemis mosquera',
#   'scientific_name': 'Heliantheini in subfamily Lesbiinae'},
#  {'bird': 'The golden-breasted starling',
#   'alternate_names': 'royal starling',
#   'scientific_name': 'Lamprotornis regius'},
#  {'bird': 'Golden-browed chat-tyrant',
#   'alternate_names': ['Silvicultrix pulchella'],
#   'scientific_name': 'Tyrannidae'},
#  {'bird': 'The golden-browed chlorophonia',
#   'alternate_names': 'Chlorophonia callophrys',
#   'scientific_name': 'Fringillidae'},
#  {'bird': 'golden-browed warbler',
#   'alternate_names': 'Basileuterus belli',
#   'scientific_name': 'Parulidae, the New World warblers'},
#  {'bird': 'Aratinga auricapilla',
#   'alternate_names': 'none',
#   'scientific_name': 'Kuhl, 1820'},
#  {'bird': 'Dendroica chrysoparia',
#   'alternate_names': 'Sclater & Salvin, 1861',
#   'scientific_name': 'Dendroica chrysoparia Sclater & Salvin, 1861'},
#  {'bird': 'golden-cheeked woodpecker',
#   'alternate_names': 'Melanerpes chrysogenys',
#   'scientific_name': 'Picinae of the woodpecker family Picidae'},
#  {'bird': 'golden-chested tanager',
#   'alternate_names': [],
#   'scientific_name': 'Bangsia rothschildi'},
#  {'bird': 'golden-chevroned tanager',
#   'alternate_names': [],
#   'scientific_name': 'Thraupis ornata'},
#  {'bird': 'golden-collared honeycreeper',
#   'alternate_names': ['Iridophanes pulcherrimus'],
#   'scientific_name': 'Iridophanes pulcherrimus'},
#  {'bird': 'macaw',
#   'alternate_names': ['golden-collared macaw', 'yellow-collared macaw'],
#   'scientific_name': 'Primolius auricollis'},
#  {'bird': 'golden-collared manakin',
#   'alternate_names': 'Manacus vitellinus',
#   'scientific_name': 'Pipridae'},
#  {'bird': 'golden-collared tanager',
#   'alternate_names': [],
#   'scientific_name': 'Iridosornis jelskii'},
#  {'bird': 'See text', 'alternate_names': 'None', 'scientific_name': 'None'},
#  {'bird': 'Dryobates cassini',
#   'alternate_names': 'None',
#   'scientific_name': 'Dryobates cassini'},
#  {'bird': 'golden-crested myna',
#   'alternate_names': ['Ampeliceps coronatus'],
#   'scientific_name': 'Sturnidae'},
#  {'bird': 'The golden-crowned babbler',
#   'alternate_names': 'None',
#   'scientific_name': 'Sterrhoptilus dennistouni'},
#  {'bird': 'Trochilus auriceps',
#   'alternate_names': ['Chlorostilbon auriceps'],
#   'scientific_name': 'Trochilus auriceps'},
#  {'bird': 'The golden-crowned flycatcher',
#   'alternate_names': 'Myiodynastes chrysocephalus',
#   'scientific_name': 'Tyrannidae'},
#  {'bird': 'golden-crowned kinglet',
#   'alternate_names': 'Regulus satrapa',
#   'scientific_name': 'Regulidae'},
#  {'bird': 'Pipra vilasboasi',
#   'alternate_names': [],
#   'scientific_name': 'Sick, 1959'},
#  {'bird': 'golden-crowned spadebill',
#   'alternate_names': [],
#   'scientific_name': 'Platyrinchus coronatus'},
#  {'bird': 'Emberiza atricapilla',
#   'alternate_names': 'Gmelin, 1789 Zonotrichia coronata Pallas, 1844',
#   'scientific_name': 'Emberiza atricapilla Gmelin, 1789 Zonotrichia coronata Pallas, 1844'},
#  {'bird': 'golden-crowned tanager',
#   'alternate_names': [],
#   'scientific_name': 'Iridosornis rufivertex'},
#  {'bird': 'golden-crowned warbler',
#   'alternate_names': 'Basileuterus culicivorus',
#   'scientific_name': 'Basileuterus culicivorus'},
#  {'bird': 'The golden-eared tanager',
#   'alternate_names': 'Tangara chrysotis',
#   'scientific_name': 'Thraupidae'},
#  {'bird': 'Diglossopis glauca',
#   'alternate_names': 'None',
#   'scientific_name': 'Diglossopis glauca'},
#  {'bird': 'Goldenface',
#   'alternate_names': 'Pachycare flavogriseum',
#   'scientific_name': 'Pachycare flavogriseum'},
#  {'bird': 'The golden-faced tyrannulet',
#   'alternate_names': 'Zimmerius chrysops',
#   'scientific_name': 'Tyrannidae'},
#  {'bird': 'golden-fronted bowerbird',
#   'alternate_names': 'Amblyornis flavifrons',
#   'scientific_name': 'Amblyornis flavifrons'},
#  {'bird': 'golden-fronted fulvetta',
#   'alternate_names': ['gold-fronted fulvetta'],
#   'scientific_name': 'Schoeniparus variegaticeps'},
#  {'bird': 'Hylophilus aurantiifrons',
#   'alternate_names': [],
#   'scientific_name': 'Hylophilus aurantiifrons'},
#  {'bird': 'Golden-fronted Leafbird',
#   'alternate_names': 'Chloropsis aurifrons',
#   'scientific_name': 'Chloropsis aurifrons'},
#  {'bird': 'golden-fronted whitestart',
#   'alternate_names': ['golden-fronted redstart'],
#   'scientific_name': 'Myioborus ornatus',
#   'family': 'Parulidae'},
#  {'bird': 'golden-fronted woodpecker',
#   'alternate_names': 'Melanerpes aurifrons',
#   'scientific_name': 'Picinae of the woodpecker family Picidae'},
#  {'bird': 'golden-green woodpecker',
#   'alternateNames': 'Piculus chrysochloros',
#   'scientificName': 'Picinae of the woodpecker family Picidae'},
#  {'bird': 'The golden-headed cisticola',
#   'alternate_names': 'bright-capped cisticola',
#   'scientific_name': 'Cisticola exilis'},
#  {'bird': 'The golden-headed manakin',
#   'alternate_names': 'Ceratopipra erythrocephala',
#   'scientific_name': 'Ceratopipra erythrocephala'},
#  {'bird': 'golden-headed quetzal or corequenque',
#   'alternate_names': ['Trogon auriceps'],
#   'scientific_name': 'Pharomachrus auriceps'},
#  {'bird': 'golden-hooded tanager',
#   'alternate_names': 'Stilpnia larvata',
#   'scientific_name': 'Stilpnia larvata'},
#  {'bird': 'Golden-mantled Racket-tail',
#   'alternate_names': ['Prioniturus platurus'],
#   'scientific_name': 'Psittaculidae'},
#  {'bird': 'Megalaima pulcherrimus',
#   'alternate_names': 'None',
#   'scientific_name': 'Megalaima pulcherrimus'},
#  {'bird': 'golden-naped finch',
#   'alternate_names': 'Pyrrhoplectes epauletta',
#   'scientific_name': 'Fringillidae'},
#  {'bird': 'golden-naped tanager',
#   'alternate_names': [],
#   'scientific_name': 'Chalcothraupis ruficervix'},
#  {'bird': 'The golden-naped weaver',
#   'alternate_names': 'Ploceus aureonucha',
#   'scientific_name': 'Ploceidae'},
#  {'bird': 'The golden-naped woodpecker',
#   'alternate_names': 'Melanerpes chrysauchen',
#   'scientific_name': 'Picidae'},
#  {'bird': 'golden-olive woodpecker',
#   'alternate_names': 'Colaptes rubiginosus',
#   'scientific_name': 'Picinae of the woodpecker family Picidae'},
#  {'bird': 'golden-plumed parakeet',
#   'alternate_names': 'Leptosittaca branickii',
#   'scientific_name': 'Psittacidae, Leptosittaca'},
#  {'bird': 'Euphonia cyanocephala',
#   'alternate_names': '',
#   'scientific_name': 'Euphonia cyanocephala'},
#  {'bird': 'golden-rumped flowerpecker',
#   'alternate_names': 'Dicaeum annae',
#   'scientific_name': 'Dicaeidae'},
#  {'bird': 'Psephotus chrysopterygius',
#   'alternate_names': [],
#   'scientific_name': 'Psephotus chrysopterygius'},
#  {'bird': 'The golden-sided euphonia',
#   'alternate_names': 'Euphonia cayennensis',
#   'scientific_name': 'Fringillidae'},
#  {'bird': 'golden-spangled piculet',
#   'alternate_names': ['Picumnus exilis'],
#   'scientific_name': 'Picumnus exilis'},
#  {'bird': 'Golden-spotted ground dove',
#   'alternate_names': 'Metriopelia aymara',
#   'scientific_name': 'Columbidae'},
#  {'bird': 'Touit',
#   'alternate_names': ['surda', 'lapsus'],
#   'scientific_name': 'Touit surda'},
#  {'bird': 'Amazilia oenone',
#   'alternate_names': [],
#   'scientific_name': 'Amazilia oenone[3]'},
#  {'bird': 'Chrysoptilus abingoni',
#   'alternate_names': [],
#   'scientific_name': 'Chrysoptilus abingoni'},
#  {'bird': 'Cyanops ramsayi',
#   'alternate_names': 'Megalaima franklinii',
#   'scientific_name': 'Cyanops ramsayiMegalaima franklinii'},
#  {'bird': 'The golden-tufted mountain grackle',
#   'alternate_names': 'golden-tufted grackle',
#   'scientific_name': 'Macroagelaius imthurni',
#   'family': 'Icteridae'},
#  '\n\n{\n  "bird": "Megalaima chrysopogon",\n  "alternate_names": "Asian Barred Owlet, Barred Owlet, Brown-cheeked Owlet, Brown-cheeked Wood-Owlet, Brown-cheeked Wood-Owl, Brown-cheeked Wood-owl, Brown-cheeked Woodowlet, Brown-cheeked Woodowl, Brown-cheeked Woodpecker-Owl, Brown-cheeked Woodpecker-owl, Brown-cheeked Woodpecker-Owlet, Brown-cheeked Woodpecker-owlet, Brown-cheeked Woodpecker-owl, Brown-cheeked Woodpecker-owl, Brown-cheeked Woodpecker-owl, Brown-cheeked Woodpecker-owl, Brown-cheeked Woodpecker-owl, Brown-cheeked Woodpecker-owl, Brown-cheeked Woodpecker-owl, Brown-cheeked Woodpecker-owl, Brown-cheeked Woodpecker-owl, Brown-cheeked Woodpecker-owl, Brown-cheeked Woodpecker-owl, Brown-cheeked Woodpecker-owl, Brown-cheeked Woodpecker-owl, Brown-cheeked Woodpecker-owl, Brown-cheeked Woodpecker-owl, Brown-cheeked Woodpecker-owl, Brown-cheeked Woodpecker-owl, Brown-cheeked Woodpecker-owl, Brown-cheeked Woodpecker-owl, Brown-cheeked Woodpecker-owl, Brown-cheeked Woodpecker-owl, Brown-cheeked Woodpecker-owl, Brown-cheeked Woodpecker-owl, Brown-cheeked Woodpecker-owl, Brown-cheeked Woodpecker-owl, Brown-cheeked Woodpecker-owl, Brown-cheeked Woodpecker-owl, Brown-cheeked Woodpecker-owl, Brown-cheeked Woodpecker-owl, Brown-cheeked Woodpecker-owl, Brown-cheeked Woodpecker-owl, Brown-cheeked Woodpecker-owl, Brown-cheeked Wood',
#  {'bird': 'The golden-winged cacique',
#   'alternate_names': 'Cacicus chrysopterus',
#   'scientific_name': 'Icteridae'},
#  {'bird': 'Garrulax ngoclinhensis',
#   'alternate_names': [],
#   'scientific_name': 'Garrulax ngoclinhensis'},
#  {'bird': 'golden-winged manakin',
#   'alternate_names': 'Masius chrysopterus',
#   'scientific_name': 'Pipridae'},
#  {'bird': 'Psittacus chrysopterus',
#   'alternateNames': [],
#   'scientificName': 'Linnaeus, 1766'},
#  {'bird': 'golden-winged sparrow',
#   'alternate_names': 'Arremon schlegeli',
#   'scientific_name': 'Passerellidae'},
#  {'bird': 'The golden-winged sunbird',
#   'alternate_names': 'Drepanorhynchus reichenowi',
#   'scientific_name': 'Nectariniidae'},
#  {'bird': 'The golden-winged tody-flycatcher',
#   'alternateNames': ['Poecilotriccus calopterus'],
#   'scientificName': 'Poecilotriccus calopterus'},
#  {'bird': 'golden-winged warbler',
#   'alternate_names': 'Vermivora chrysoptera',
#   'scientific_name': 'New World warbler'},
#  {'bird': "Goldie's bird-of-paradise",
#   'alternateNames': 'Paradisaea decora',
#   'scientificName': 'Paradisaea decora'},
#  {'bird': 'lorikeet',
#   'alternate_names': ['Glossoptilus goldiei'],
#   'scientific_name': 'Psittaculidae'},
#  {'bird': "Goldman's warbler",
#   'alternate_names': 'Setophaga goldmani',
#   'scientific_name': 'Parulidae'},
#  {'bird': 'gold-ringed tanager',
#   'alternate_names': [],
#   'scientific_name': 'Bangsia aureocincta'},
#  {'bird': 'Goliath Coucal',
#   'alternate_names': [],
#   'scientific_name': 'Centropus goliath'},
#  {'bird': 'Garza goliath',
#   'alternate_names': 'Goliath Heron, Giant Heron',
#   'scientific_name': 'Ardea goliath'},
#  {'bird': 'Goliath Imperial Pigeon',
#   'alternate_names': ['New Caledonian Imperial Pigeon', 'Notou'],
#   'scientific_name': 'Ducula goliath'},
#  {'bird': 'Telophorus quadricolor',
#   'alternate_names': [],
#   'scientific_name': 'Telophorus quadricolor'},
#  {'bird': 'Gorgeted puffleg',
#   'alternate_names': 'None',
#   'scientific_name': 'Eriocnemis isabellae'},
#  {'Bird': 'Gorgeted Sunangel',
#   'Alternate Names': 'Heliangelus Strophianus',
#   'Scientific Name': 'Heliangelus Strophianus'},
#  {'bird': 'gorgeted wood quail',
#   'alternate_names': ['Odontophorus strophium'],
#   'scientific_name': 'Odontophorus strophium'},
#  {'bird': 'Acestrura heliodor',
#   'alternate_names': [],
#   'scientific_name': 'Acestrura heliodor[3]'},
#  {'bird': "Gosling's Apalis",
#   'alternate_names': 'Apalis goslingi',
#   'scientific_name': 'Cisticolidae'},
#  {'bird': "Gosling's bunting",
#   'alternate_names': ['grey-throated bunting'],
#   'scientific_name': 'Emberiza goslingi'},
#  {'bird': 'Nesospiza goughensis',
#   'alternate_names': ['Nesospiza jessiae'],
#   'scientific_name': 'Nesospiza goughensis (protonym)'},
#  {'bird': 'Gough moorhen',
#   'alternate_names': ['common moorhen'],
#   'scientific_name': 'Gallinula comeri'},
#  {'bird': 'Gouldian finch',
#   'alternate_names': ['Lady Gouldian finch', "Gould's finch", 'rainbow finch'],
#   'scientific_name': 'Chloebia gouldiae'},
#  {'bird': 'hummingbird',
#   'alternate_names': "Gould's emerald",
#   'scientific_name': 'Riccordia elegans',
#   'family': 'Trochilidae'},
#  {'bird': "Gould's frogmouth",
#   'alternate_names': 'Batrachostomus stellatus',
#   'scientific_name': 'Podargidae'},
#  {'bird': "Gould's jewelfront",
#   'alternate_names': "Gould's brilliant",
#   'scientific_name': 'Heliodoxa aurescens',
#   'family': 'Trochilidae'},
#  {'bird': 'Redirect to', 'alternate_names': None, 'scientific_name': None},
#  {'bird': "Gould's petrel",
#   'alternate_names': 'Pterodroma leucoptera',
#   'scientific_name': 'Procellariidae'},
#  {'bird': 'Brachypteryx stellatus',
#   'alternate_names': [],
#   'scientific_name': 'Brachypteryx stellatus'},
#  {'bird': "Gould's toucanet",
#   'alternate_names': 'Selenidera gouldii',
#   'scientific_name': 'Ramphastidae'},
#  {'bird': 'honeyeater',
#   'alternate_names': ['Microptilotis gracilis'],
#   'scientific_name': 'Microptilotis gracilis'},
#  {'bird': 'pitta',
#   'alternate_names': ['black-crowned pitta'],
#   'scientific_name': 'Erythropitta venusta'},
#  {'bird': 'Prinia gracilis',
#   'alternate_names': 'Graceful Warbler',
#   'scientific_name': 'Prinia gracilis'},
#  {'bird': "Grace's warbler",
#   'alternate_names': 'Setophaga graciae',
#   'scientific_name': 'Setophaga graciae'},
#  {'bird': 'Fringilla teydea',
#   'alternate_names': ['Polatzeki'],
#   'scientific_name': 'Hartert 1905'},
#  {'bird': 'Grand Comoro brush warbler',
#   'alternate_names': 'Nesillas brevicaudata',
#   'scientific_name': 'Acrocephalidae'},
#  {'bird': 'Grand Comoro bulbul',
#   'alternate_names': 'Hypsipetes parvirostris',
#   'scientific_name': 'Pycnonotidae'},
#  {'bird': 'Grand Comoro drongo',
#   'alternate_names': 'Dicrurus fuscipennis',
#   'scientific_name': 'Dicruridae'},
#  {'bird': 'grand rhabdornis',
#   'alternate_names': ['long-billed rhabdornis', 'long-billed creeper'],
#   'scientific_name': 'Rhabdornis grandis'},
#  {'bird': 'Grandala',
#   'alternate_names': ['Grandala coelicolor'],
#   'scientific_name': 'Turdidae'},
#  {'bird': "Grant's bluebill",
#   'alternate_names': 'Spermophaga poliogenys',
#   'scientific_name': 'Estrildid Finch'},
#  {'bird': 'Redirect to', 'alternate_names': None, 'scientific_name': None},
#  {'bird': 'Grass Wren',
#   'alternate_names': [],
#   'scientific_name': 'Cistothorus platensis'},
#  {'bird': 'grass-green tanager',
#   'alternate_names': [],
#   'scientific_name': 'Chlorornis riefferii'},
#  {'bird': 'grasshopper buzzard',
#   'alternate_names': [],
#   'scientific_name': 'Butastur rufipennis'},
#  {'bird': 'Coturniculus savannarum',
#   'alternate_names': [],
#   'scientific_name': 'Coturniculus savannarum'},
#  {'bird': 'Grassland Sparrow',
#   'alternate_names': 'Ammodramus humeralis',
#   'scientific_name': 'Passerellidae'},
#  {'bird': 'Sicalis luteiventris',
#   'alternate_names': [],
#   'scientific_name': 'Sicalis luteiventris'},
#  {'bird': "Grauer's broadbill",
#   'alternate_names': 'African green broadbill',
#   'scientific_name': 'Pseudocalyptomena graueri'},
#  {'bird': 'Coracina graueri',
#   'alternate_names': [],
#   'scientific_name': 'Coracina graueri'},
#  {'bird': "Grauer's swamp warbler",
#   'alternate_names': 'Bradypterus graueri',
#   'scientific_name': 'Locustellidae'},
#  {'bird': "Grauer's warbler",
#   'alternate_names': [],
#   'scientific_name': 'Graueria vittata'},
#  {'bird': 'Molothrus badius',
#   'alternate_names': 'None',
#   'scientific_name': 'Vieillot, 1819'},
#  {'bird': 'gray-barred wren',
#   'alternate_names': 'Campylorhynchus megalopterus',
#   'scientific_name': 'Troglodytidae'},
#  {'bird': 'Galeoscoptes',
#   'alternate_names': [],
#   'scientific_name': 'Galeoscoptes Cabanis, 1850'},
#  {'bird': 'Asturina plagiata',
#   'alternate_names': ['Buteo nitidus plagiatus', 'Asturina nitida plagiata'],
#   'scientific_name': 'Asturina plagiata'},
#  {'bird': 'gray kingbird',
#   'alternate_names': ['pitirre', 'petchary', 'white-breasted kingbird'],
#   'scientific_name': 'Tyrannus dominicensis'},
#  {'bird': 'gray thrasher',
#   'alternate_names': [],
#   'scientific_name': 'Toxostoma cinereum'},
#  {'bird': 'gray vireo',
#   'alternate_names': ['Vireo vicinior'],
#   'scientific_name': 'Vireo vicinior'},
#  {'bird': 'Linaria tephrocotis',
#   'alternate_names': "Swainson's Linnet, Swainson's Linaria",
#   'scientific_name': 'Linaria tephrocotis Swainson, 1831[2]'},
#  {'bird': 'gray-headed kite',
#   'alternate_names': 'Leptodon cayanensis',
#   'scientific_name': 'Leptodon cayanensis'},
#  {'bird': 'Asturina nitida',
#   'alternate_names': 'None',
#   'scientific_name': 'Asturina nitida'},
#  {'bird': 'Locustella fasciolata',
#   'alternate_names': [],
#   'scientific_name': 'Locustella fasciolata'},
#  {'bird': 'See text', 'alternate_names': 'None', 'scientific_name': 'None'},
#  {'bird': 'gray-throated warbling finch',
#   'alternate_names': ['Microspingus cabanisi'],
#   'scientific_name': 'Thraupidae'},
#  {'bird': 'The great antpitta',
#   'alternate_names': 'Grallaria excelsa',
#   'scientific_name': 'Grallariidae'},
#  {'bird': 'antshrike',
#   'alternate_names': ['Taraba major'],
#   'scientific_name': 'Thamnophilidae'},
#  {'bird': 'argus',
#   'alternate_names': 'Argusianus argus',
#   'scientific_name': 'Argusianus argus'},
#  {'bird': 'The great auk',
#   'alternateNames': ['Pinguinus impennis'],
#   'scientificName': 'Pinguinus impennis'},
#  {'bird': 'Great barbet',
#   'alternate_names': 'Psilopogon virens',
#   'scientific_name': 'Psilopogon virens'},
#  {'bird': 'great black hawk',
#   'alternate_names': ['Buteogallus urubitinga'],
#   'scientific_name': 'Accipitridae'},
#  {'bird': 'Great black-backed gull',
#   'alternate_names': ['Larus marinus'],
#   'scientific_name': 'Larus marinus'},
#  {'bird': 'The great blue heron',
#   'alternate_names': 'Ardea herodias',
#   'scientific_name': 'Ardeidae'},
#  {'bird': 'The great blue turaco',
#   'alternate_names': ['Corythaeola cristata'],
#   'scientific_name': 'Musophagidae'},
#  {'bird': 'Great Bowerbird',
#   'alternate_names': 'Chlamydera nuchalis',
#   'scientific_name': 'Chlamydera nuchalis'},
#  {'bird': 'The great bustard',
#   'alternate_names': ['Otis tarda'],
#   'scientific_name': 'Otis tarda'},
#  {'bird': 'Pelecanus carbo',
#   'alternate_names': [],
#   'scientific_name': 'Linnaeus, 1758'},
#  {'bird': 'Turdus crinitus',
#   'alternate_names': [],
#   'scientific_name': 'Linnaeus, 1758'},
#  {'bird': 'Colymbus cristatus',
#   'alternate_names': [],
#   'scientific_name': 'Linnaeus, 1758'},
#  {'bird': 'cuckoo-dove',
#   'alternate_names': ['Reinwardtoena reinwardti'],
#   'scientific_name': 'Reinwardtoena reinwardti'},
#  {'bird': 'The great curassow',
#   'alternate_names': 'Crax rubra',
#   'scientific_name': 'Crax rubra'},
#  {'bird': 'Aerornis senex',
#   'alternate_names': [],
#   'scientific_name': 'Aerornis senex[2]'},
#  {'bird': 'Great eared nightjar',
#   'alternate_names': ['Lyncornis macrotis'],
#   'scientific_name': 'Caprimulgidae'},
#  {'bird': 'The great egret',
#   'alternate_names': ['common egret',
#    'large egret',
#    'great white egret',
#    'great white heron'],
#   'scientific_name': 'Ardea alba'},
#  {'bird': 'See text', 'alternate_names': 'None', 'scientific_name': 'None'},
#  {'bird': 'Pelecanus minor',
#   'alternate_names': 'Gmelin 1789, Tachypetes palmerstoni',
#   'scientific_name': 'Pelecanus minor Gmelin 1789'},
#  {'bird': 'Podicephorus major',
#   'alternate_names': ['Boddaert 1783', 'Bochenski 1994'],
#   'scientific_name': 'Podicephorus major (Boddaert 1783) Bochenski 1994'},
#  {'bird': 'Ara ambiguus',
#   'alternate_names': ['Ara ambiguus ambiguus', 'Ara ambiguus guayaquilensis'],
#   'scientific_name': 'Ara ambiguus'},
#  {'bird': 'Great Grey Owl',
#   'alternateNames': ['Great Gray Owl'],
#   'scientificName': 'Strix nebulosa'},
#  {'bird': 'See text', 'alternate_names': 'None', 'scientific_name': 'None'},
#  {'bird': 'The great hanging parrot',
#   'alternate_names': ['Celebes hanging parrot',
#    'Sulawesi hanging parrot',
#    'maroon-rumped hanging parrot'],
#   'scientific_name': 'Loriculus stigmatus'},
#  {'bird': 'Buceros homrai',
#   'alternate_names': ['Dichoceros bicornis',
#    'Homraius bicornis',
#    'Dichoceros cavatus',
#    'Buceros cavatus',
#    'Buceros cristatus'],
#   'scientific_name': 'Buceros homrai'},
# ...
#   'scientific_name': 'Ortalis cinereiceps'},
#  {'bird': 'Parus cinctus',
#   'alternate_names': ['Poecile cincta'],
#   'scientific_name': 'Parus cinctus'},
#  {'bird': 'Coracina schisticeps',
#   'alternate_names': 'None',
#   'scientific_name': 'Coracina schisticeps'},
#  {'bird': 'grey-headed dove',
#   'alternate_names': ['Leptotila plumbeiceps'],
#   'scientific_name': 'Leptotila plumbeiceps'},
#  {'bird': 'Grey-headed Fish Eagle',
#   'alternate_names': 'Haliaeetus ichthyaetus',
#   'scientific_name': 'Haliaeetus ichthyaetus'},
#  {'bird': 'Grey-headed fruit dove',
#   'alternate_names': 'Ptilinopus hyogastrus',
#   'scientific_name': 'Columbidae'},
#  {'bird': 'grey-headed goshawk',
#   'alternate_names': 'Accipiter poliocephalus',
#   'scientific_name': 'Accipitridae'},
#  {'bird': 'Grey-headed Greenbul',
#   'alternate_names': ['Grey-headed Yellow-bellied Greenbul'],
#   'scientific_name': 'Phyllastrephus poliocephalus'},
#  {'bird': 'Larus cirrocephalus',
#   'alternate_names': [],
#   'scientific_name': 'Larus cirrocephalus'},
#  {'bird': 'Lichenostomus keartlandi',
#   'alternate_names': None,
#   'scientific_name': 'Lichenostomus keartlandi'},
#  {'bird': 'imperial pigeon',
#   'alternate_names': 'Ducula radiata',
#   'scientific_name': 'Columbidae'},
#  {'bird': 'Grey-headed Kingfisher',
#   'alternate_names': 'Halcyon leucocephala',
#   'scientific_name': 'Halcyon leucocephala'},
#  {'bird': 'Hoplopterus cinereus',
#   'alternate_names': ['Microsarcops cinereus', 'Pluvianus cinereus'],
#   'scientific_name': 'Blyth, 1842'},
#  {'bird': 'lovebird',
#   'alternate_names': ['gray-headed lovebird', 'Madagascar lovebird'],
#   'scientific_name': 'Agapornis canus'},
#  {'bird': 'mannikin or munia',
#   'alternate_names': ['grey-headed mannikin', 'grey-headed munia'],
#   'scientific_name': 'Lonchura caniceps'},
#  {'bird': 'Grey-headed Nigrita',
#   'alternate_names': ['Nigrita canicapillus'],
#   'scientific_name': 'Nigrita canicapillus'},
#  {'bird': 'grey-headed oliveback',
#   'alternate_names': ['white-cheeked oliveback'],
#   'scientific_name': 'Delacourella capistrata'},
#  {'bird': 'Grey-headed parakeet',
#   'alternate_names': ['Slaty-headed parakeet'],
#   'scientific_name': 'Psittacula finschii'},
#  {'bird': 'Grey-headed Parrotbill',
#   'alternate_names': 'Psittiparus gularis',
#   'scientific_name': 'Sylviidae'},
#  {'bird': 'Grey-headed piprites',
#   'alternate_names': ['Piprites griseiceps'],
#   'scientific_name': 'Piprites griseiceps'},
#  {'bird': 'grey-headed robin',
#   'alternate_names': ['Heteromyias cinereifrons'],
#   'scientific_name': 'Petroicidae'},
#  {'bird': 'Odontospiza griseicapilla',
#   'alternate_names': 'Lonchura griseicapilla',
#   'scientific_name': 'Odontospiza griseicapilla'},
#  {'bird': 'grey-headed spinetail',
#   'alternate_names': 'Cranioleuca semicinerea',
#   'scientific_name': 'Furnariidae'},
#  {'bird': 'Deleornis fraseri axillaris',
#   'alternate_names': ['Anthreptes axillaris', 'Anthreptes fraseri axillaris'],
#   'scientific_name': 'Deleornis fraseri axillaris'},
#  {'bird': 'Porphyrio porphyrio',
#   'alternate_names': ['Purple Swamphen', 'Pūkeko'],
#   'scientific_name': 'Porphyrio porphyrio poliocephalus'},
#  {'bird': 'grey-headed tanager',
#   'alternate_names': [],
#   'scientific_name': 'Eucometis penicillata'},
#  {'bird': 'Myiothlypis griseiceps',
#   'alternate_names': 'None',
#   'scientific_name': 'Myiothlypis griseiceps'},
#  {'bird': 'Grey-headed woodpecker',
#   'alternate_names': 'Grey-faced woodpecker',
#   'scientific_name': 'Picus canus'},
#  {'bird': 'Attila rufus',
#   'alternate_names': 'Grey-hooded Attila',
#   'scientific_name': 'Tyrannidae'},
#  {'bird': 'grey-hooded bush tanager',
#   'alternate_names': 'Cnemoscopus rubrirostris',
#   'scientific_name': 'Thraupidae'},
#  {'bird': 'Grey-hooded Flycatcher',
#   'alternateNames': ['Mionectes rufiventris'],
#   'scientificName': 'Tyrannidae'},
#  {'bird': 'Alcippe cinereiceps',
#   'alternate_names': 'Grey-capped Wood-Warbler, Grey-headed Wren-Warbler',
#   'scientific_name': 'Alcippe cinereiceps'},
#  {'bird': 'Bolborhynchus aymara',
#   'alternate_names': "d'Orbigny, 1839",
#   'scientific_name': "Bolborhynchus aymara (d'Orbigny, 1839)"},
#  {'bird': 'Paradoxornis zappeyi',
#   'alternate_names': 'None',
#   'scientific_name': 'Paradoxornis zappeyi'},
#  {'bird': 'grey-hooded sierra finch',
#   'alternate_names': 'Phrygilus gayi',
#   'scientific_name': 'Thraupidae'},
#  {'bird': 'Aethopyga primigenius',
#   'alternate_names': 'lapsus',
#   'scientific_name': 'Aethopyga primigenius'},
#  {'bird': 'Seicercus xanthoschistos',
#   'alternate_names': [],
#   'scientific_name': 'G'},
#  {'bird': 'grey-hooded white-eye',
#   'alternate_names': 'grey-hooded ibon',
#   'scientific_name': 'Heleia pinaiae'},
#  {'bird': 'eagle-owl',
#   'alternate_names': ['greyish eagle-owl', 'vermiculated eagle-owl'],
#   'scientific_name': 'Bubo cinerascens'},
#  {'bird': 'greyish miner',
#   'alternate_names': 'Geositta maritima',
#   'scientific_name': 'Furnariidae'},
#  {'bird': 'Rhytipterna simplex',
#   'alternate_names': 'greyish mourner',
#   'scientific_name': 'Rhytipterna simplex'},
#  {'bird': 'greyish piculet',
#   'alternate_names': 'Picumnus granadensis',
#   'scientific_name': 'Picumninae of the woodpecker family Picidae'},
#  {'bird': 'Greyish Saltator',
#   'alternate_names': [],
#   'scientific_name': 'Saltator coerulescens'},
#  {'bird': 'greylag goose or graylag goose',
#   'alternate_names': ['Anser anser'],
#   'scientific_name': 'Anser anser'},
#  {'bird': 'tinamou',
#   'alternate_names': ['grey-legged tinamou', 'gray-legged tinamou'],
#   'scientific_name': 'Crypturellus duidae'},
#  {'bird': 'grey-mantled wren',
#   'alternate_names': ['Odontorchilus branickii'],
#   'scientific_name': 'Odontorchilus branickii'},
#  {'bird': 'Grey-naped antpitta',
#   'alternate_names': 'Grallaria griseonucha',
#   'scientific_name': 'Grallariidae'},
#  {'bird': 'Grey-necked bunting',
#   'alternate_names': ['Grey-hooded bunting', 'Chestnut-eared bunting'],
#   'scientific_name': 'Emberiza buchanani'},
#  {'bird': 'grey-necked rockfowl',
#   'alternate_names': 'Picathartes oreas',
#   'scientific_name': 'Picathartidae'},
#  {'bird': 'grey-olive greenbul',
#   'alternate_names': ['grey-olive bulbul'],
#   'scientific_name': 'Phyllastrephus cerviniventris'},
#  {'bird': 'Grey-rumped swallow',
#   'alternate_names': ['Pseudhirundo griseopyga'],
#   'scientific_name': 'Pseudhirundo griseopyga'},
#  {'bird': 'Acanthylis cinereiventris',
#   'alternate_names': [],
#   'scientific_name': 'Acanthylis cinereiventris[2]'},
#  {'bird': 'grey-rumped swiftlet',
#   'alternate_names': ['Collocalia marginata'],
#   'scientific_name': 'Apodidae'},
#  {'bird': 'Grey-rumped Treeswift',
#   'alternate_names': 'None',
#   'scientific_name': 'Hemiprocne longipennis'},
#  {'bird': 'Grey-sided Bush Warbler',
#   'alternate_names': ['Cettia brunnifrons'],
#   'scientific_name': 'Cettia brunnifrons'},
#  {'bird': 'grey-sided flowerpecker',
#   'alternate_names': 'Dicaeum celebicum',
#   'scientific_name': 'Dicaeidae'},
#  {'bird': 'Ianthocincla caerulata',
#   'alternate_names': ['Garrulax caerulatus'],
#   'scientific_name': 'Ianthocincla caerulata'},
#  {'bird': 'grey-sided scimitar babbler',
#   'alternate_names': [],
#   'scientific_name': 'Erythrogenys swinhoei'},
#  {'bird': 'grey-sided thrush',
#   'alternate_names': ['Turdus feae'],
#   'scientific_name': 'Turdidae'},
#  {'bird': 'grey-streaked flycatcher or grey-spotted flycatcher',
#   'scientificName': 'Muscicapa griseisticta',
#   'genus': 'Muscicapa',
#   'family': 'Muscicapidae'},
#  {'bird': 'grey-streaked honeyeater',
#   'alternate_names': 'black-backed honeyeater',
#   'scientific_name': 'Ptiloprora perstriata'},
#  {'bird': 'Francolinus griseostriatus',
#   'alternate_names': 'Grey-breasted Francolin, Grey-breasted Spurfowl',
#   'scientific_name': 'Francolinus griseostriatus'},
#  {'bird': 'mountaingem',
#   'alternate_names': ['gray-tailed mountaingem',
#    'grey-tailed mountain-gem',
#    'gray-tailed mountain-gem'],
#   'scientific_name': 'Lampornis cinereicauda'},
#  {'bird': 'Lathria subalaris', 'alternate_names': [], 'scientific_name': 'P'},
#  {'bird': 'Heteroscelus brevipes',
#   'alternate_names': ['Heterosceles brevipes', 'Heteractitis brevipes'],
#   'scientific_name': 'Heteroscelus brevipes'},
#  {'bird': 'grey-throated babbler',
#   'alternate_names': [],
#   'scientific_name': 'Stachyris nigriceps'},
#  {'bird': 'grey-throated barbet',
#   'alternate_names': 'Gymnobucco bonapartei',
#   'scientific_name': 'Lybiidae family'},
#  {'bird': 'Grey-throated chat',
#   'alternate_names': 'Cardinals or cardinal grosbeaks',
#   'scientific_name': 'Granatellus sallaei'},
#  {'bird': 'grey-throated leaftosser',
#   'alternate_names': [],
#   'scientific_name': 'Sclerurus albigularis'},
#  {'bird': 'grey-throated martin or Asian plain martin',
#   'alternate_names': ['Riparia chinensis'],
#   'scientific_name': 'Riparia chinensis'},
#  {'bird': 'grey-throated rail',
#   'alternate_names': 'Canirallus oculeus',
#   'scientific_name': 'Rallidae'},
#  {'bird': 'Anthreptes malacensis',
#   'alternate_names': 'griseigularis',
#   'scientific_name': 'Anthreptes malacensis griseigularis'},
#  {'bird': 'grey-throated tit-flycatcher',
#   'alternate_names': ['Myioparus griseigularis'],
#   'scientific_name': 'Myioparus griseigularis'},
#  {'bird': 'Basileuterus cinereicollis',
#   'alternate_names': 'Gray-crowned Yellowthroat, Gray-hooded Yellowthroat',
#   'scientific_name': 'Basileuterus cinereicollis'},
#  {'bird': 'Zosterops ugiensis',
#   'alternate_names': 'None',
#   'scientific_name': 'Zosterops ugiensis'},
#  {'bird': 'grey-winged blackbird',
#   'alternate_names': 'Turdus boulboul',
#   'scientific_name': 'Turdus boulboul'},
#  {'bird': 'grey-winged cotinga',
#   'alternate_names': [],
#   'scientific_name': 'Lipaugus conditus'},
#  {'bird': 'Francolinus africanus',
#   'alternate_names': 'Scleroptila africanus',
#   'scientific_name': 'Francolinus africanusScleroptila africanus'},
#  {'bird': 'Inca finch',
#   'alternate_names': ['Incaspiza ortizi'],
#   'scientific_name': 'Emberizidae'},
#  {'bird': 'Grey-winged robin-chat',
#   'alternate_names': ['Grey-winged akalat'],
#   'scientific_name': 'Sheppardia polioptera'},
#  {'bird': 'Grey-winged trumpeter',
#   'alternate_names': ['Psophia crepitans'],
#   'scientific_name': 'Psophiidae'},
#  {'bird': 'Redirect to', 'alternate_names': None, 'scientific_name': None},
#  {'bird': "Grimwood's longclaw",
#   'alternate_names': 'Macronyx grimwoodi',
#   'scientific_name': 'Motacillidae'},
#  {'bird': 'Groove-billed Ani',
#   'alternate_names': ['Crotophaga sulcirostris'],
#   'scientific_name': 'Crotophaga sulcirostris'},
#  {'bird': 'See text', 'alternate_names': 'None', 'scientific_name': 'None'},
#  {'bird': 'Lanius dubium',
#   'alternate_names': [],
#   'scientific_name': 'Latham, 1801'},
#  {'bird': 'ground cuckoo-shrike',
#   'alternate_names': ['Coracina maxima'],
#   'scientific_name': 'Coracina maxima'},
#  {'bird': 'Podoces humilis',
#   'alternate_names': ['Parus humilis'],
#   'scientific_name': 'Hume, 1871'},
#  {'bird': 'Ground Woodpecker',
#   'alternate_names': ['Andean Flicker', 'Campo Flicker'],
#   'scientific_name': 'Geocolaptes olivaceus'},
#  {'bird': 'Psophocichla litsitsirupa',
#   'alternate_names': ['Psophocichla litsipsirupa'],
#   'scientific_name': 'Cabanis, 1860'},
#  {'bird': 'Growling Riflebird',
#   'alternate_names': 'Eastern Riflebird',
#   'scientific_name': 'Ptiloris intercedens'},
#  {'bird': 'Guadalcanal dwarf kingfisher',
#   'alternate_names': 'Ceyx nigromaxilla',
#   'scientific_name': 'Alcedinidae'},
#  {'bird': 'Guadalcanal honeyeater',
#   'alternate_names': 'none',
#   'scientific_name': 'Guadalcanaria inexpectata'},
#  {'bird': 'Guadalcanal thrush',
#   'alternate_names': [],
#   'scientific_name': 'Zoothera turipavae'},
#  {'bird': 'Junco hyemalis insularis',
#   'alternate_names': [],
#   'scientific_name': 'Ridgway, 1876'},
#  {'bird': 'Guadalupe murrelet',
#   'alternate_names': "Xantus' Murrelet",
#   'scientific_name': 'Synthliboramphus hypoleucus'},
#  {'bird': 'Oceanodroma leucorhoa macrodactyla',
#   'alternate_names': 'None',
#   'scientific_name': 'Oceanodroma leucorhoa macrodactyla W'},
#  {'bird': 'Picus herminieri',
#   'alternate_names': ['Linneopicus herminieri'],
#   'scientific_name': 'Lesson, 1830'},
#  {'bird': 'Guaiabero',
#   'alternate_names': ['Bolbopsittacus lunulatus'],
#   'scientific_name': 'Psittaculidae'},
#  {'bird': 'Guaiquinima whitestart',
#   'alternate_names': ['Guaiquinima redstart',
#    'Saffron-breasted whitestart',
#    'Saffron-breasted redstart'],
#   'scientific_name': 'Myioborus cardonai'},
#  {'bird': 'Guam flycatcher',
#   'alternate_names': 'Guam broadbill',
#   'scientific_name': 'Myiagra freycineti'},
#  {'bird': 'Guam kingfisher',
#   'alternate_names': [],
#   'scientific_name': 'Todiramphus cinnamominus'},
#  {'bird': 'Guam rail',
#   'alternate_names': "Ko'ko' bird",
#   'scientific_name': 'Hypotaenidia owstoni'},
#  {'bird': 'Phalacrocorax bougainvillii',
#   'alternate_names': ['Phalacrocorax bougainvilliorum',
#    'Leucocarbo bougainvillii'],
#   'scientific_name': 'Phalacrocorax bougainvillii'},
#  {'bird': 'Guatemalan pygmy owl',
#   'alternate_names': 'Glaucidium cobanense',
#   'scientific_name': 'Surniinae'},
#  {'bird': 'Guatemalan tyrannulet',
#   'alternate_names': ['paltry tyrannulet'],
#   'scientific_name': 'Zimmerius vilissimus'},
#  {'bird': 'Guayaquil woodpecker',
#   'alternate_names': 'Campephilus gayaquilensis',
#   'scientific_name': 'Picinae of the woodpecker family Picidae'},
#  {'bird': 'Pipra rupicola',
#   'alternate_names': [],
#   'scientific_name': 'Linnaeus, 1766'},
#  {'bird': 'Guianan gnatcatcher',
#   'alternate_names': 'none',
#   'scientific_name': 'Polioptila guianensis'},
#  {'bird': 'Guianan puffbird',
#   'alternate_names': ['puffbirds', 'nunlets', 'nunbirds'],
#   'scientific_name': 'Notharchus macrorhynchos'},
#  {'bird': 'Guianan red cotinga',
#   'alternate_names': [],
#   'scientific_name': 'Phoenicircus carnifex'},
#  {'bird': 'Guianan schiffornis',
#   'alternate_names': 'olivaceous schiffornis',
#   'scientific_name': 'Schiffornis olivacea'},
#  {'bird': 'Sitta surinamensis',
#   'alternate_names': 'Brown-headed Nuthatch, Surinam Nuthatch',
#   'scientific_name': 'Sitta surinamensis'},
#  {'bird': 'Guianan toucanet',
#   'alternate_names': 'Guyana toucanet',
#   'scientific_name': 'Selenidera piperivora',
#   'family': 'Ramphastidae'},
#  {'bird': 'Guianan trogon',
#   'alternate_names': ['Trogon violaceus'],
#   'scientific_name': 'Trogonidae'},
#  {'bird': 'Zimmerius gracilipes',
#   'alternate_names': "Zimmer's Flycatcher, Acer Flycatcher",
#   'scientific_name': 'Zimmerius gracilipes acer'},
#  {'bird': 'Hypocnemis cantator',
#   'alternate_names': 'None',
#   'scientific_name': 'Hypocnemis cantator'},
#  {'bird': 'Guianan woodcreeper',
#   'alternate_names': [],
#   'scientific_name': 'Lepidocolaptes albolineatus'},
#  {'bird': 'Cuculus persa',
#   'alternate_names': [],
#   'scientific_name': 'Linnaeus, 1758'},
#  {'bird': 'Guira cuckoo',
#   'alternate_names': 'Guira guira',
#   'scientific_name': 'Guira guira'},
#  {'bird': 'Motacilla guira',
#   'alternate_names': [],
#   'scientific_name': 'Motacilla guira (protonym)'},
#  {'bird': "Güldenstädt's redstart",
#   'alternate_names': 'white-winged redstart',
#   'scientific_name': 'Phoenicurus erythrogastrus',
#   'genus': 'Phoenicurus',
#   'family': 'Muscicapidae'},
#  {'bird': 'Sterna nilotica',
#   'alternate_names': 'Gull-billed Tern, White-winged Tern, White-winged Black Tern',
#   'scientific_name': 'Chlidonias nilotica'},
#  {'bird': 'Accipiter gundlachii',
#   'alternate_names': 'Lawrence, 1860 [orth',
#   'scientific_name': 'Accipiter gundlachii Lawrence, 1860 [orth'},
#  {'bird': 'Centrocercus urophasianoides',
#   'alternate_names': 'None',
#   'scientific_name': 'Centrocercus urophasianoides'},
#  {'bird': "Gurney's eagle",
#   'alternate_names': ['Aquila gurneyi'],
#   'scientific_name': 'Accipitridae'},
#  {'bird': "Gurney's pitta",
#   'alternate_names': ['Thai: นกแต้วแร้วท้องดำ'],
#   'scientific_name': 'Hydrornis gurneyi'},
#  {'bird': "Gurney's sugarbird",
#   'alternate_names': 'Promerops gurneyi',
#   'scientific_name': 'Promerops gurneyi'},
#  {'bird': 'Anabazenops guttulatus',
#   'alternate_names': 'none',
#   'scientific_name': 'Anabazenops guttulatus'},
#  {'bird': 'gyrfalcon',
#   'alternate_names': ['Falco rusticolus'],
#   'scientific_name': 'Falco rusticolus'}]

# %%
import pandas as pd

df = pd.DataFrame({
    'raw': obj,
    'json': t
})

df
# Out:
#                                                    raw  \
# 0    The Iago sparrow (Passer iagoensis), also know...
# 1    The Ibadan malimbe (Malimbus ibadanensis) is a...
# 2    The Ibera seedeater (Sporophila iberaensis) is...
# 3    The Iberian chiffchaff (Phylloscopus ibericus)...
# 4    The Iberian green woodpecker (Picus sharpei) i...
# ..                                                 ...
# 889  Gurney's eagle (Aquila gurneyi) is a large eag...
# 890  Gurney's pitta (Hydrornis gurneyi) (Thai: นกแต...
# 891  Gurney's sugarbird (Promerops gurneyi) is a me...
# 892                             Anabazenops guttulatus
# 893  The gyrfalcon (/ˈdʒɜːrˌfɔː(l)kən/ or /ˈdʒɜːrˌf...
#
#                                                   json
# 0    {'bird': 'Iago sparrow', 'alternate_names': ['...
# 1    {'bird': 'Ibadan malimbe', 'alternate_names': ...
# 2    {'bird': 'Ibera seedeater', 'alternate_names':...
# 3    {'bird': 'Iberian chiffchaff', 'alternate_name...
# 4    {'bird': 'Iberian green woodpecker', 'alternat...
# ..                                                 ...
# 889  {'bird': 'Gurney's eagle', 'alternate_names': ...
# 890  {'bird': 'Gurney's pitta', 'alternate_names': ...
# 891  {'bird': 'Gurney's sugarbird', 'alternate_name...
# 892  {'bird': 'Anabazenops guttulatus', 'alternate_...
# 893  {'bird': 'gyrfalcon', 'alternate_names': ['Fal...
#
# [894 rows x 2 columns]

# %%
def get(x):
    try:
        return x['scientific_name']
    except:
        return None
df['scientific_name'] = df.json.apply(get)

# %%
df
# Out:
#                                                    raw  \
# 0    The Iago sparrow (Passer iagoensis), also know...
# 1    The Ibadan malimbe (Malimbus ibadanensis) is a...
# 2    The Ibera seedeater (Sporophila iberaensis) is...
# 3    The Iberian chiffchaff (Phylloscopus ibericus)...
# 4    The Iberian green woodpecker (Picus sharpei) i...
# ..                                                 ...
# 889  Gurney's eagle (Aquila gurneyi) is a large eag...
# 890  Gurney's pitta (Hydrornis gurneyi) (Thai: นกแต...
# 891  Gurney's sugarbird (Promerops gurneyi) is a me...
# 892                             Anabazenops guttulatus
# 893  The gyrfalcon (/ˈdʒɜːrˌfɔː(l)kən/ or /ˈdʒɜːrˌf...
#
#                                                   json  \
# 0    {'bird': 'Iago sparrow', 'alternate_names': ['...
# 1    {'bird': 'Ibadan malimbe', 'alternate_names': ...
# 2    {'bird': 'Ibera seedeater', 'alternate_names':...
# 3    {'bird': 'Iberian chiffchaff', 'alternate_name...
# 4    {'bird': 'Iberian green woodpecker', 'alternat...
# ..                                                 ...
# 889  {'bird': 'Gurney's eagle', 'alternate_names': ...
# 890  {'bird': 'Gurney's pitta', 'alternate_names': ...
# 891  {'bird': 'Gurney's sugarbird', 'alternate_name...
# 892  {'bird': 'Anabazenops guttulatus', 'alternate_...
# 893  {'bird': 'gyrfalcon', 'alternate_names': ['Fal...
#
#                          bird                      alternate_names  \
# 0                Iago sparrow  [Cape Verde, rufous-backed sparrow]
# 1              Ibadan malimbe               [Malimbus ibadanensis]
# 2             Ibera seedeater              [Sporophila iberaensis]
# 3          Iberian chiffchaff                                   []
# 4    Iberian green woodpecker                        Picus sharpei
# ..                        ...                                  ...
# 889            Gurney's eagle                     [Aquila gurneyi]
# 890            Gurney's pitta             [Thai: นกแต้วแร้วท้องดำ]
# 891        Gurney's sugarbird                    Promerops gurneyi
# 892    Anabazenops guttulatus                                 none
# 893                 gyrfalcon                   [Falco rusticolus]
#
#             scientific_name
# 0          Passer iagoensis
# 1                 Ploceidae
# 2                Thraupidae
# 3     Phylloscopus ibericus
# 4             Picus sharpei
# ..                      ...
# 889            Accipitridae
# 890       Hydrornis gurneyi
# 891       Promerops gurneyi
# 892  Anabazenops guttulatus
# 893        Falco rusticolus
#
# [894 rows x 5 columns]

# %%
df.to_csv('annotation.csv')
